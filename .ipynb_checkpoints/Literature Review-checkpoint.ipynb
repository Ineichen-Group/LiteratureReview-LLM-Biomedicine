# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
from webcolors import hex_to_rgb
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Load Data

# %%
def load_raw_data():
    df_pubmed = pd.read_excel("data/Scoping_review_text-analysis_extraction_2024.xlsx", sheet_name="Harmonized Information Extracti")
    df_pubmed['publication_type'] = "biomedical_journal"
    df_acl = pd.read_excel("data/Scoping_review_text-analysis_extraction_2024.xlsx", sheet_name="ACLEMNLP Google Scholar")
    df_acl['publication_type'] = "nlp_venue"
    return df_pubmed, df_acl

# %%
df_pubmed, df_acl = load_raw_data()

# %%
def load_raw_data_included_all():
    df_pubmed, df_acl = load_raw_data()
    df_included = df_pubmed[df_pubmed['Included'] == 1.0]
    df_acl_included = df_acl[df_acl['Included'] == 1.0]
    df = pd.concat([df_included, df_acl_included], ignore_index=True)
    df['year'] = df['year'].astype(int)
    print(df_pubmed.shape, df_included.shape, df_acl.shape, df_acl_included.shape)
    return df

# %%
df_2024 = pd.read_excel("data/Scoping_review_text-analysis_extraction_2024.xlsx", sheet_name="SED Version Sijing Extractions ")
## ALIGN WITH PREVIOUS NAMES
# Replace 'Association for Computational Linguistics' with 'ACL'
df_2024['journal'] = df_2024['journal'].str.replace('Association for Computational Linguistics', 'ACL', regex=False)
df_2024['journal'] = df_2024['journal'].str.replace('BMC bioinformatics', 'BMC Bioinformatics', regex=False)
df_2024['journal'] = df_2024['journal'].str.replace('Frontiers in psychiatry', 'Frontiers in Psychiatry', regex=False)

# Replace 'ACL Findings' followed by any characters with 'ACL/Findings'
df_2024['journal'] = df_2024['journal'].str.replace(r'ACL Findings.*', 'ACL/ Findings', regex=True)
df_2024['journal'] = df_2024['journal'].str.replace(r'Findings of the ACL.*', 'ACL/ Findings', regex=True)

df_2024['journal'] = df_2024['journal'].str.replace(r'EMNLP.*', 'EMNLP', regex=True)

df_2024['publication_type'] = np.where(
    df_2024['journal'].str.contains('EMNLP|ACL'), 
    'nlp_venue', 
    'biomedical_journal'
)

# %%
df_2024_included = df_2024[df_2024['Included'] == 1.0]
df_2024_included.loc[:, 'year'] = df_2024_included['year'].astype(int)
# Out:
# /Users/donevas/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_initial = load_raw_data_included_all()
# Out:
# (504, 71) (89, 71) (491, 68) (51, 68)

# %%
# Creating sets of lowercased titles for each DataFrame
titles_df1 = set(df_initial['title'].str.lower())
titles_df2 = set(df_2024_included['title'].str.lower())

# Finding the intersection of the two sets
overlap_titles = titles_df1.intersection(titles_df2)

# Counting the number of overlaps
number_of_overlaps = len(overlap_titles)

# %%
overlap_titles
# Out:
# set()

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)

# %%
df.shape
# Out:
# (196, 74)

# %%
df.groupby("publication_type")["title"].count()
# Out:
# publication_type
# biomedical_journal    137
# nlp_venue              59
# Name: title, dtype: int64

# %%
df.head(3)
# Out:
#                                               author  \
# 0  Abdelkader, W. and Navarro, T. and Parrish, R....
# 1  Alachram, H. and Chereda, H. and Beisbarth, T....
# 2          Ambalavanan, A. K. and Devarakonda, M. V.
#
#                             doi                                 Link to paper  \
# 0                 10.2196/29398                 https://doi.org/10.2196/29398
# 1  10.1371/journal.pone.0258623  https://doi.org/10.1371/journal.pone.0258623
# 2     10.1016/j.jbi.2020.103578     https://doi.org/10.1016/j.jbi.2020.103578
#
#                                                title  \
# 0  A Deep Learning Approach to Refine the Identif...
# 1  Text mining-based word representations for bio...
# 2  Using the contextual language model BERT for m...
#
#                              journal  year Extracted by Included  \
# 0            JMIR Research Protocols  2021          BVI      1.0
# 1     PLoS ONE [Electronic Resource]  2021          BVI      1.0
# 2  Journal of Biomedical Informatics  2020          BVI      1.0
#
#   Reason for exclusion      Target application  \
# 0                  NaN     Text Classification
# 1                  NaN  Information Extraction
# 2                  NaN     Text Classification
#
#                         Domain of automated approach  \
# 0  Literature Screening/ Methodological Quality: ...
# 1  General biomedical text mining/ Genomics: Extr...
# 2  Literature Screening/ Combination of Selection...
#
#                               Target database                       Data type  \
# 0                                      PubMed                       Abstracts
# 1  PubMed, Gene Expression Omnibus repository  Abstracts, Functional Genomics
# 2                                     MEDLINE                       Abstracts
#
#   Data filter applied        Hosted Application for End-users  \
# 0                 NaN                                      no
# 1                 NaN  yes: https://ebiomecon.genexplain.com/
# 2                 NaN                                      no
#
#   Alternative Approach                            LLM Model  \
# 0                  NaN  BERT, BioBERT, BlueBERT, PubMedBERT
# 1                  NaN                              BioBERT
# 2                  NaN                              SciBERT
#
#                       Models/Resources used with LLM  \
# 0                                                NaN
# 1  Graph-CNN based on Human Protein Reference Dat...
# 2  feed forward network (FFN) as the text classif...
#
#   System Architecture/ Flow Programming language Library/Framework  \
# 0         BERT architecture               Python       HuggingFace
# 1         BERT architecture               Python           PyTorch
# 2         BERT architecture               Python           PyTorch
#
#   Library/Framework Harmonized  \
# 0                  HuggingFace
# 1                      PyTorch
# 2                      PyTorch
#
#                         Reported performance metrics  \
# 0  F1, recall, specificity, accuracy, precision, ...
# 1            AUC, Accuracy, F1, similarity threshold
# 2                              Precision, Recall, F1
#
#              Reported performance metrics Harmonized Source code availability  \
# 0  F1-Score, Recall, Specificity, Accuracy, Preci...                       no
# 1      AUC, Accuracy, F1-Score, Similarity Threshold                       no
# 2                        Precision, Recall, F1-Score                      yes
#
#                                   Source code link Data used availability  \
# 0                                              NaN              partially
# 1                                              NaN                    NaN
# 2  https://github.com/md-labs/Clinical_Hedges_BERT                    yes
#
#                                Preprocessing applied  \
# 0                                                NaN
# 1  for word2vec training: The first phase applied...
# 2                                                NaN
#
#             Pretraining corpus origin       Pretraining corpus size  \
# 0               depends on BERT model         depends on BERT model
# 1  for word2vec PubMed FTP repository  16,558,093 article abstracts
# 2                         see SciBERT                   see SciBERT
#
#                  Fine-tuning corpus data/task  \
# 0                Custom-annotated PubMed data
# 1  HPRD PPI; Custom-annotated from GEO series
# 2                     Clinical Hedges Dataset
#
#                                      New annotations Annotations type  \
# 0  Article type: original study, systematic revie...              NaN
# 1  genomic predictors of response and survival in...              NaN
# 2                                                NaN              NaN
#
#   New dataset developed                            Fine-tuning corpus size  \
# 0                   yes  Total 2012–2020, N=160 712 (positive 29810 and...
# 1                   yes  10 microarray datasets measured on Affymetrix ...
# 2                    no                                     50,590 entries
#
#   Number of tasks/datasets for performance evaluation  \
# 0                                                1.0
# 1  4 (lung cancer, liver cancer, prostate cancer,...
# 2                                                NaN
#
#    Hardware used for training/validation/fine-tuning Hardware type  \
# 0  8 Intel Silver 4216 Cascade Lake CPU cores, an...      GPU, CPU
# 1                                                NaN           NaN
# 2                                                GPU           GPU
#
#   Internal validity 1 Internal validity 2 External validity  \
# 0                 Yes                  No                No
# 1                 Yes                  No               yes
# 2                 Yes                  No               yes
#
#           External validity.1  \
# 0                         NaN
# 1                    word2vec
# 2  CNN, Customized text query
#
#                                              Comment  Unnamed: 43  \
# 0                                          Protocol!          NaN
# 1                                                NaN          NaN
# 2  Clinical Hedges dataset could be relevant for ...          NaN
#
#                                                  url  \
# 0  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 1  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 2  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
#
#                           label  type  \
# 0  Abdelkader_2021_JMIRReseProt  JOUR
# 1    Alachram_2021_PLoONE.ElRes  JOUR
# 2     Ambalavanan_2020_JoofBiIn  JOUR
#
#                                             abstract  \
# 0  BACKGROUND: A barrier to practicing evidence-b...
# 1  Biomedical and life science literature is an e...
# 2  BACKGROUND: Finding specific scientific articl...
#
#                                              address   accession  Link issue  \
# 0  Abdelkader, Wael. Health Information Research ...  34847061.0   NaN  11.0
# 1  Alachram, Halima. Department of Medical Bioinf...  34653224.0   NaN  10.0
# 2  Ambalavanan, Ashwin Karthik. Arizona State Uni...  33059047.0   NaN   NaN
#
#                                             keywords language       issn  \
# 0                                                NaN  English  1929-0748
# 1  Algorithms and *Breast Neoplasms/ge [Genetics]...  English  1932-6203
# 2  Information Storage and Retrieval and Medline ...  English  1532-0480
#
#       pages volume                   DA       DB                 DP     ID  \
# 0    e29398   10.0  2023-11-29 00:00:00  MEDLINE  Ovid Technologies   15.0
# 1  e0258623   16.0                  NaN  MEDLINE  Ovid Technologies  101.0
# 2  103578.0  112.0                 12.0  MEDLINE  Ovid Technologies  182.0
#
#                 j2                                m3  \
# 0  JMIR Res Protoc                               NaN
# 1         PLoS ONE  Research Support, Non-U.S. Gov't
# 2  J Biomed Inform                               NaN
#
#                                                   n1  \
# 0  Abdelkader, Wael Navarro, Tamara Parrish, Rick...
# 1  Alachram, Halima Chereda, Hryhorii Beisbarth, ...
# 2  Ambalavanan, Ashwin Karthik Devarakonda, Murth...
#
#                                                   ST   m1  c5  c2  c1  OP  \
# 0  A Deep Learning Approach to Refine the Identif...  NaN NaN NaN NaN NaN
# 1  Text mining-based word representations for bio...  NaN NaN NaN NaN NaN
# 2  Using the contextual language model BERT for m...  NaN NaN NaN NaN NaN
#
#      publication_type  Unnamed: 40 Data availability  Unnamed: 33
# 0  biomedical_journal          NaN               NaN          NaN
# 1  biomedical_journal          NaN               NaN          NaN
# 2  biomedical_journal          NaN               NaN          NaN

# %% [markdown]
# ### random sample for a pilot with student

# %%
# Sample 3 random rows from df_included
df_included_sampled = df_pubmed[df_pubmed['Included'] == 1.0].sample(n=3, random_state=42)

# Sample 2 random rows from df_acl_included
df_acl_included_sampled = df_acl[df_acl['Included'] == 1.0].sample(n=2, random_state=42)

# Combine the sampled DataFrames
combined_df = pd.concat([df_included_sampled, df_acl_included_sampled])
combined_df_first_cols = combined_df.iloc[:, :6]

# Display the combined DataFrame
combined_df.head()
# Out:
#                                                 author  \
# 219  Li, D. and Xiong, Y. and Hu, B. and Tang, B. a...
# 265  Martenot, V. and Masdeu, V. and Cupe, J. and G...
# 166                      Ji, Z. and Wei, Q. and Xu, H.
# 279  ['Zhang, Y.', 'Zhou, B.', 'Song, K.', 'Sui, X....
# 256                ['Lu, Q.', 'Dou, D.', 'Nguyen, T.']
#
#                             doi  \
# 219  10.1186/s12911-021-01614-7
# 265  10.1186/s12911-022-02085-0
# 166                         NaN
# 279                         NaN
# 256                         NaN
#
#                                          Link to paper  \
# 219         https://doi.org/10.1186/s12911-021-01614-7
# 265         https://doi.org/10.1186/s12911-022-02085-0
# 166                                   https://doi.org/
# 279  https://aclanthology.org/2022.findings-emnlp.1...
# 256  https://aclanthology.org/2022.findings-emnlp.3...
#
#                                                  title  \
# 219  Drug knowledge discovery via multi-task learni...
# 265  LiSA: an assisted literature search pipeline f...
# 166  BERT-based Ranking for Biomedical Entity Norma...
# 279  PM2F2N: Patient Multi-view Multi-modal Feature...
# 256  ClinicalT5: A generative language model for cl...
#
#                                                journal    year Extracted by  \
# 219          BMC Medical Informatics & Decision Making  2021.0          SDO
# 265          BMC Medical Informatics & Decision Making  2022.0          SDO
# 166  AMIA Summits on Translational Science Proceedings  2020.0          SDO
# 279  Association for Computational Linguistics/ Fin...  2022.0          SDO
# 256  Association for Computational Linguistics/ Fin...  2022.0          SDO
#
#     Included Reason for exclusion            Target application  \
# 219      1.0                  NaN        Information Extraction
# 265      1.0                  NaN         Information Retrieval
# 166      1.0                  NaN  Entity Normalization/Linking
# 279      1.0                  NaN           Text Classification
# 256      1.0                  NaN                  Multi-Domain
#
#                           Domain of automated approach  \
# 219  Pharma/ Drug Repurposing: Collecting mutation-...
# 265  Literature-Based Discovery/ Pharma/ Adverse-Dr...
# 166  General biomedical text mining: Alleviate the ...
# 279  Clinical/ Outcome Prediction: clinical outcome...
# 256  General biomedical text mining: T5-based text-...
#
#                           Target database                        Data type  \
# 219                                PubMed                        Abstracts
# 265                                PubMed  Abstracts, Full-text, Sentences
# 166                Clinical texts, PubMed        Clinical notes, Abstracts
# 279  Clinical texts, sensory patient data                   Clinical notes
# 256                        Clinical texts                   Clinical notes
#
#     Data filter applied Hosted Application for End-users Alternative Approach  \
# 219                 NaN                               no                  NaN
# 265                 NaN              yes, but not public                  NaN
# 166                 NaN                               no                  NaN
# 279                 NaN                               no                  NaN
# 256                 NaN                               no                  NaN
#
#                                              LLM Model  \
# 219             BERT, NCBI BERT, ClinicalBERT, BioBERT
# 265  BioBERT, BlueBERT, SciBERT, Bio+ClinicalBERT, ...
# 166                        BERT, BioBERT, ClinicalBERT
# 279                                            BioBERT
# 256                                 SciFive-PubMed-PMC
#
#                         Models/Resources used with LLM  \
# 219                                                NaN
# 265  regex-search, keyword search algorithm, rule-b...
# 166                                               BM25
# 279  Graph Neural Networks, TF-IDF, Bi-GRU, Med7 mo...
# 256                                                NaN
#
#                              System Architecture/ Flow Programming language  \
# 219  We start by splitting the PubMed abstract into...               Python
# 265  documents -> format into 3 tables: documents (...               Python
# 166  Mention -> Pre-processing -> Candidate Conpcet...         Python, Java
# 279                                                NaN               Python
# 256                                                NaN               Python
#
#                           Library/Framework  \
# 219                                     NaN
# 265  HuggingFace, PowerBI for visualization
# 166                           CLAMP toolkit
# 279                                     NaN
# 256                                     NaN
#
#                Library/Framework Harmonized  \
# 219                                     NaN
# 265  HuggingFace, PowerBI for visualization
# 166                           CLAMP toolkit
# 279                                     NaN
# 256                    PyTorch, HuggingFace
#
#                           Reported performance metrics  \
# 219                        Precision, Recall, F1-score
# 265  precision, recall, F1-score; comparison to key...
# 166                                           accuracy
# 279                                                NaN
# 256                                                NaN
#
#                Reported performance metrics Harmonized  \
# 219                        Precision, Recall, F1-Score
# 265  Precision, Recall, F1-Score, Comparison to Key...
# 166                                           Accuracy
# 279                                       AUROC, AUPRC
# 256              Precision, Recall, F1-Score, Accuracy
#
#     Source code availability                     Source code link  \
# 219                       no                                  NaN
# 265                       no                                  NaN
# 166                       no                                  NaN
# 279                      yes  https://github.com/ZovanZhou/PM2F2N
# 256                       no                                  NaN
#
#     Data used availability                              Preprocessing applied  \
# 219                    yes                             WordPiece tokenization
# 265              partially                              sentence tokenization
# 166                    yes  spelling correction, abbreviation resolution, ...
# 279                    yes                                                NaN
# 256                    yes  minimal pre-processing isconducted where unnec...
#
#             Pretraining corpus origin           Pretraining corpus size  \
# 219             depends on BERT model             depends on BERT model
# 265                   depends on BERT                   depends on BERT
# 166  depends on the pre-trained model  depends on the pre-trained model
# 279                           biobert                           biobert
# 256                         MIMIC-III                   2 million notes
#
#                           Fine-tuning corpus data/task  \
# 219  BC5CDR-disease; NCBI-disease; BC2GM; 2010 i2b2...
# 265  ADE-Corpus-V2 dataset; Custom-annotated PubMed...
# 166             ShARe/CLEF; NCBI-disease; TAC-ADR 2017
# 279                                         MIMIC-III
# 256  HOC dataset; NCBI-disease; BC5CDR-disease; MedNLI
#
#                                        New annotations Annotations type  \
# 219                                                NaN              NaN
# 265  sentences labeled for three categories based o...              NaN
# 166                                                NaN              NaN
# 279                                                NaN              NaN
# 256                                                NaN              NaN
#
#     New dataset developed                            Fine-tuning corpus size  \
# 219                    no  # Train 4559; 5423; 12,573; 16,315 # Dev 4580;...
# 265                   yes                     20k sentences ; 7776 sentences
# 166                    no                      see paper table with overview
# 279                    no                                        see table 1
# 256                    no                                                tbr
#
#     Number of tasks/datasets for performance evaluation  \
# 219                                                4.0
# 265                                                3.0
# 166                                                3.0
# 279                                                4.0
# 256                                                3.0
#
#     Hardware used for training/validation/fine-tuning Hardware type  \
# 219                                               NaN           NaN
# 265                                               NaN           NaN
# 166                                  Quadro P6000 GPU           GPU
# 279                                 NVIDIA GTX A6000            GPU
# 256                     3 Nvidia Tesla V100-32GB GPUs           GPU
#
#     Internal validity 1 Internal validity 2 External validity  \
# 219                 yes                 NaN               yes
# 265                 yes                 NaN         partially
# 166                 yes                 NaN               yes
# 279                 yes                 NaN               yes
# 256                 yes                 NaN               yes
#
#                                    External validity.1  \
# 219                                       BiLSTM + CRF
# 265                           only LLM models compared
# 166  UWM, TaggerOne, CNN-based, Xu et al.’s system,...
# 279                                        SOTA models
# 256                         BART, T5, BioBART, SciFive
#
#                                  Comment  Unnamed: 43  \
# 219                                  NaN          NaN
# 265  they use PowerBI for visualisation!          NaN
# 166                                  NaN          NaN
# 279                                  NaN          NaN
# 256                                  NaN          NaN
#
#                                                    url                 label  \
# 219  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...        Li_2021_BMI.DM
# 265  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...  Martenot_2022_BMI.DM
# 166  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...  Ji_2020_AMSuonTrScPr
# 279                                                NaN                   NaN
# 256                                                NaN                   NaN
#
#      type                                           abstract  \
# 219  JOUR  BACKGROUND: Drug repurposing is to find new in...
# 265  JOUR  INTRODUCTION: Detecting safety signals attribu...
# 166  JOUR  Developing high-performance entity normalizati...
# 279   NaN  Clinical outcome prediction is critical to the...
# 256   NaN  In the past few years, large pre-trained langu...
#
#                                                address   accession  Link  \
# 219  Li, Dongfang. Harbin Institute of Technology (...  34789238.0   NaN
# 265  Martenot, Vincent. Quinten, 8 rue Vernier, 750...  36550485.0   NaN
# 166  Ji, Zongcheng. School of Biomedical Informatic...  32477646.0   NaN
# 279                                                NaN         NaN   NaN
# 256                                                NaN         NaN   NaN
#
#        issue                                           keywords language  \
# 219  Suppl 9  Algorithms and Humans and Information Storage ...  English
# 265      1.0  Humans and *Deep Learning and Reproducibility ...  English
# 166      NaN                                                NaN  English
# 279      NaN                                                NaN      NaN
# 256      NaN                                                NaN      NaN
#
#           issn    pages  volume     DA       DB                 DP      ID  \
# 219  1472-6947    251.0    21.0  11 16  MEDLINE  Ovid Technologies  2897.0
# 265  1472-6947    338.0    22.0  12 22  MEDLINE  Ovid Technologies  3308.0
# 166  2153-4063  269-277  2020.0    NaN  MEDLINE  Ovid Technologies  2280.0
# 279        NaN      NaN     NaN    NaN      NaN                NaN     NaN
# 256        NaN      NaN     NaN    NaN      NaN                NaN     NaN
#
#                                j2                                m3  \
# 219         BMC Med Inf Decis Mak  Research Support, Non-U.S. Gov't
# 265         BMC Med Inf Decis Mak  Research Support, Non-U.S. Gov't
# 166  AMIA Summits Transl Sci Proc                               NaN
# 279                           NaN                               NaN
# 256                           NaN                               NaN
#
#                                                     n1  \
# 219  Li, Dongfang Xiong, Ying Hu, Baotian Tang, Buz...
# 265  Martenot, Vincent Masdeu, Valentin Cupe, Jean ...
# 166  Ji, Zongcheng Wei, Qiang Xu, Hua and ASReview_...
# 279                                                NaN
# 256                                                NaN
#
#                                                     ST   m1  c5  c2  c1  OP  \
# 219  Drug knowledge discovery via multi-task learni...  NaN NaN NaN NaN NaN
# 265  LiSA: an assisted literature search pipeline f...  NaN NaN NaN NaN NaN
# 166  BERT-based Ranking for Biomedical Entity Norma...  NaN NaN NaN NaN NaN
# 279                                                NaN  NaN NaN NaN NaN NaN
# 256                                                NaN  NaN NaN NaN NaN NaN
#
#        publication_type  Unnamed: 40
# 219  biomedical_journal          NaN
# 265  biomedical_journal          NaN
# 166  biomedical_journal          NaN
# 279           nlp_venue          NaN
# 256           nlp_venue          NaN

# %%
combined_df_first_cols.to_csv("sample_to_test_new_extractor.csv")

# %%
combined_df.to_csv("full_sample_to_test_new_extractor.csv")

# %% [markdown]
# # Explorative

# %%
df_2024_included.groupby("publication_type")["title"].count()
# Out:
# publication_type
# biomedical_journal    48
# nlp_venue              8
# Name: title, dtype: int64

# %% [markdown]
# ## Overview excluded papers

# %%
df_bio_excluded = df_pubmed[df_pubmed['Included'] == 0]
df_acl_excluded = df_acl[df_acl['Included'] == 0]
df_2024_excluded = df_2024[df_2024['Included'] == 0]

len(df_bio_excluded), len(df_acl_excluded), len(df_2024_excluded)
# Out:
# (406, 32, 79)

# %%
df_excluded = pd.concat([df_bio_excluded, df_acl_excluded, df_2024_excluded], ignore_index=True)
df_excluded['year'] = df_excluded['year'].astype(int)

# %%
df_excluded = df_excluded[["Reason for exclusion", "year", "publication_type"]]

# %%
df_excluded
# Out:
#                                   Reason for exclusion  year  \
# 0                                              No LLMs  2017
# 1                                              No LLMs  2021
# 2                                              No LLMs  2022
# 3                                              No LLMs  2018
# 4                                               Review  2021
# 5                                              No LLMs  2017
# 6                                              No LLMs  2019
# 7                                              No LLMs  2017
# 8                                              No LLMs  2020
# 9                                              No LLMs  2021
# 10                                             No LLMs  2018
# 11                                             No LLMs  2019
# 12                                             No LLMs  2022
# 13                                             No LLMs  2022
# 14                                             No LLMs  2017
# 15                                             No LLMs  2019
# 16                                             No LLMs  2022
# 17                                             No LLMs  2022
# 18                                             No LLMs  2022
# 19                                             No LLMs  2023
# 20                                             No LLMs  2023
# 21                                             No LLMs  2022
# 22                                             No LLMs  2018
# 23                                             No LLMs  2021
# 24                                             No LLMs  2018
# 25                                             No LLMs  2017
# 26                                             No LLMs  2017
# 27                                             No LLMs  2018
# 28                                             No LLMs  2019
# 29                                             No LLMs  2021
# 30                                             No LLMs  2017
# 31                                             No LLMs  2021
# 32                                             No LLMs  2020
# 33                                             No LLMs  2021
# 34                                             No LLMs  2018
# 35                                             No LLMs  2017
# 36                                              Review  2022
# 37                                             No LLMs  2022
# 38                                             No LLMs  2018
# 39                                             No LLMs  2020
# 40                                             No LLMs  2019
# 41                                             No LLMs  2021
# 42                                             No LLMs  2019
# 43                                             No LLMs  2020
# 44                                             No LLMs  2019
# 45                                             No LLMs  2017
# 46                                             No LLMs  2022
# 47                                             No LLMs  2022
# 48                                             No LLMs  2020
# 49                                             No LLMs  2020
# 50                                             No LLMs  2021
# 51                                             No LLMs  2018
# 52                                             No LLMs  2021
# 53                                             No LLMs  2017
# 54                                             No LLMs  2023
# 55                                             No LLMs  2017
# 56                                             No LLMs  2020
# 57                                             No LLMs  2020
# 58                                             No LLMs  2018
# 59                                             No LLMs  2019
# 60                                             No LLMs  2018
# 61                                             No LLMs  2019
# 62                                             No LLMs  2017
# 63                                             No LLMs  2020
# 64                                             No LLMs  2020
# 65                                             No LLMs  2021
# 66                                             No LLMs  2019
# 67                                             No LLMs  2022
# 68                                             No LLMs  2020
# 69                                             No LLMs  2020
# 70                                             No LLMs  2017
# 71                                             No LLMs  2017
# 72                                             No LLMs  2018
# 73                                             No LLMs  2021
# 74                                             No LLMs  2022
# 75                                             No LLMs  2017
# 76                                         Not English  2022
# 77                                             No LLMs  2019
# 78                                             No LLMs  2020
# 79                                             No LLMs  2022
# 80                                             No LLMs  2022
# 81                                             No LLMs  2017
# 82                                             No LLMs  2020
# 83                                             No LLMs  2019
# 84                                             No LLMs  2018
# 85                                             No LLMs  2018
# 86                                             No LLMs  2019
# 87                                             No LLMs  2020
# 88                                             No LLMs  2021
# 89                                             No LLMs  2018
# 90                                             No LLMs  2017
# 91                                             No LLMs  2018
# 92                                             No LLMs  2019
# 93                                             No LLMs  2022
# 94                                             No LLMs  2019
# 95                                           DUPLICATE  2019
# 96                                              Review  2019
# 97                                              Review  2020
# 98                                              Review  2020
# 99                                              Review  2021
# 100                                          DUPLICATE  2021
# 101                                             Review  2019
# 102                                             Review  2018
# 103                                            No LLMs  2020
# 104                                            No LLMs  2019
# 105                WITHDRAWN due to integrity concerns  2021
# 106                                            No LLMs  2020
# 107  No LLMs (although benchmaerked with a BERT sys...  2022
# 108    No biomedical focus, but Chemistry application.  2022
# 109                                            No LLMs  2021
# 110                                            No LLMs  2018
# 111                                            No LLMs  2017
# 112                                            No LLMs  2022
# 113                                            No LLMs  2022
# 114                                            No LLMs  2020
# 115                                            No LLMs  2017
# 116                                            No LLMs  2019
# 117                                            No LLMs  2018
# 118                                            No LLMs  2019
# 119                                            No LLMs  2020
# 120                                            No LLMs  2019
# 121                                            No LLMs  2018
# 122                                            No LLMs  2019
# 123                                            No LLMs  2019
# 124                                            No LLMs  2018
# 125                                             Review  2020
# 126                                            No LLMs  2017
# 127                                            No LLMs  2020
# 128                                            No LLMs  2021
# 129                                            No LLMs  2018
# 130                                            No LLMs  2022
# 131                                            No LLMs  2018
# 132                                            No LLMs  2020
# 133                                            No LLMs  2021
# 134                                            No LLMs  2020
# 135                                            No LLMs  2019
# 136                                            No LLMs  2019
# 137                                            No LLMs  2019
# 138                                            No LLMs  2019
# 139                                            No LLMs  2018
# 140                                            No LLMs  2017
# 141                                            No LLMs  2023
# 142                                            No LLMs  2019
# 143                                             Review  2020
# 144                                            No LLMs  2017
# 145                                            No LLMs  2019
# 146                                            No LLMs  2019
# 147                                            No LLMs  2018
# 148                                            No LLMs  2018
# 149                                            No LLMs  2019
# 150                                            No LLMs  2017
# 151                                            No LLMs  2018
# 152                                            No LLMs  2019
# 153  No biomedical focus, but Agricultural applicat...  2020
# 154                                            No LLMs  2020
# 155                                            No LLMs  2023
# 156                                            No LLMs  2020
# 157                                            No LLMs  2019
# 158                                            No LLMs  2017
# 159                                            No LLMs  2017
# 160                                            No LLMs  2019
# 161                                            No LLMs  2019
# 162                                            No LLMs  2018
# 163                                            No LLMs  2021
# 164                                            No LLMs  2018
# 165                      Protocol, not the actual work  2021
# 166                                            No LLMs  2017
# 167                                            No LLMs  2017
# 168                                            No LLMs  2020
# 169                                            No LLMs  2021
# 170                                            No LLMs  2018
# 171                                            No LLMs  2017
# 172                                            No LLMs  2020
# 173                                            No LLMs  2018
# 174                                            No LLMs  2019
# 175                                            No LLMs  2022
# 176                                            No LLMs  2019
# 177                                            No LLMs  2019
# 178                                        Not English  2022
# 179                                            No LLMs  2022
# 180                                            No LLMs  2020
# 181                                            No LLMs  2020
# 182                                            No LLMs  2019
# 183                                            No LLMs  2018
# 184                                            No LLMs  2018
# 185                                            No LLMs  2022
# 186                                            No LLMs  2022
# 187                                            No LLMs  2020
# 188                                            No LLMs  2019
# 189                                            No LLMs  2019
# 190                                            No LLMs  2018
# 191                                            No LLMs  2017
# 192                           Not English, but Spanish  2021
# 193                                            No LLMs  2020
# 194                                            No LLMs  2019
# 195                                            No LLMs  2019
# 196                        Focus on dataset, not model  2022
# 197                                            No LLMs  2020
# 198                                            No LLMs  2018
# 199                                            No LLMs  2020
# 200                                            No LLMs  2017
# 201                                No biomedical focus  2023
# 202                                             Survey  2023
# 203                                            No LLMs  2017
# 204                                            No LLMs  2021
# 205                                            No LLMs  2020
# 206                                            No LLMs  2020
# 207                                            No LLMs  2017
# 208                                            No LLMs  2018
# 209                                            No LLMs  2020
# 210                                            No LLMs  2020
# 211                                            No LLMs  2018
# 212                                            No LLMs  2018
# 213                                            No LLMs  2017
# 214                      Focus on platform, not models  2021
# 215                                            No LLMs  2018
# 216                                            No LLMs  2023
# 217                                            No LLMs  2018
# 218                                            No LLMs  2023
# 219                                            No LLMs  2022
# 220                                          no access  2019
# 221                                            No LLMs  2021
# 222                                            No LLMs  2019
# 223                                            No LLMs  2019
# 224                                            No LLMs  2020
# 225                                            No LLMs  2023
# 226  No LLMs (although benchmaerked with a BERT sys...  2022
# 227                                            No LLMs  2019
# 228                                            No LLMs  2023
# 229                                            No LLMs  2022
# 230                                            No LLMs  2022
# 231                                            No LLMs  2020
# 232                                            No LLMs  2018
# 233                               Not focused on model  2018
# 234                                            No LLMs  2021
# 235                                          no access  2021
# 236                                            No LLMs  2018
# 237                                            No LLMs  2019
# 238                                            No LLMs  2017
# 239                                            No LLMs  2021
# 240                                            No LLMs  2020
# 241                                            No LLMs  2021
# 242                                            No LLMs  2021
# 243                                            No LLMs  2022
# 244                                            No LLMs  2018
# 245                                            No LLMs  2020
# 246                                            No LLMs  2019
# 247                                            No LLMs  2021
# 248                                            No LLMs  2020
# 249                                            No LLMs  2022
# 250                                            No LLMs  2018
# 251                                            No LLMs  2020
# 252                                            No LLMs  2022
# 253                                            No LLMs  2021
# 254                                            No LLMs  2022
# 255                                            No LLMs  2017
# 256                                            No LLMs  2021
# 257                               Not focused on model  2020
# 258                                            No LLMs  2018
# 259                                            No LLMs  2017
# 260                                            No LLMs  2017
# 261                                            No LLMs  2020
# 262                                            No LLMs  2018
# 263                      Protocol, not the actual work  2018
# 264  No LLMs (although benchmaerked with a BERT sys...  2022
# 265                                            No LLMs  2018
# 266                               Not focused on model  2021
# 267                                            No LLMs  2022
# 268  No LLMs (although benchmaerked with a BERT sys...  2021
# 269                                            No LLMs  2020
# 270                                            No LLMs  2021
# 271                               Not focused on model  2021
# 272                      Protocol, not the actual work  2020
# 273          Focus on chemical molecules, not on text   2017
# 274                                            No LLMs  2022
# 275                                            No LLMs  2019
# 276                                            No LLMs  2021
# 277                                            No LLMs  2019
# 278                                            No LLMs  2019
# 279  No LLMs (although benchmaerked with a BERT sys...  2021
# 280                                            No LLMs  2020
# 281                                            No LLMs  2017
# 282                                            No LLMs  2019
# 283                                            No LLMs  2022
# 284                                            No LLMs  2019
# 285                                          DUPLICATE  2022
# 286                                            No LLMs  2022
# 287                                            No LLMs  2019
# 288                                            No LLMs  2020
# 289                                            No LLMs  2019
# 290                               No biomedical focus.  2021
# 291                                            No LLMs  2018
# 292                                            No LLMs  2019
# 293                                            No LLMs  2021
# 294  Not focused on model, but new dataset developm...  2019
# 295                                            No LLMs  2020
# 296                                            No LLMs  2020
# 297                                            No LLMs  2018
# 298                                            No LLMs  2018
# 299                                            No LLMs  2019
# 300                                            No LLMs  2022
# 301                      Focus on platform, not models  2017
# 302  No LLMs (although benchmaerked with a BERT sys...  2022
# 303                                             Review  2021
# 304                                             Review  2021
# 305                                            No LLMs  2022
# 306                                            No LLMs  2019
# 307                                            No LLMs  2017
# 308                                            No LLMs  2017
# 309                                            No LLMs  2019
# 310                                            No LLMs  2017
# 311  Not focused on model, but presentation of a da...  2022
# 312                                            No LLMs  2017
# 313  No LLMs (although benchmaerked with a BERT sys...  2022
# 314                                            No LLMs  2019
# 315                                            No LLMs  2020
# 316                                            No LLMs  2019
# 317                                            No LLMs  2020
# 318                                            No LLMs  2023
# 319                                            No LLMs  2020
# 320                           Not English, but Spanish  2021
# 321                                            No LLMs  2018
# 322  No LLMs (although benchmaerked with a BERT sys...  2022
# 323                                            No LLMs  2018
# 324                               Not focused on model  2020
# 325                               Not focused on model  2020
# 326                                            No LLMs  2019
# 327                                            No LLMs  2022
# 328                               Not focused on model  2021
# 329                                            No LLMs  2022
# 330                                            No LLMs  2021
# 331                                            No LLMs  2018
# 332             No biomedical focus, but food science.  2022
# 333                                            No LLMs  2019
# 334                                            No LLMs  2017
# 335                                            No LLMs  2022
# 336                               Not focused on model  2018
# 337                                            No LLMs  2022
# 338                                            No LLMs  2022
# 339                                            No LLMs  2020
# 340                                            No LLMs  2019
# 341                                            No LLMs  2020
# 342                                            No LLMs  2017
# 343                                            No LLMs  2017
# 344                                            No LLMs  2017
# 345                                            No LLMs  2018
# 346                                            No LLMs  2019
# 347                                            No LLMs  2019
# 348                                            No LLMs  2018
# 349                                            No LLMs  2020
# 350                                            No LLMs  2020
# 351                                            No LLMs  2017
# 352                                            No LLMs  2019
# 353                                            No LLMs  2023
# 354                                            No LLMs  2021
# 355                                            No LLMs  2020
# 356  Not focused on model, but new dataset developm...  2023
# 357                               No biomedical focus.  2020
# 358                                            No LLMs  2020
# 359  Not focused on model, but new dataset developm...  2020
# 360                                            No LLMs  2018
# 361                                        Not English  2021
# 362                               Not focused on model  2018
# 363                               No biomedical focus.  2019
# 364                                            No LLMs  2019
# 365                               No biomedical focus.  2020
# 366                                            No LLMs  2019
# 367                                            No LLMs  2018
# 368                               No biomedical focus.  2022
# 369                                            No LLMs  2020
# 370                               No biomedical focus.  2019
# 371                                            No LLMs  2021
# 372                                            No LLMs  2018
# 373                               Not focused on model  2021
# 374                                            No LLMs  2017
# 375                                            No LLMs  2017
# 376                                            No LLMs  2019
# 377                                            No LLMs  2021
# 378                                            No LLMs  2019
# 379                                            No LLMs  2018
# 380                                            No LLMs  2019
# 381                                            No LLMs  2022
# 382                                        Not English  2020
# 383                                        Not English  2021
# 384                                            No LLMs  2021
# 385                                            No LLMs  2021
# 386                                            No LLMs  2017
# 387                                            No LLMs  2019
# 388                                            No LLMs  2018
# 389                                            No LLMs  2018
# 390                                            No LLMs  2019
# 391                                            No LLMs  2020
# 392                                            No LLMs  2018
# 393                                            No LLMs  2018
# 394                                            No LLMs  2017
# 395                                            No LLMs  2018
# 396                                            No LLMs  2018
# 397                                            No LLMs  2017
# 398                                            No LLMs  2018
# 399                                            No LLMs  2020
# 400                                            No LLMs  2022
# 401                                            No LLMs  2020
# 402                                            No LLMs  2019
# 403                                            No LLMs  2021
# 404                                            No LLMs  2020
# 405                                            No LLMs  2017
# 406                                            No LLMs  2022
# 407                                            No LLMs  2021
# 408                                            No LLMs  2020
# 409  No biomedical focus, but questionnaires in psy...  2020
# 410  Focus on strategy for dataset development, not...  2020
# 411                          Not English, but Chinese.  2020
# 412                       Focus on image, not on text.  2020
# 413                                            No LLMs  2022
# 414                                No biomedical focus  2023
# 415                          Not English, but Chinese.  2020
# 416                                            No LLMs  2022
# 417                                            No LLMs  2020
# 418                                            No LLMs  2021
# 419                               No biomedical focus.  2023
# 420                          Not English, but Chinese.  2022
# 421  Not focused on model, but on dveloping new eva...  2023
# 422                               No biomedical focus.  2020
# 423                               No biomedical focus.  2020
# 424                  Not focused on model development.  2023
# 425                       Focus on image, not on text.  2023
# 426                                            No LLMs  2019
# 427                       Focus on image, not on text.  2021
# 428                                            No LLMs  2023
# 429                                            No LLMs  2022
# 430                           Focus on questionnaires.  2021
# 431                                            No LLMs  2021
# 432                                            No LLMs  2020
# 433                                No biomedical focus  2023
# 434                                            No LLMs  2021
# 435                       Focus on image, not on text.  2020
# 436                                            No LLMs  2020
# 437                       Focus on image, not on text.  2022
# 438                                        Not English  2023
# 439                                            No LLMs  2023
# 440                               No biomedical domain  2023
# 441                                            No LLMs  2023
# 442                               No biomedical domain  2023
# 443                               No biomedical domain  2023
# 444                               No biomedical domain  2023
# 445                               No biomedical domain  2023
# 446                                            No LLMs  2023
# 447                               No biomedical domain  2023
# 448                               No biomedical domain  2023
# 449                               No biomedical domain  2023
# 450                               No biomedical domain  2023
# 451                                        Not English  2023
# 452                              No LLMs, Review Paper  2023
# 453                               No biomedical domain  2023
# 454                                          DUPLICATE  2024
# 455                               No biomedical domain  2023
# 456                               No biomedical domain  2023
# 457                                        Not English  2023
# 458                               No biomedical domain  2023
# 459                                            No LLMs  2023
# 460                               No biomedical domain  2023
# 461                                       Review Paper  2023
# 462                               No biomedical domain  2023
# 463                               No biomedical domain  2023
# 464                                       Review Paper  2023
# 465                                            No LLMs  2023
# 466                                       Review Paper  2023
# 467                               No biomedical domain  2023
# 468                                          DUPLICATE  2023
# 469                                       Review Paper  2023
# 470                                       Review Paper  2023
# 471                                       Review Paper  2023
# 472                                        Not English  2023
# 473                                       Review Paper  2023
# 474                                       Review Paper  2023
# 475                                       Review Paper  2023
# 476                                           Not text  2023
# 477                                       Review Paper  2023
# 478                                           Not text  2023
# 479                               No biomedical domain  2023
# 480                               No biomedical domain  2023
# 481                                          DUPLICATE  2023
# 482                                       Review Paper  2023
# 483                                            No LLMs  2023
# 484                                        Not English  2023
# 485                                          DUPLICATE  2022
# 486                                          DUPLICATE  2023
# 487                                       Review Paper  2023
# 488                                       Review Paper  2023
# 489                                       Review Paper  2023
# 490                                       Review Paper  2023
# 491                                       Review Paper  2023
# 492                                       Review Paper  2023
# 493                                       Review Paper  2023
# 494                                       Review Paper  2023
# 495                                       Review Paper  2023
# 496                                       Review Paper  2023
# 497                                                NaN  2023
# 498                                                NaN  2023
# 499                                       Review Paper  2023
# 500                                       Review Paper  2023
# 501                                       Review Paper  2023
# 502                                    Includes vision  2023
# 503                                       Review Paper  2023
# 504                                       Review Paper  2023
# 505                                       Review Paper  2023
# 506                                       Review Paper  2023
# 507                                       Review Paper  2023
# 508                               No biomedical domain  2023
# 509                                            No LLMs  2023
# 510                   DUPLICATE with Simona ACL papers  2023
# 511                                                NaN  2023
# 512                                            No LLMs  2023
# 513                                          DUPLICATE  2023
# 514                                       Review Paper  2023
# 515                   DUPLICATE with Simona ACL papers  2023
# 516                                                NaN  2023
#
#        publication_type
# 0    biomedical_journal
# 1    biomedical_journal
# 2    biomedical_journal
# 3    biomedical_journal
# 4    biomedical_journal
# 5    biomedical_journal
# 6    biomedical_journal
# 7    biomedical_journal
# 8    biomedical_journal
# 9    biomedical_journal
# 10   biomedical_journal
# 11   biomedical_journal
# 12   biomedical_journal
# 13   biomedical_journal
# 14   biomedical_journal
# 15   biomedical_journal
# 16   biomedical_journal
# 17   biomedical_journal
# 18   biomedical_journal
# 19   biomedical_journal
# 20   biomedical_journal
# 21   biomedical_journal
# 22   biomedical_journal
# 23   biomedical_journal
# 24   biomedical_journal
# 25   biomedical_journal
# 26   biomedical_journal
# 27   biomedical_journal
# 28   biomedical_journal
# 29   biomedical_journal
# 30   biomedical_journal
# 31   biomedical_journal
# 32   biomedical_journal
# 33   biomedical_journal
# 34   biomedical_journal
# 35   biomedical_journal
# 36   biomedical_journal
# 37   biomedical_journal
# 38   biomedical_journal
# 39   biomedical_journal
# 40   biomedical_journal
# 41   biomedical_journal
# 42   biomedical_journal
# 43   biomedical_journal
# 44   biomedical_journal
# 45   biomedical_journal
# 46   biomedical_journal
# 47   biomedical_journal
# 48   biomedical_journal
# 49   biomedical_journal
# 50   biomedical_journal
# 51   biomedical_journal
# 52   biomedical_journal
# 53   biomedical_journal
# 54   biomedical_journal
# 55   biomedical_journal
# 56   biomedical_journal
# 57   biomedical_journal
# 58   biomedical_journal
# 59   biomedical_journal
# 60   biomedical_journal
# 61   biomedical_journal
# 62   biomedical_journal
# 63   biomedical_journal
# 64   biomedical_journal
# 65   biomedical_journal
# 66   biomedical_journal
# 67   biomedical_journal
# 68   biomedical_journal
# 69   biomedical_journal
# 70   biomedical_journal
# 71   biomedical_journal
# 72   biomedical_journal
# 73   biomedical_journal
# 74   biomedical_journal
# 75   biomedical_journal
# 76   biomedical_journal
# 77   biomedical_journal
# 78   biomedical_journal
# 79   biomedical_journal
# 80   biomedical_journal
# 81   biomedical_journal
# 82   biomedical_journal
# 83   biomedical_journal
# 84   biomedical_journal
# 85   biomedical_journal
# 86   biomedical_journal
# 87   biomedical_journal
# 88   biomedical_journal
# 89   biomedical_journal
# 90   biomedical_journal
# 91   biomedical_journal
# 92   biomedical_journal
# 93   biomedical_journal
# 94   biomedical_journal
# 95   biomedical_journal
# 96   biomedical_journal
# 97   biomedical_journal
# 98   biomedical_journal
# 99   biomedical_journal
# 100  biomedical_journal
# 101  biomedical_journal
# 102  biomedical_journal
# 103  biomedical_journal
# 104  biomedical_journal
# 105  biomedical_journal
# 106  biomedical_journal
# 107  biomedical_journal
# 108  biomedical_journal
# 109  biomedical_journal
# 110  biomedical_journal
# 111  biomedical_journal
# 112  biomedical_journal
# 113  biomedical_journal
# 114  biomedical_journal
# 115  biomedical_journal
# 116  biomedical_journal
# 117  biomedical_journal
# 118  biomedical_journal
# 119  biomedical_journal
# 120  biomedical_journal
# 121  biomedical_journal
# 122  biomedical_journal
# 123  biomedical_journal
# 124  biomedical_journal
# 125  biomedical_journal
# 126  biomedical_journal
# 127  biomedical_journal
# 128  biomedical_journal
# 129  biomedical_journal
# 130  biomedical_journal
# 131  biomedical_journal
# 132  biomedical_journal
# 133  biomedical_journal
# 134  biomedical_journal
# 135  biomedical_journal
# 136  biomedical_journal
# 137  biomedical_journal
# 138  biomedical_journal
# 139  biomedical_journal
# 140  biomedical_journal
# 141  biomedical_journal
# 142  biomedical_journal
# 143  biomedical_journal
# 144  biomedical_journal
# 145  biomedical_journal
# 146  biomedical_journal
# 147  biomedical_journal
# 148  biomedical_journal
# 149  biomedical_journal
# 150  biomedical_journal
# 151  biomedical_journal
# 152  biomedical_journal
# 153  biomedical_journal
# 154  biomedical_journal
# 155  biomedical_journal
# 156  biomedical_journal
# 157  biomedical_journal
# 158  biomedical_journal
# 159  biomedical_journal
# 160  biomedical_journal
# 161  biomedical_journal
# 162  biomedical_journal
# 163  biomedical_journal
# 164  biomedical_journal
# 165  biomedical_journal
# 166  biomedical_journal
# 167  biomedical_journal
# 168  biomedical_journal
# 169  biomedical_journal
# 170  biomedical_journal
# 171  biomedical_journal
# 172  biomedical_journal
# 173  biomedical_journal
# 174  biomedical_journal
# 175  biomedical_journal
# 176  biomedical_journal
# 177  biomedical_journal
# 178  biomedical_journal
# 179  biomedical_journal
# 180  biomedical_journal
# 181  biomedical_journal
# 182  biomedical_journal
# 183  biomedical_journal
# 184  biomedical_journal
# 185  biomedical_journal
# 186  biomedical_journal
# 187  biomedical_journal
# 188  biomedical_journal
# 189  biomedical_journal
# 190  biomedical_journal
# 191  biomedical_journal
# 192  biomedical_journal
# 193  biomedical_journal
# 194  biomedical_journal
# 195  biomedical_journal
# 196  biomedical_journal
# 197  biomedical_journal
# 198  biomedical_journal
# 199  biomedical_journal
# 200  biomedical_journal
# 201  biomedical_journal
# 202  biomedical_journal
# 203  biomedical_journal
# 204  biomedical_journal
# 205  biomedical_journal
# 206  biomedical_journal
# 207  biomedical_journal
# 208  biomedical_journal
# 209  biomedical_journal
# 210  biomedical_journal
# 211  biomedical_journal
# 212  biomedical_journal
# 213  biomedical_journal
# 214  biomedical_journal
# 215  biomedical_journal
# 216  biomedical_journal
# 217  biomedical_journal
# 218  biomedical_journal
# 219  biomedical_journal
# 220  biomedical_journal
# 221  biomedical_journal
# 222  biomedical_journal
# 223  biomedical_journal
# 224  biomedical_journal
# 225  biomedical_journal
# 226  biomedical_journal
# 227  biomedical_journal
# 228  biomedical_journal
# 229  biomedical_journal
# 230  biomedical_journal
# 231  biomedical_journal
# 232  biomedical_journal
# 233  biomedical_journal
# 234  biomedical_journal
# 235  biomedical_journal
# 236  biomedical_journal
# 237  biomedical_journal
# 238  biomedical_journal
# 239  biomedical_journal
# 240  biomedical_journal
# 241  biomedical_journal
# 242  biomedical_journal
# 243  biomedical_journal
# 244  biomedical_journal
# 245  biomedical_journal
# 246  biomedical_journal
# 247  biomedical_journal
# 248  biomedical_journal
# 249  biomedical_journal
# 250  biomedical_journal
# 251  biomedical_journal
# 252  biomedical_journal
# 253  biomedical_journal
# 254  biomedical_journal
# 255  biomedical_journal
# 256  biomedical_journal
# 257  biomedical_journal
# 258  biomedical_journal
# 259  biomedical_journal
# 260  biomedical_journal
# 261  biomedical_journal
# 262  biomedical_journal
# 263  biomedical_journal
# 264  biomedical_journal
# 265  biomedical_journal
# 266  biomedical_journal
# 267  biomedical_journal
# 268  biomedical_journal
# 269  biomedical_journal
# 270  biomedical_journal
# 271  biomedical_journal
# 272  biomedical_journal
# 273  biomedical_journal
# 274  biomedical_journal
# 275  biomedical_journal
# 276  biomedical_journal
# 277  biomedical_journal
# 278  biomedical_journal
# 279  biomedical_journal
# 280  biomedical_journal
# 281  biomedical_journal
# 282  biomedical_journal
# 283  biomedical_journal
# 284  biomedical_journal
# 285  biomedical_journal
# 286  biomedical_journal
# 287  biomedical_journal
# 288  biomedical_journal
# 289  biomedical_journal
# 290  biomedical_journal
# 291  biomedical_journal
# 292  biomedical_journal
# 293  biomedical_journal
# 294  biomedical_journal
# 295  biomedical_journal
# 296  biomedical_journal
# 297  biomedical_journal
# 298  biomedical_journal
# 299  biomedical_journal
# 300  biomedical_journal
# 301  biomedical_journal
# 302  biomedical_journal
# 303  biomedical_journal
# 304  biomedical_journal
# 305  biomedical_journal
# 306  biomedical_journal
# 307  biomedical_journal
# 308  biomedical_journal
# 309  biomedical_journal
# 310  biomedical_journal
# 311  biomedical_journal
# 312  biomedical_journal
# 313  biomedical_journal
# 314  biomedical_journal
# 315  biomedical_journal
# 316  biomedical_journal
# 317  biomedical_journal
# 318  biomedical_journal
# 319  biomedical_journal
# 320  biomedical_journal
# 321  biomedical_journal
# 322  biomedical_journal
# 323  biomedical_journal
# 324  biomedical_journal
# 325  biomedical_journal
# 326  biomedical_journal
# 327  biomedical_journal
# 328  biomedical_journal
# 329  biomedical_journal
# 330  biomedical_journal
# 331  biomedical_journal
# 332  biomedical_journal
# 333  biomedical_journal
# 334  biomedical_journal
# 335  biomedical_journal
# 336  biomedical_journal
# 337  biomedical_journal
# 338  biomedical_journal
# 339  biomedical_journal
# 340  biomedical_journal
# 341  biomedical_journal
# 342  biomedical_journal
# 343  biomedical_journal
# 344  biomedical_journal
# 345  biomedical_journal
# 346  biomedical_journal
# 347  biomedical_journal
# 348  biomedical_journal
# 349  biomedical_journal
# 350  biomedical_journal
# 351  biomedical_journal
# 352  biomedical_journal
# 353  biomedical_journal
# 354  biomedical_journal
# 355  biomedical_journal
# 356  biomedical_journal
# 357  biomedical_journal
# 358  biomedical_journal
# 359  biomedical_journal
# 360  biomedical_journal
# 361  biomedical_journal
# 362  biomedical_journal
# 363  biomedical_journal
# 364  biomedical_journal
# 365  biomedical_journal
# 366  biomedical_journal
# 367  biomedical_journal
# 368  biomedical_journal
# 369  biomedical_journal
# 370  biomedical_journal
# 371  biomedical_journal
# 372  biomedical_journal
# 373  biomedical_journal
# 374  biomedical_journal
# 375  biomedical_journal
# 376  biomedical_journal
# 377  biomedical_journal
# 378  biomedical_journal
# 379  biomedical_journal
# 380  biomedical_journal
# 381  biomedical_journal
# 382  biomedical_journal
# 383  biomedical_journal
# 384  biomedical_journal
# 385  biomedical_journal
# 386  biomedical_journal
# 387  biomedical_journal
# 388  biomedical_journal
# 389  biomedical_journal
# 390  biomedical_journal
# 391  biomedical_journal
# 392  biomedical_journal
# 393  biomedical_journal
# 394  biomedical_journal
# 395  biomedical_journal
# 396  biomedical_journal
# 397  biomedical_journal
# 398  biomedical_journal
# 399  biomedical_journal
# 400  biomedical_journal
# 401  biomedical_journal
# 402  biomedical_journal
# 403  biomedical_journal
# 404  biomedical_journal
# 405  biomedical_journal
# 406           nlp_venue
# 407           nlp_venue
# 408           nlp_venue
# 409           nlp_venue
# 410           nlp_venue
# 411           nlp_venue
# 412           nlp_venue
# 413           nlp_venue
# 414           nlp_venue
# 415           nlp_venue
# 416           nlp_venue
# 417           nlp_venue
# 418           nlp_venue
# 419           nlp_venue
# 420           nlp_venue
# 421           nlp_venue
# 422           nlp_venue
# 423           nlp_venue
# 424           nlp_venue
# 425           nlp_venue
# 426           nlp_venue
# 427           nlp_venue
# 428           nlp_venue
# 429           nlp_venue
# 430           nlp_venue
# 431           nlp_venue
# 432           nlp_venue
# 433           nlp_venue
# 434           nlp_venue
# 435           nlp_venue
# 436           nlp_venue
# 437           nlp_venue
# 438  biomedical_journal
# 439  biomedical_journal
# 440           nlp_venue
# 441           nlp_venue
# 442           nlp_venue
# 443           nlp_venue
# 444           nlp_venue
# 445           nlp_venue
# 446           nlp_venue
# 447           nlp_venue
# 448           nlp_venue
# 449           nlp_venue
# 450           nlp_venue
# 451  biomedical_journal
# 452  biomedical_journal
# 453           nlp_venue
# 454  biomedical_journal
# 455           nlp_venue
# 456           nlp_venue
# 457  biomedical_journal
# 458           nlp_venue
# 459  biomedical_journal
# 460           nlp_venue
# 461  biomedical_journal
# 462           nlp_venue
# 463           nlp_venue
# 464  biomedical_journal
# 465           nlp_venue
# 466  biomedical_journal
# 467           nlp_venue
# 468  biomedical_journal
# 469  biomedical_journal
# 470  biomedical_journal
# 471  biomedical_journal
# 472  biomedical_journal
# 473  biomedical_journal
# 474  biomedical_journal
# 475  biomedical_journal
# 476  biomedical_journal
# 477  biomedical_journal
# 478  biomedical_journal
# 479           nlp_venue
# 480  biomedical_journal
# 481  biomedical_journal
# 482  biomedical_journal
# 483  biomedical_journal
# 484  biomedical_journal
# 485           nlp_venue
# 486           nlp_venue
# 487  biomedical_journal
# 488  biomedical_journal
# 489  biomedical_journal
# 490  biomedical_journal
# 491  biomedical_journal
# 492  biomedical_journal
# 493  biomedical_journal
# 494  biomedical_journal
# 495  biomedical_journal
# 496  biomedical_journal
# 497  biomedical_journal
# 498  biomedical_journal
# 499  biomedical_journal
# 500  biomedical_journal
# 501  biomedical_journal
# 502  biomedical_journal
# 503  biomedical_journal
# 504  biomedical_journal
# 505  biomedical_journal
# 506  biomedical_journal
# 507  biomedical_journal
# 508           nlp_venue
# 509  biomedical_journal
# 510           nlp_venue
# 511  biomedical_journal
# 512  biomedical_journal
# 513  biomedical_journal
# 514  biomedical_journal
# 515           nlp_venue
# 516  biomedical_journal

# %%
df_excluded["Reason for exclusion"] = df_excluded["Reason for exclusion"].str.replace(
    r'^No biomedical focus.*$', 'Different focus', regex=True)
df_excluded["Reason for exclusion"] = df_excluded["Reason for exclusion"].str.replace(
    r'^Focus on.*$', 'Different focus', regex=True)
df_excluded["Reason for exclusion"] = df_excluded["Reason for exclusion"].str.replace(
    r'^Not focused on model.*$', 'Different focus', regex=True)
df_excluded["Reason for exclusion"] = df_excluded["Reason for exclusion"].str.replace(
    r'^Not English.*$', 'Not English', regex=True)

df_excluded.groupby(['Reason for exclusion']).size().sort_values()
# Out:
# Reason for exclusion
# Includes vision                                         1
# No LLMs, Review Paper                                   1
# Survey                                                  1
# WITHDRAWN due to integrity concerns                     1
# DUPLICATE with Simona ACL papers                        2
# Not text                                                2
# no access                                               2
# Protocol, not the actual work                           3
# No LLMs (although benchmaerked with a BERT system)      8
# DUPLICATE                                               9
# Review                                                 12
# Not English                                            15
# No biomedical domain                                   20
# Review Paper                                           30
# Different focus                                        43
# No LLMs                                               363
# dtype: int64

# %% [markdown]
# ## Overview papers metadata

# %%
df = pd.concat([df_included, df_acl_included, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)
#df = df[df['year'] != 2024]

df.head(3)
# Out:
#                                               author  \
# 0  Abdelkader, W. and Navarro, T. and Parrish, R....
# 1  Alachram, H. and Chereda, H. and Beisbarth, T....
# 2          Ambalavanan, A. K. and Devarakonda, M. V.
#
#                             doi                                 Link to paper  \
# 0                 10.2196/29398                 https://doi.org/10.2196/29398
# 1  10.1371/journal.pone.0258623  https://doi.org/10.1371/journal.pone.0258623
# 2     10.1016/j.jbi.2020.103578     https://doi.org/10.1016/j.jbi.2020.103578
#
#                                                title  \
# 0  A Deep Learning Approach to Refine the Identif...
# 1  Text mining-based word representations for bio...
# 2  Using the contextual language model BERT for m...
#
#                              journal  year Extracted by Included  \
# 0            JMIR Research Protocols  2021          BVI      1.0
# 1     PLoS ONE [Electronic Resource]  2021          BVI      1.0
# 2  Journal of Biomedical Informatics  2020          BVI      1.0
#
#   Reason for exclusion      Target application  \
# 0                  NaN     Text Classification
# 1                  NaN  Information Extraction
# 2                  NaN     Text Classification
#
#                         Domain of automated approach  \
# 0  Literature Screening/ Methodological Quality: ...
# 1  General biomedical text mining/ Genomics: Extr...
# 2  Literature Screening/ Combination of Selection...
#
#                               Target database                       Data type  \
# 0                                      PubMed                       Abstracts
# 1  PubMed, Gene Expression Omnibus repository  Abstracts, Functional Genomics
# 2                                     MEDLINE                       Abstracts
#
#   Data filter applied        Hosted Application for End-users  \
# 0                 NaN                                      no
# 1                 NaN  yes: https://ebiomecon.genexplain.com/
# 2                 NaN                                      no
#
#   Alternative Approach                            LLM Model  \
# 0                  NaN  BERT, BioBERT, BlueBERT, PubMedBERT
# 1                  NaN                              BioBERT
# 2                  NaN                              SciBERT
#
#                       Models/Resources used with LLM  \
# 0                                                NaN
# 1  Graph-CNN based on Human Protein Reference Dat...
# 2  feed forward network (FFN) as the text classif...
#
#   System Architecture/ Flow Programming language Library/Framework  \
# 0         BERT architecture               Python       HuggingFace
# 1         BERT architecture               Python           PyTorch
# 2         BERT architecture               Python           PyTorch
#
#   Library/Framework Harmonized  \
# 0                  HuggingFace
# 1                      PyTorch
# 2                      PyTorch
#
#                         Reported performance metrics  \
# 0  F1, recall, specificity, accuracy, precision, ...
# 1            AUC, Accuracy, F1, similarity threshold
# 2                              Precision, Recall, F1
#
#              Reported performance metrics Harmonized Source code availability  \
# 0  F1-Score, Recall, Specificity, Accuracy, Preci...                       no
# 1      AUC, Accuracy, F1-Score, Similarity Threshold                       no
# 2                        Precision, Recall, F1-Score                      yes
#
#                                   Source code link Data used availability  \
# 0                                              NaN              partially
# 1                                              NaN                    NaN
# 2  https://github.com/md-labs/Clinical_Hedges_BERT                    yes
#
#                                Preprocessing applied  \
# 0                                                NaN
# 1  for word2vec training: The first phase applied...
# 2                                                NaN
#
#             Pretraining corpus origin       Pretraining corpus size  \
# 0               depends on BERT model         depends on BERT model
# 1  for word2vec PubMed FTP repository  16,558,093 article abstracts
# 2                         see SciBERT                   see SciBERT
#
#                  Fine-tuning corpus data/task  \
# 0                Custom-annotated PubMed data
# 1  HPRD PPI; Custom-annotated from GEO series
# 2                     Clinical Hedges Dataset
#
#                                      New annotations Annotations type  \
# 0  Article type: original study, systematic revie...              NaN
# 1  genomic predictors of response and survival in...              NaN
# 2                                                NaN              NaN
#
#   New dataset developed                            Fine-tuning corpus size  \
# 0                   yes  Total 2012–2020, N=160 712 (positive 29810 and...
# 1                   yes  10 microarray datasets measured on Affymetrix ...
# 2                    no                                     50,590 entries
#
#   Number of tasks/datasets for performance evaluation  \
# 0                                                1.0
# 1  4 (lung cancer, liver cancer, prostate cancer,...
# 2                                                NaN
#
#    Hardware used for training/validation/fine-tuning Hardware type  \
# 0  8 Intel Silver 4216 Cascade Lake CPU cores, an...      GPU, CPU
# 1                                                NaN           NaN
# 2                                                GPU           GPU
#
#   Internal validity 1 Internal validity 2 External validity  \
# 0                 Yes                  No                No
# 1                 Yes                  No               yes
# 2                 Yes                  No               yes
#
#           External validity.1  \
# 0                         NaN
# 1                    word2vec
# 2  CNN, Customized text query
#
#                                              Comment  Unnamed: 43  \
# 0                                          Protocol!          NaN
# 1                                                NaN          NaN
# 2  Clinical Hedges dataset could be relevant for ...          NaN
#
#                                                  url  \
# 0  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 1  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 2  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
#
#                           label  type  \
# 0  Abdelkader_2021_JMIRReseProt  JOUR
# 1    Alachram_2021_PLoONE.ElRes  JOUR
# 2     Ambalavanan_2020_JoofBiIn  JOUR
#
#                                             abstract  \
# 0  BACKGROUND: A barrier to practicing evidence-b...
# 1  Biomedical and life science literature is an e...
# 2  BACKGROUND: Finding specific scientific articl...
#
#                                              address   accession  Link issue  \
# 0  Abdelkader, Wael. Health Information Research ...  34847061.0   NaN  11.0
# 1  Alachram, Halima. Department of Medical Bioinf...  34653224.0   NaN  10.0
# 2  Ambalavanan, Ashwin Karthik. Arizona State Uni...  33059047.0   NaN   NaN
#
#                                             keywords language       issn  \
# 0                                                NaN  English  1929-0748
# 1  Algorithms and *Breast Neoplasms/ge [Genetics]...  English  1932-6203
# 2  Information Storage and Retrieval and Medline ...  English  1532-0480
#
#       pages volume                   DA       DB                 DP     ID  \
# 0    e29398   10.0  2023-11-29 00:00:00  MEDLINE  Ovid Technologies   15.0
# 1  e0258623   16.0                  NaN  MEDLINE  Ovid Technologies  101.0
# 2  103578.0  112.0                 12.0  MEDLINE  Ovid Technologies  182.0
#
#                 j2                                m3  \
# 0  JMIR Res Protoc                               NaN
# 1         PLoS ONE  Research Support, Non-U.S. Gov't
# 2  J Biomed Inform                               NaN
#
#                                                   n1  \
# 0  Abdelkader, Wael Navarro, Tamara Parrish, Rick...
# 1  Alachram, Halima Chereda, Hryhorii Beisbarth, ...
# 2  Ambalavanan, Ashwin Karthik Devarakonda, Murth...
#
#                                                   ST   m1  c5  c2  c1  OP  \
# 0  A Deep Learning Approach to Refine the Identif...  NaN NaN NaN NaN NaN
# 1  Text mining-based word representations for bio...  NaN NaN NaN NaN NaN
# 2  Using the contextual language model BERT for m...  NaN NaN NaN NaN NaN
#
#      publication_type  Unnamed: 40 Data availability  Unnamed: 33
# 0  biomedical_journal          NaN               NaN          NaN
# 1  biomedical_journal          NaN               NaN          NaN
# 2  biomedical_journal          NaN               NaN          NaN

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import pandas as pd

# Assuming df and category_counts are your DataFrames
# You would need to have these DataFrames prepared with the necessary data

# Create a larger figure and subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# First plot
# Group by year and publication type, then count the occurrences
counts = df.groupby(['year', 'publication_type']).size().unstack(fill_value=0)

# Plot the stacked bar chart on the first subplot
bars = counts.plot(kind='bar', stacked=True, color=['skyblue', 'darkgrey'], width=0.8, ax=axes[0], zorder=2)
# Add horizontal grid lines for better readability in the second plot
axes[0].grid(axis='y', linestyle='--', alpha=0.6, zorder=1)

# Add count values as annotations for the first plot
# (This code is adjusted to work with subplots)
for i, year in enumerate(counts.index):
    for pub_type, count in zip(counts.columns, counts.loc[year]):
        if pub_type == "biomedical_journal":
            axes[0].text(i, count/2, str(count), color='black' if count < counts.sum(axis=1).max() else 'black', ha='center', va='center', fontsize=15)
        else:
            total_count = counts.sum(axis=1)[year]
            va = 'center' if count < 10 else 'top' if count >= label_threshold else 'bottom'
            axes[0].text(i, total_count - 4, str(count), color='black' if count < counts.sum(axis=1).max() else 'black', ha='center', va=va, fontsize=15)

# Add total count values on top of each bar for the first plot
for i, total_count in enumerate(counts.sum(axis=1)):
    axes[0].text(i, total_count, str(total_count), color='black', ha='center', va='bottom', fontsize=15)
    

# Customize the first plot
axes[0].set_ylim(0, 100)
axes[0].set_xticks(range(len(counts.index)))
axes[0].set_xticklabels(counts.index, rotation=360, fontsize=15)
axes[0].tick_params(axis='y', labelsize=15)
axes[0].set_xlabel('Year', fontsize=15)
#axes[0].set_ylabel('Number of Articles', fontsize=15)
axes[0].set_title('Number of Included Articles over Time', fontsize=16)
axes[0].legend(['Biomedical Journal', 'NLP Venue'], fontsize=15)

# SECOND PLOT
# Get the top 10 categories and sort in descending order
category_counts = df.groupby(['journal', 'publication_type']).size()
# Modify the value with "\n" added
category_counts = category_counts.rename("count")
category_counts = category_counts.reset_index()
category_counts['journal'] = category_counts['journal'].replace({
    "Database: The Journal of Biological Databases and Curation": "Database: The Journal of\nBiological Databases and Curation",
    "BMC Medical Informatics & Decision Making": "BMC Medical Informatics &\nDecision Making",
    "Association for Computational Linguistics/ Findings": "ACL/ Findings",
    "Association for Computational Linguistics/ BioNLP": "ACL/ BioNLP",
    "Association for Computational Linguistics/ NLP-COVID19": "ACL/ NLP-COVID19",
    "AMIA Summits on Translational Science Proceedings": "AMIA Summits on Translational\nScience Proceedings",
    "AMIA ... Annual Symposium Proceedings/AMIA Symposium":"AMIA Symposium"
})
top_10_categories = category_counts.groupby(['journal', 'publication_type'])['count'].sum().reset_index()
top_10_categories = top_10_categories.sort_values(by='count', ascending=False).head(10)

# Assign colors based on the publication type
colors = ['skyblue' if pub_type == 'biomedical_journal' else 'darkgrey' for pub_type in top_10_categories['publication_type']]
colors = colors[::-1]  # Reverse the order of colors

# Create a horizontal bar chart with different colors for the second subplot
bar_plot = axes[1].barh(top_10_categories['journal'][::-1], top_10_categories['count'][::-1], color=colors, zorder=2)

# Customize the second plot
axes[1].set_xlabel('Count', fontsize=15)
#axes[1].set_ylabel('Venue/ Journal Name', fontsize=15)
axes[1].set_title('Top 10 Number of Included Articles per Source', fontsize=16)
axes[1].tick_params(axis='y', labelsize=15)  # Adjust labelsize as needed
axes[1].tick_params(axis='x', labelsize=15)  # Adjust y-axis label size

# Add count values as annotations for the second plot
for bar, count in zip(bar_plot, top_10_categories['count'][::-1]):
    width = bar.get_width()
    axes[1].text(width, bar.get_y() + bar.get_height() / 2, str(count), va='center', fontsize=15)

# Add horizontal grid lines for better readability in the second plot
axes[1].grid(axis='x', linestyle='--', alpha=0.6, zorder=1)

# Create legend handles for each category and place it outside the plot for the second plot
legend_handles = [Patch(color='skyblue', label='Biomedical Journal'), Patch(color='darkgrey', label='NLP Venue')]
axes[1].legend(handles=legend_handles, fontsize=15, loc='lower right')

plt.tight_layout()
plt.savefig('viz/overview_years_and_journal_count_2024.pdf')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a larger figure
plt.figure(figsize=(10, 8))

# Group by year and publication type, then count the occurrences
counts = df.groupby(['year', 'publication_type']).size().unstack(fill_value=0)

# Plot the stacked bar chart
bars = counts.plot(kind='bar', stacked=True, color=['skyblue', 'darkblue'], width=0.8)

# Define a threshold for label adjustment (e.g., 5)
label_threshold = 5

# Add count values as annotations for each bar
for i, year in enumerate(counts.index):
    for pub_type, count in zip(counts.columns, counts.loc[year]):
        if pub_type == "biomedical_journal":
            plt.text(i, count/2 , str(count), color='white' if count < counts.sum(axis=1).max() else 'black', ha='center', va='center', fontsize=12)
        else:
            total_count = counts.sum(axis=1)[year]
            va = 'center' if count < 10 else 'top' if count >= label_threshold else 'bottom'
            plt.text(i, total_count - 4, str(count), color='white' if count < counts.sum(axis=1).max() else 'black', ha='center', va=va, fontsize=12)

# Add total count values on top of each bar
for i, total_count in enumerate(counts.sum(axis=1)):
    plt.text(i, total_count, str(total_count), color='black', ha='center', va='bottom', fontsize=12)
    
# Set the y-axis limit to ensure it reaches up to 45
plt.ylim(0, 100)

# Customize the plot
plt.xticks(range(len(counts.index)), counts.index, rotation=360, fontsize=14)
plt.tick_params(axis='y', labelsize=14)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Number of Articles', fontsize=15)
#plt.title('Number Articles Over Publication Year', fontsize=16)
plt.legend(['Biomedical Journal', 'NLP Venue'], fontsize=12)

plt.tight_layout()
plt.savefig('viz/years_count_stacked_with_labels_2024.pdf')
# Display the chart
plt.show()

# %%
top_10_categories
# Out:
#                                               journal    publication_type  \
# 1                                       ACL/ Findings           nlp_venue
# 11                                 BMC Bioinformatics  biomedical_journal
# 41                  Journal of Biomedical Informatics  biomedical_journal
# 28                                              EMNLP           nlp_venue
# 18                                     Bioinformatics  biomedical_journal
# 2                                    ACL/ NLP-COVID19           nlp_venue
# 70                                            medRxiv  biomedical_journal
# 69                                            bioRxiv  biomedical_journal
# 12         BMC Medical Informatics &\nDecision Making  biomedical_journal
# 27  Database: The Journal of\nBiological Databases...  biomedical_journal
#
#     count
# 1      32
# 11     16
# 41     15
# 28     13
# 18      9
# 2       7
# 70      5
# 69      5
# 12      5
# 27      4

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Assuming df is your DataFrame

# Count the frequency of each category
category_counts = df.groupby(['journal', 'publication_type']).size()

# Modify the value with "\n" added
category_counts = category_counts.rename("count")
category_counts = category_counts.reset_index()
category_counts['journal'] = category_counts['journal'].replace({
    "Database: The Journal of Biological Databases and Curation": "Database: The Journal of\nBiological Databases and Curation",
    "BMC Medical Informatics & Decision Making": "BMC Medical Informatics &\nDecision Making",
    "Association for Computational Linguistics/ Findings": "ACL/ Findings",
    "Association for Computational Linguistics/ BioNLP": "ACL/ BioNLP",
    "Association for Computational Linguistics/ NLP-COVID19": "ACL/ NLP-COVID19",
    "AMIA Summits on Translational Science Proceedings": "AMIA Summits on Translational\nScience Proceedings",
    "AMIA ... Annual Symposium Proceedings/AMIA Symposium":"AMIA Symposium"
})

# Get the top 10 categories and sort in descending order
top_10_categories = category_counts.groupby(['journal', 'publication_type'])['count'].sum().reset_index()
top_10_categories = top_10_categories.sort_values(by='count', ascending=False).head(10)

# Transpose the DataFrame
top_10_categories = pd.DataFrame(top_10_categories)

# Assign colors based on the publication type
colors = ['skyblue' if pub_type == 'biomedical_journal' else 'darkblue' for pub_type in top_10_categories['publication_type']]

# Reverse the order of colors to correspond with reversed bars
colors = colors[::-1]

# Create a larger figure
plt.figure(figsize=(10, 6))

# Create a horizontal bar chart with different colors for each publication type
bar_plot = plt.barh(top_10_categories['journal'][::-1], top_10_categories['count'][::-1], color=colors, zorder=2)

# Add labels and title
plt.xlabel('Count', fontsize=14)
plt.ylabel('Venue/ Journal Name', fontsize=14)
plt.title('Top 10 Number of Included Articles per Source', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add count values as annotations
for bar, count in zip(bar_plot, top_10_categories['count'][::-1]):
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, str(count), va='center', fontsize=12)

# Add horizontal grid lines for better readability
plt.grid(axis='x', linestyle='--', alpha=0.6, zorder=1)

# Create legend handles for each category and place it outside the plot
legend_handles = [Patch(color='skyblue', label='Biomedical Journal'), Patch(color='darkblue', label='NLP Venue')]
plt.legend(handles=legend_handles, fontsize=12, loc='lower right')

plt.tick_params(axis='y', labelsize=14)
plt.tick_params(axis='x', labelsize=14)

# Save the plot to a local folder
plt.savefig('viz/top_10_journals_count_2024.pdf', bbox_inches='tight')

# Display the chart
plt.show()

# %%
top_10_categories
# Out:
#                                               journal    publication_type  \
# 1                                       ACL/ Findings           nlp_venue
# 11                                 BMC Bioinformatics  biomedical_journal
# 41                  Journal of Biomedical Informatics  biomedical_journal
# 28                                              EMNLP           nlp_venue
# 18                                     Bioinformatics  biomedical_journal
# 2                                    ACL/ NLP-COVID19           nlp_venue
# 70                                            medRxiv  biomedical_journal
# 69                                            bioRxiv  biomedical_journal
# 12         BMC Medical Informatics &\nDecision Making  biomedical_journal
# 27  Database: The Journal of\nBiological Databases...  biomedical_journal
#
#     count
# 1      32
# 11     16
# 41     15
# 28     13
# 18      9
# 2       7
# 70      5
# 69      5
# 12      5
# 27      4

# %% [markdown]
# ## Target DB and Data Type

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)
# Replace semicolons with commas in the 'Target database' column
df['Target database'] = df['Target database'].str.replace(';', ',', regex=False)

df.head(2)
# Out:
#                                               author  \
# 0  Abdelkader, W. and Navarro, T. and Parrish, R....
# 1  Alachram, H. and Chereda, H. and Beisbarth, T....
#
#                             doi                                 Link to paper  \
# 0                 10.2196/29398                 https://doi.org/10.2196/29398
# 1  10.1371/journal.pone.0258623  https://doi.org/10.1371/journal.pone.0258623
#
#                                                title  \
# 0  A Deep Learning Approach to Refine the Identif...
# 1  Text mining-based word representations for bio...
#
#                           journal  year Extracted by Included  \
# 0         JMIR Research Protocols  2021          BVI      1.0
# 1  PLoS ONE [Electronic Resource]  2021          BVI      1.0
#
#   Reason for exclusion      Target application  \
# 0                  NaN     Text Classification
# 1                  NaN  Information Extraction
#
#                         Domain of automated approach  \
# 0  Literature Screening/ Methodological Quality: ...
# 1  General biomedical text mining/ Genomics: Extr...
#
#                               Target database                       Data type  \
# 0                                      PubMed                       Abstracts
# 1  PubMed, Gene Expression Omnibus repository  Abstracts, Functional Genomics
#
#   Data filter applied        Hosted Application for End-users  \
# 0                 NaN                                      no
# 1                 NaN  yes: https://ebiomecon.genexplain.com/
#
#   Alternative Approach                            LLM Model  \
# 0                  NaN  BERT, BioBERT, BlueBERT, PubMedBERT
# 1                  NaN                              BioBERT
#
#                       Models/Resources used with LLM  \
# 0                                                NaN
# 1  Graph-CNN based on Human Protein Reference Dat...
#
#   System Architecture/ Flow Programming language Library/Framework  \
# 0         BERT architecture               Python       HuggingFace
# 1         BERT architecture               Python           PyTorch
#
#   Library/Framework Harmonized  \
# 0                  HuggingFace
# 1                      PyTorch
#
#                         Reported performance metrics  \
# 0  F1, recall, specificity, accuracy, precision, ...
# 1            AUC, Accuracy, F1, similarity threshold
#
#              Reported performance metrics Harmonized Source code availability  \
# 0  F1-Score, Recall, Specificity, Accuracy, Preci...                       no
# 1      AUC, Accuracy, F1-Score, Similarity Threshold                       no
#
#   Source code link Data used availability  \
# 0              NaN              partially
# 1              NaN                    NaN
#
#                                Preprocessing applied  \
# 0                                                NaN
# 1  for word2vec training: The first phase applied...
#
#             Pretraining corpus origin       Pretraining corpus size  \
# 0               depends on BERT model         depends on BERT model
# 1  for word2vec PubMed FTP repository  16,558,093 article abstracts
#
#                  Fine-tuning corpus data/task  \
# 0                Custom-annotated PubMed data
# 1  HPRD PPI; Custom-annotated from GEO series
#
#                                      New annotations Annotations type  \
# 0  Article type: original study, systematic revie...              NaN
# 1  genomic predictors of response and survival in...              NaN
#
#   New dataset developed                            Fine-tuning corpus size  \
# 0                   yes  Total 2012–2020, N=160 712 (positive 29810 and...
# 1                   yes  10 microarray datasets measured on Affymetrix ...
#
#   Number of tasks/datasets for performance evaluation  \
# 0                                                1.0
# 1  4 (lung cancer, liver cancer, prostate cancer,...
#
#    Hardware used for training/validation/fine-tuning Hardware type  \
# 0  8 Intel Silver 4216 Cascade Lake CPU cores, an...      GPU, CPU
# 1                                                NaN           NaN
#
#   Internal validity 1 Internal validity 2 External validity  \
# 0                 Yes                  No                No
# 1                 Yes                  No               yes
#
#   External validity.1    Comment  Unnamed: 43  \
# 0                 NaN  Protocol!          NaN
# 1            word2vec        NaN          NaN
#
#                                                  url  \
# 0  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 1  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
#
#                           label  type  \
# 0  Abdelkader_2021_JMIRReseProt  JOUR
# 1    Alachram_2021_PLoONE.ElRes  JOUR
#
#                                             abstract  \
# 0  BACKGROUND: A barrier to practicing evidence-b...
# 1  Biomedical and life science literature is an e...
#
#                                              address   accession  Link issue  \
# 0  Abdelkader, Wael. Health Information Research ...  34847061.0   NaN  11.0
# 1  Alachram, Halima. Department of Medical Bioinf...  34653224.0   NaN  10.0
#
#                                             keywords language       issn  \
# 0                                                NaN  English  1929-0748
# 1  Algorithms and *Breast Neoplasms/ge [Genetics]...  English  1932-6203
#
#       pages volume                   DA       DB                 DP     ID  \
# 0    e29398   10.0  2023-11-29 00:00:00  MEDLINE  Ovid Technologies   15.0
# 1  e0258623   16.0                  NaN  MEDLINE  Ovid Technologies  101.0
#
#                 j2                                m3  \
# 0  JMIR Res Protoc                               NaN
# 1         PLoS ONE  Research Support, Non-U.S. Gov't
#
#                                                   n1  \
# 0  Abdelkader, Wael Navarro, Tamara Parrish, Rick...
# 1  Alachram, Halima Chereda, Hryhorii Beisbarth, ...
#
#                                                   ST   m1  c5  c2  c1  OP  \
# 0  A Deep Learning Approach to Refine the Identif...  NaN NaN NaN NaN NaN
# 1  Text mining-based word representations for bio...  NaN NaN NaN NaN NaN
#
#      publication_type  Unnamed: 40 Data availability  Unnamed: 33
# 0  biomedical_journal          NaN               NaN          NaN
# 1  biomedical_journal          NaN               NaN          NaN

# %%
df.shape
# Out:
# (196, 74)

# %%
df['Target database'] = df['Target database'].replace("PubMed articles (also financial, lifestyle, recreation, technology, writing and science data)", "PubMed")

# Create a new column to store the flattened data types
df['Flattened_Data_Types'] = df['Target database'].str.split(', ')

# Explode the flattened data types into separate rows
df_exploded = df.explode('Flattened_Data_Types')

# Replace "PubMed articles" with "PubMed"
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("PubMed articles", "PubMed/ MEDLINE")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Pubmed", "PubMed/ MEDLINE")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("PubMed", "PubMed/ MEDLINE")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("MEDLINE", "PubMed/ MEDLINE")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("MedLine", "PubMed/ MEDLINE")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Embase", "PubMed/ MEDLINE")

df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("DrugBank database", "DrugBank")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Drugbank", "EMBASE")

df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("MedRxiv", "medRxiv")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("BioRxiv", "bioRxiv")

df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("EuropePMC", "Europe PMC")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("CINAHL (Ebsco)", "CINAHL")

# Replace "electronic health records" and "Electronic Health Records" with "Clinical texts"
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace(["clinical notes", "electronic health records", "Electronic Health Records"], "Clinical texts")

# Count the frequency of each data type
data_source_counts = df_exploded['Flattened_Data_Types'].value_counts()

# Print the frequency counts
# Adjust the maximum display options to show the full list
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the full list of data type counts
print(data_source_counts)
# Out:
# PubMed/ MEDLINE                                                 131
# Clinical texts                                                   41
# Social media                                                     16
# CORD-19                                                          10
# DrugBank                                                          7
# EMBASE                                                            7
# Wikipedia                                                         6
# Cochrane                                                          4
# bioRxiv                                                           3
# medRxiv                                                           3
# arXiv                                                             3
# Structured Product Labels (SPL)                                   3
# ClinicalTrials.gov                                                3
# Web of Science                                                    3
# MeSH                                                              2
# Mayo Clinic                                                       2
# DailyMed                                                          2
# CINAHL                                                            2
# CTD                                                               2
# Scopus                                                            2
# Europe PMC                                                        2
# SIDER                                                             1
# American Pregnancy Association                                    1
# ClinicalKey (Elsevier)                                            1
# time-series                                                       1
# sensory patient data                                              1
# Social Skills Performance Assessment Tests                        1
# NeuroQuery                                                        1
# Public.Resource.Org                                               1
# ChatGPT                                                           1
# GPT-4                                                             1
# re-written questions from PICO                                    1
# DrugProt                                                          1
# S2ORC                                                             1
# NCBI Entrez Gene                                                  1
# MedlinePlus                                                       1
# UniProt                                                           1
# LiverTox                                                          1
# non-medical sources                                               1
# DrugCentral                                                       1
# Electronic Medicines\nCompendium (EMC)                            1
# NHS Tayside                                                       1
# computer science literature                                       1
# BIOSIS                                                            1
# Scientific claims                                                 1
# Genetic Association Database                                      1
# Chinese DBs                                                       1
# PubMed                                                            1
# Chinese TCM journals                                              1
# Genia Event Task                                                  1
# Semantic Scholar                                                  1
# BooksCorpus                                                       1
# ClinVar                                                           1
# DisGeNET                                                          1
# IEEE                                                              1
# BioMed Central                                                    1
# ProPheno database                                                 1
# iDISK                                                             1
# Biological expression language (BEL) corpora based on PubMed      1
# DailyMed structured drug product labels                           1
# MSKCC precision oncology knowledge base                           1
# NCBI Taxonomy                                                     1
# Freebase                                                          1
# Gene Expression Omnibus repository                                1
# PLoS One                                                          1
# Nature                                                            1
# PubChem                                                           1
# SemMedDB                                                          1
# NIH-FAQs                                                          1
# VAERS                                                             1
# Name: Flattened_Data_Types, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_exploded is your DataFrame with the exploded data types and data_type_counts is the counts
# If not, you can adjust accordingly based on your DataFrame structure

# Get the top 10 data types and their counts, in descending order
top_10_data_types = data_source_counts.nlargest(10)

# Reverse the order
top_10_data_types = top_10_data_types[::-1]

# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_data_types.index, top_10_data_types, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('Data Sources', fontsize=15)
plt.title('Top 10 Data Sources by Frequency', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/top_10_data_types_frequency_2024.png')

# Display the chart
plt.show()

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)
df['Data type'] = df['Data type'].str.replace(';', ',', regex=False)

#df.head(2)

# %%
# Create a new column to store the flattened data types
df['Flattened_Data_Types'] = df['Data type'].str.split(', ')

# Explode the flattened data types into separate rows
df_exploded = df.explode('Flattened_Data_Types')
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.title()
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Abstract", "Abstracts")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Abstract", "Abstracts")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Full-Texts", "Full-Text")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Discharge Summaries", "Patient Discharge Summaries")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Freetext Radiology Reports", "Free-Text Radiology Reports")
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].replace("Free-Text Radiology Reports", "Radiology Reports",)

# Count the frequency of each data type
data_type_counts = df_exploded['Flattened_Data_Types'].value_counts()

# Print the frequency counts
# Adjust the maximum display options to show the full list
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the full list of data type counts
print(data_type_counts)
# Out:
# Abstracts                                                                                 115
# Full-Text                                                                                  49
# Clinical Notes                                                                             17
# Patient Discharge Summaries                                                                12
# Electronic Health Records                                                                   9
# Title                                                                                       9
# Systematic Reviews                                                                          7
# Twitter                                                                                     6
# Drug Labels                                                                                 4
# Patient Recording Transcriptions                                                            4
# Wiki Articles                                                                               4
# Radiology Reports                                                                           3
# Reddit                                                                                      3
# Online Healthcare Information                                                               3
# Sentences                                                                                   2
# Cancer Pathology Reports                                                                    2
# Transcribed Medical Reports                                                                 2
# Askapatient.Com                                                                             2
# Clinical Practice Guidelines                                                                1
# Keywords                                                                                    1
# Patient Text Vignette                                                                       1
# Gpt-Generated Content                                                                       1
# Semi-Synthetic Documents                                                                    1
# Brain Imaging Reports                                                                       1
# Prompts                                                                                     1
# Progress Notes                                                                              1
# Patient Forums On Patient.Info                                                              1
# Meta-Analysis                                                                               1
# Archive Of Human Genetic Variants And Interpretations Of Their Significance To Disease      1
# Time-Series Data From Medical Devices                                                       1
# Disease Genomics Platform                                                                   1
# Online Health Communities Discussion Boards Related To Cancer (Cancernet)                   1
# Doctor-Patient Conversations                                                                1
# Functional Genomics                                                                         1
# Metabolomics                                                                                1
# Stroke                                                                                      1
# Psychiatric Intake Records                                                                  1
# Clinical Evidence                                                                           1
# Name: Flattened_Data_Types, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_exploded is your DataFrame with the exploded data types and data_type_counts is the counts
# If not, you can adjust accordingly based on your DataFrame structure

# Get the top 10 data types and their counts, in descending order
top_10_data_types = data_type_counts.nlargest(10)

# Reverse the order
top_10_data_types = top_10_data_types[::-1]

# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_data_types.index, top_10_data_types, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('Data Types', fontsize=15)
plt.title('Top 10 Data Types by Frequency', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/top_10_data_types_details_frequency_2024.png')

# Display the chart
plt.show()

# %% [markdown]
# ### combined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_exploded is your DataFrame with the exploded data types and data_type_counts is the counts
# If not, you can adjust accordingly based on your DataFrame structure

# Get the top 10 data sources and their counts, in descending order
# This assumes you have a similar way to calculate top data sources as for data types
# Adjust this part according to your data source counts calculation
top_10_data_sources = data_source_counts.nlargest(10)

# Reverse the order for plotting
#top_10_data_types = top_10_data_types[::-1]
top_10_data_sources = top_10_data_sources[::-1]

# Create a larger figure to hold both subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# FIRST plot - Top 10 Data Sources by Frequency
bars = axes[0].barh(top_10_data_sources.index, top_10_data_sources, color='lightgrey')
# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    axes[0].text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

axes[0].tick_params(axis='y', labelsize=15)
axes[0].tick_params(axis='x', labelsize=15)
axes[0].set_xlabel('Frequency', fontsize=15)
#axes[0].set_ylabel('Data Sources', fontsize=15)
axes[0].set_title('Top 10 Data Sources by Frequency', fontsize=16)
axes[0].set_xlim(0, 140)  # Set x-axis limit up to 125

# SECOND plot - Top 10 Data Types by Frequency
bars = axes[1].barh(top_10_data_types.index, top_10_data_types, color='lightgrey')
# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    axes[1].text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

axes[1].tick_params(axis='y', labelsize=15)
axes[1].tick_params(axis='x', labelsize=15)
axes[1].set_xlabel('Frequency', fontsize=15)
#axes[1].set_ylabel('Data Types', fontsize=15)
axes[1].set_title('Top 10 Data Types by Frequency', fontsize=16)
axes[1].set_xlim(0, 125)  # Set x-axis limit up to 125


plt.tight_layout()
# Save the combined plot to a local folder
plt.savefig('viz/top_10_data_types_and_sources_frequency_2024.pdf')
# Display the combined chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame df_exploded
# Group by 'year' and count the occurrences of each 'Flattened_Data_Types' value
grouped = df_exploded.groupby(['year', 'Flattened_Data_Types']).size().reset_index(name='count')

# Sort the data by year and count in descending order
grouped = grouped.sort_values(by=['year', 'count'], ascending=[True, False])

# Get the top 5 most frequent values for each year
top5_values = grouped.groupby('year').head(5)

# Create a pivot table to make it easier for plotting
pivot_table = top5_values.pivot(index='year', columns='Flattened_Data_Types', values='count')

# Plot the data in a line chart
pivot_table.plot(kind='line', marker='o', figsize=(12, 6))
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Top 5 Flattened_Data_Types Over Each Year')
plt.legend(title='Flattened_Data_Types', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ## Fine-tuning corpus data/task

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)

df.head(2)
# Out:
#                                               author  \
# 0  Abdelkader, W. and Navarro, T. and Parrish, R....
# 1  Alachram, H. and Chereda, H. and Beisbarth, T....
#
#                             doi                                 Link to paper  \
# 0                 10.2196/29398                 https://doi.org/10.2196/29398
# 1  10.1371/journal.pone.0258623  https://doi.org/10.1371/journal.pone.0258623
#
#                                                title  \
# 0  A Deep Learning Approach to Refine the Identif...
# 1  Text mining-based word representations for bio...
#
#                           journal  year Extracted by Included  \
# 0         JMIR Research Protocols  2021          BVI      1.0
# 1  PLoS ONE [Electronic Resource]  2021          BVI      1.0
#
#   Reason for exclusion      Target application  \
# 0                  NaN     Text Classification
# 1                  NaN  Information Extraction
#
#                         Domain of automated approach  \
# 0  Literature Screening/ Methodological Quality: ...
# 1  General biomedical text mining/ Genomics: Extr...
#
#                               Target database                       Data type  \
# 0                                      PubMed                       Abstracts
# 1  PubMed, Gene Expression Omnibus repository  Abstracts, Functional Genomics
#
#   Data filter applied        Hosted Application for End-users  \
# 0                 NaN                                      no
# 1                 NaN  yes: https://ebiomecon.genexplain.com/
#
#   Alternative Approach                            LLM Model  \
# 0                  NaN  BERT, BioBERT, BlueBERT, PubMedBERT
# 1                  NaN                              BioBERT
#
#                       Models/Resources used with LLM  \
# 0                                                NaN
# 1  Graph-CNN based on Human Protein Reference Dat...
#
#   System Architecture/ Flow Programming language Library/Framework  \
# 0         BERT architecture               Python       HuggingFace
# 1         BERT architecture               Python           PyTorch
#
#   Library/Framework Harmonized  \
# 0                  HuggingFace
# 1                      PyTorch
#
#                         Reported performance metrics  \
# 0  F1, recall, specificity, accuracy, precision, ...
# 1            AUC, Accuracy, F1, similarity threshold
#
#              Reported performance metrics Harmonized Source code availability  \
# 0  F1-Score, Recall, Specificity, Accuracy, Preci...                       no
# 1      AUC, Accuracy, F1-Score, Similarity Threshold                       no
#
#   Source code link Data used availability  \
# 0              NaN              partially
# 1              NaN                    NaN
#
#                                Preprocessing applied  \
# 0                                                NaN
# 1  for word2vec training: The first phase applied...
#
#             Pretraining corpus origin       Pretraining corpus size  \
# 0               depends on BERT model         depends on BERT model
# 1  for word2vec PubMed FTP repository  16,558,093 article abstracts
#
#                  Fine-tuning corpus data/task  \
# 0                Custom-annotated PubMed data
# 1  HPRD PPI; Custom-annotated from GEO series
#
#                                      New annotations Annotations type  \
# 0  Article type: original study, systematic revie...              NaN
# 1  genomic predictors of response and survival in...              NaN
#
#   New dataset developed                            Fine-tuning corpus size  \
# 0                   yes  Total 2012–2020, N=160 712 (positive 29810 and...
# 1                   yes  10 microarray datasets measured on Affymetrix ...
#
#   Number of tasks/datasets for performance evaluation  \
# 0                                                1.0
# 1  4 (lung cancer, liver cancer, prostate cancer,...
#
#    Hardware used for training/validation/fine-tuning Hardware type  \
# 0  8 Intel Silver 4216 Cascade Lake CPU cores, an...      GPU, CPU
# 1                                                NaN           NaN
#
#   Internal validity 1 Internal validity 2 External validity  \
# 0                 Yes                  No                No
# 1                 Yes                  No               yes
#
#   External validity.1    Comment  Unnamed: 43  \
# 0                 NaN  Protocol!          NaN
# 1            word2vec        NaN          NaN
#
#                                                  url  \
# 0  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 1  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
#
#                           label  type  \
# 0  Abdelkader_2021_JMIRReseProt  JOUR
# 1    Alachram_2021_PLoONE.ElRes  JOUR
#
#                                             abstract  \
# 0  BACKGROUND: A barrier to practicing evidence-b...
# 1  Biomedical and life science literature is an e...
#
#                                              address   accession  Link issue  \
# 0  Abdelkader, Wael. Health Information Research ...  34847061.0   NaN  11.0
# 1  Alachram, Halima. Department of Medical Bioinf...  34653224.0   NaN  10.0
#
#                                             keywords language       issn  \
# 0                                                NaN  English  1929-0748
# 1  Algorithms and *Breast Neoplasms/ge [Genetics]...  English  1932-6203
#
#       pages volume                   DA       DB                 DP     ID  \
# 0    e29398   10.0  2023-11-29 00:00:00  MEDLINE  Ovid Technologies   15.0
# 1  e0258623   16.0                  NaN  MEDLINE  Ovid Technologies  101.0
#
#                 j2                                m3  \
# 0  JMIR Res Protoc                               NaN
# 1         PLoS ONE  Research Support, Non-U.S. Gov't
#
#                                                   n1  \
# 0  Abdelkader, Wael Navarro, Tamara Parrish, Rick...
# 1  Alachram, Halima Chereda, Hryhorii Beisbarth, ...
#
#                                                   ST   m1  c5  c2  c1  OP  \
# 0  A Deep Learning Approach to Refine the Identif...  NaN NaN NaN NaN NaN
# 1  Text mining-based word representations for bio...  NaN NaN NaN NaN NaN
#
#      publication_type  Unnamed: 40 Data availability  Unnamed: 33
# 0  biomedical_journal          NaN               NaN          NaN
# 1  biomedical_journal          NaN               NaN          NaN

# %%
#df = df_2024_included.copy()

# %%
# Create a new column to store the flattened data types
df['Fine-tuning corpus data/task'] = df['Fine-tuning corpus data/task'].str.replace(',', ';', regex=False)
df['Flattened_Data_Types'] = df['Fine-tuning corpus data/task'].str.split('; ?')

# Explode the flattened data types into separate rows
df_exploded = df.explode('Flattened_Data_Types')
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.strip()
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"BC5CDR-Dis", "BC5CDR-disease", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"BC5CDR-Chem", "BC5CDR-chem", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"ChemProt", "CHEMPROT", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"NCBI-Dis", "NCBI-disease", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"NCBI-diseaseease", "NCBI-disease", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"TREC-Covid", "TREC-COVID", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"HOC dataset", "HoC", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"SCIERC", "SciERC", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"GAD-10", "GAD", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"AGAC corpus", "AGAC", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"BioCreative-LitCovid", "LitCovid", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"Genia Event 2013", "GENIA Event 2013", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"THYME(?! Clinical Notes)", "THYME Clinical Notes", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"ChemDNER", "CHEMDNER", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"DementiaBank English Pitt Corpus", "DementiaBank Pitt Corpus", regex=True)
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"DrugBank DB", "DrugBank", regex=True)


# Convert the Flattened_Data_Types column to strings
df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].astype(str)

# Filter out rows containing 'custom' or 'self' in the Flattened_Data_Types column
df_exploded = df_exploded[~df_exploded['Flattened_Data_Types'].str.contains(r'custom|self', case=False)]


#df_exploded['Flattened_Data_Types'] = df_exploded['Flattened_Data_Types'].str.replace(r"BC5CDR.*", "BC5CDR", regex=True)


# Count the frequency of each data type
data_type_counts = df_exploded['Flattened_Data_Types'].value_counts()

# Print the frequency counts
# Adjust the maximum display options to show the full list
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the full list of data type counts
data_type_counts
# Out:
# NCBI-disease                                                                                                                         21
# BC5CDR-disease                                                                                                                       14
# BC2GM                                                                                                                                13
# BC5CDR-chem                                                                                                                          12
# CHEMPROT                                                                                                                             10
# DDIExtractions 2013                                                                                                                  10
# JNLPBA                                                                                                                                9
# BC5CDR                                                                                                                                9
# MIMIC-III                                                                                                                             8
# BioASQ                                                                                                                                6
# BC4CHEMD                                                                                                                              6
# LINNAEUS                                                                                                                              5
# 2010 i2b2/VA                                                                                                                          5
# Existing Systematic Review datasets                                                                                                   5
# Species-800                                                                                                                           5
# EU-ADR                                                                                                                                5
# HoC                                                                                                                                   4
# EBM-NLP                                                                                                                               4
# ShARe/CLEF                                                                                                                            4
# GAD                                                                                                                                   4
# SciERC                                                                                                                                4
# MedNLI                                                                                                                                4
# TREC-COVID                                                                                                                            4
# AGAC                                                                                                                                  3
# TAC-ADR 2017                                                                                                                          3
# PubMedQA                                                                                                                              3
# LitCovid                                                                                                                              3
# THYME Clinical Notes                                                                                                                  3
# nan                                                                                                                                   3
# 2019 n2c2/OHNLP ClinicalSTS                                                                                                           3
# DementiaBank Pitt Corpus                                                                                                              2
# CAMDA                                                                                                                                 2
# SemEval 2010 Task 8                                                                                                                   2
# DrugBank                                                                                                                              2
# BioCreative VII DrugProt Dataset                                                                                                      2
# MedMentions                                                                                                                           2
# BIOSSES                                                                                                                               2
# CORD-19                                                                                                                               2
# CHEMDNER                                                                                                                              2
# Reddit posts                                                                                                                          2
# GENIA Event 2013                                                                                                                      2
# CRAFT-ST 2019                                                                                                                         2
# TAC-DDI 2019                                                                                                                          2
# GENIA Event 2011                                                                                                                      2
# PubMed dataset                                                                                                                        2
# RCT                                                                                                                                   1
# MSNBC                                                                                                                                 1
# HPRD PPI                                                                                                                              1
# OntoNotes 5.0                                                                                                                         1
# AQUAINT                                                                                                                               1
# ACE2004                                                                                                                               1
# CWEB                                                                                                                                  1
# NEDMed                                                                                                                                1
# CNN/DailyMail                                                                                                                         1
# PubMed-summarization by Cohan et al.                                                                                                  1
# Wiki-ZSL                                                                                                                              1
# ACL-ARC                                                                                                                               1
# BioNLP09                                                                                                                              1
# ADReSS Challenge                                                                                                                      1
# Collection of Twitter posts annotated for Suicidal Intent Present/Absent                                                              1
# FEVER                                                                                                                                 1
# MS-MARCO                                                                                                                              1
# Cleveland Clinic EHRs (ClvC)                                                                                                          1
# i2b2 EHRs                                                                                                                             1
# PARADE (computer science)                                                                                                             1
# Biomedical Discourse Relation Bank (BioDBR)                                                                                           1
# SNLI                                                                                                                                  1
# MultiNLI                                                                                                                              1
# COVID-19 tweet dataset provided by WNUT-2020                                                                                          1
# SemEval 2017 Task 4 Subtask A                                                                                                         1
# NFCorpus                                                                                                                              1
# Social Skills Performance Assessment (SSPA) tests                                                                                     1
# BioNLP11EPI                                                                                                                           1
# BioNLP11ID                                                                                                                            1
# BioNLP13CG                                                                                                                            1
# BioNLP13GE                                                                                                                            1
# BioNLP13PC                                                                                                                            1
# MTL-Bioinformatics-2016 datase                                                                                                        1
# Emonet dataset                                                                                                                        1
# FewRel                                                                                                                                1
# Battery                                                                                                                               1
# Dreaddit                                                                                                                              1
# SearchQA                                                                                                                              1
# Ask a Patient dataset                                                                                                                 1
# NHS Tayside                                                                                                                           1
# SimpleDBpediaQA                                                                                                                       1
# SimpleQuestionsWikidata                                                                                                               1
# extended CTD                                                                                                                          1
# TL-HGBI                                                                                                                               1
# BioCreative VI Precision Medicine Track Corpus                                                                                        1
# PLR                                                                                                                                   1
# non-PLR                                                                                                                               1
# SmPC                                                                                                                                  1
# germed                                                                                                                                1
# engmed                                                                                                                                1
# ng20-base                                                                                                                             1
# ng20-long                                                                                                                             1
# scopus-base                                                                                                                           1
# scopus-long                                                                                                                           1
# SHAC                                                                                                                                  1
# DementiaBank English Protocol Delaware Corpus                                                                                         1
# CPTAC                                                                                                                                 1
# MEDLINE ADE corpus                                                                                                                    1
# 2022 n2c2 challenge corpus                                                                                                            1
# GoEmotions dataset                                                                                                                    1
# UniProt                                                                                                                               1
# Kaggle MBTI dataset                                                                                                                   1
# OnlineSupportForum                                                                                                                    1
# MTurk workers conversations                                                                                                           1
# patient.info                                                                                                                          1
# MedLine                                                                                                                               1
# DailyMed                                                                                                                              1
# MIMIC-CXR                                                                                                                             1
# MatSciNER                                                                                                                             1
# ScienceExam                                                                                                                           1
# Coleridge                                                                                                                             1
# PaperField                                                                                                                            1
# SHARP Stratiﬁed                                                                                                                       1
# CMID                                                                                                                                  1
# KUAKE-QIC                                                                                                                             1
# TRANS                                                                                                                                 1
# ABS                                                                                                                                   1
# discharge                                                                                                                             1
# progress                                                                                                                              1
# NCBI Entrez Gene                                                                                                                      1
# SCI-FACT                                                                                                                              1
# SemMedDB Semantic predications                                                                                                        1
# Strategic Health IT Advanced Research Projects (SHARP) Seed                                                                           1
# TwADR-L Dataset                                                                                                                       1
# Attention Deficit Hyperactivity Disorder (ADHD) dataset                                                                               1
# TwiMed-Twitter dataset                                                                                                                1
# TwiMed-PubMed dataset                                                                                                                 1
# BioRED                                                                                                                                1
# NLM-Chem                                                                                                                              1
# CRAFT                                                                                                                                 1
# TAC-DDI 2018                                                                                                                          1
# CADEC-MCN Dataset                                                                                                                     1
# CRAFT-SA 2019                                                                                                                         1
# Multi-source Integrated Platform for Answering Clinical Questions Corpus (MiPACQ)                                                     1
# Evidence Inference 2.0                                                                                                                1
# BibTeX (.bib)                                                                                                                         1
# RIS (.ris) or End-note XML (.xml) references. Train set updated on the fly based on the user interacitions                            1
# COVID-19 Open Access Project (COAP)                                                                                                   1
# n-ary drug-gene-mutation dataset                                                                                                      1
# Cusotom-annotated PubMeb abstracts                                                                                                    1
# BioNLP 2011 Shared Task Protein Coreference                                                                                           1
# CRAFT-CR dataset                                                                                                                      1
# Twitter ADR dataset                                                                                                                   1
# Asia Bayesian Network dataset                                                                                                         1
# Risk factors of Alzheimer’s disease (AD) dataset                                                                                      1
# PubMed weekly query data labeled as relevant or not (downloading all retrieved entries over the last ten years Jan 2011–May 2021)     1
# PharmaHKG Dataset                                                                                                                     1
# INDRA KG text-triple pairs                                                                                                            1
# PICO-annotated MEDLINE abstracts                                                                                                      1
# TCM-relations                                                                                                                         1
# i2b2 2012 temporal corpus                                                                                                             1
# IntAct Database of PTM-PPI interactions                                                                                               1
# BioNLP-ST 2009 (ST09)                                                                                                                 1
# Epigenetics and Post-translational Modifications (EPI11)                                                                              1
# Infectious Diseases (ID11)                                                                                                            1
# Multi-Level Event Extraction (MLEE)                                                                                                   1
# Cancer Genetics (CG13)                                                                                                                1
# Pathway Curation (PC13)                                                                                                               1
# Gene Regulation Ontology (GRO13)                                                                                                      1
# SEER Cancer Pathology Reports                                                                                                         1
# BioInfer PPI corpus                                                                                                                   1
# Medication and Adverse Drug Events from Electronic Health Records 1.0 (MADE)                                                          1
# National NLP Clinical Challenges Task 2 (N2C2)                                                                                        1
# BioCreative VII NLM-CHEM                                                                                                              1
# HPO GSC+ dataset                                                                                                                      1
# JAX dataset                                                                                                                           1
# HIV datasets                                                                                                                          1
# PCdes                                                                                                                                 1
# Clinical Hedges Dataset                                                                                                               1
# TREC2017                                                                                                                              1
# TREC2018                                                                                                                              1
# TREC2019                                                                                                                              1
# MCN                                                                                                                                   1
# NCBI-gene/protein                                                                                                                     1
# MEDIQA-2019                                                                                                                           1
# TRECQA-2017                                                                                                                           1
# SemEval-STS                                                                                                                           1
# SemEval-NLI                                                                                                                           1
# BioNLP2013 Cancer Genetics (CG) task                                                                                                  1
# SQuAD2.0                                                                                                                              1
# QuAC                                                                                                                                  1
# COVID-QA dataset                                                                                                                      1
# NeurIPS                                                                                                                               1
# TREC Health Misinformation Track                                                                                                      1
# chemical reaction classification task on USPTO 1k TPL                                                                                 1
# TOX21                                                                                                                                 1
# KD-DTI                                                                                                                                1
# SIDER                                                                                                                                 1
# SciDocs                                                                                                                               1
# ADE-Corpus-V2 dataset                                                                                                                 1
# CINAHL (Ebsco)                                                                                                                        1
# Web of Science and IEEE                                                                                                               1
# DDI                                                                                                                                   1
# MedSTS                                                                                                                                1
# ProPheno 1.0                                                                                                                          1
# 6000 annotated relations from SemMedDB                                                                                                1
# BioCreative V BEL Task                                                                                                                1
# DailyMed Structured Drug Product Labels                                                                                               1
# PPI (AIMed)                                                                                                                           1
# Memorial Sloan Kettering CancerCenter (MSKCC) precision oncology knowledge base with thousands of mutations                           1
# i2b2 2014 challenge                                                                                                                   1
# CEGS N-GRID 2016 challenge                                                                                                            1
# PubMed 200k                                                                                                                           1
# The Comparative Toxicogenomics Database (CTD)                                                                                         1
# BBBP                                                                                                                                  1
# EBMSASS                                                                                                                               1
# Name: Flattened_Data_Types, dtype: int64

# %% [markdown]
# ### Custom Datasets

# %%
df_exploded.head()
# Out:
#                                               author  \
# 1  Alachram, H. and Chereda, H. and Beisbarth, T....
# 2          Ambalavanan, A. K. and Devarakonda, M. V.
# 3              Asada, M. and Miwa, M. and Sasaki, Y.
# 3              Asada, M. and Miwa, M. and Sasaki, Y.
# 3              Asada, M. and Miwa, M. and Sasaki, Y.
#
#                               doi  \
# 1    10.1371/journal.pone.0258623
# 2       10.1016/j.jbi.2020.103578
# 3  10.1093/bioinformatics/btac754
# 3  10.1093/bioinformatics/btac754
# 3  10.1093/bioinformatics/btac754
#
#                                     Link to paper  \
# 1    https://doi.org/10.1371/journal.pone.0258623
# 2       https://doi.org/10.1016/j.jbi.2020.103578
# 3  https://doi.org/10.1093/bioinformatics/btac754
# 3  https://doi.org/10.1093/bioinformatics/btac754
# 3  https://doi.org/10.1093/bioinformatics/btac754
#
#                                                title  \
# 1  Text mining-based word representations for bio...
# 2  Using the contextual language model BERT for m...
# 3  Integrating heterogeneous knowledge graphs int...
# 3  Integrating heterogeneous knowledge graphs int...
# 3  Integrating heterogeneous knowledge graphs int...
#
#                              journal  year Extracted by Included  \
# 1     PLoS ONE [Electronic Resource]  2021          BVI      1.0
# 2  Journal of Biomedical Informatics  2020          BVI      1.0
# 3                     Bioinformatics  2023          BVI      1.0
# 3                     Bioinformatics  2023          BVI      1.0
# 3                     Bioinformatics  2023          BVI      1.0
#
#   Reason for exclusion      Target application  \
# 1                  NaN  Information Extraction
# 2                  NaN     Text Classification
# 3                  NaN     Relation Extraction
# 3                  NaN     Relation Extraction
# 3                  NaN     Relation Extraction
#
#                         Domain of automated approach  \
# 1  General biomedical text mining/ Genomics: Extr...
# 2  Literature Screening/ Combination of Selection...
# 3  Pharma/ Drug-Drug Interaction: Drug-drug inter...
# 3  Pharma/ Drug-Drug Interaction: Drug-drug inter...
# 3  Pharma/ Drug-Drug Interaction: Drug-drug inter...
#
#                               Target database                       Data type  \
# 1  PubMed, Gene Expression Omnibus repository  Abstracts, Functional Genomics
# 2                                     MEDLINE                       Abstracts
# 3                  MEDLINE, DrugBank database                       Abstracts
# 3                  MEDLINE, DrugBank database                       Abstracts
# 3                  MEDLINE, DrugBank database                       Abstracts
#
#   Data filter applied        Hosted Application for End-users  \
# 1                 NaN  yes: https://ebiomecon.genexplain.com/
# 2                 NaN                                      no
# 3                 NaN                                      no
# 3                 NaN                                      no
# 3                 NaN                                      no
#
#   Alternative Approach                   LLM Model  \
# 1                  NaN                     BioBERT
# 2                  NaN                     SciBERT
# 3                  NaN  BERT, ChemBERT, PubMedBERT
# 3                  NaN  BERT, ChemBERT, PubMedBERT
# 3                  NaN  BERT, ChemBERT, PubMedBERT
#
#                       Models/Resources used with LLM  \
# 1  Graph-CNN based on Human Protein Reference Dat...
# 2  feed forward network (FFN) as the text classif...
# 3                     Heterogeneous knowledge graphs
# 3                     Heterogeneous knowledge graphs
# 3                     Heterogeneous knowledge graphs
#
#   System Architecture/ Flow Programming language Library/Framework  \
# 1         BERT architecture               Python           PyTorch
# 2         BERT architecture               Python           PyTorch
# 3         BERT architecture               Python       HuggingFace
# 3         BERT architecture               Python       HuggingFace
# 3         BERT architecture               Python       HuggingFace
#
#   Library/Framework Harmonized  \
# 1                      PyTorch
# 2                      PyTorch
# 3                  HuggingFace
# 3                  HuggingFace
# 3                  HuggingFace
#
#                         Reported performance metrics  \
# 1            AUC, Accuracy, F1, similarity threshold
# 2                              Precision, Recall, F1
# 3  Mean reciprokal rank, hits@1, 3, and 10, F1, p...
# 3  Mean reciprokal rank, hits@1, 3, and 10, F1, p...
# 3  Mean reciprokal rank, hits@1, 3, and 10, F1, p...
#
#              Reported performance metrics Harmonized Source code availability  \
# 1      AUC, Accuracy, F1-Score, Similarity Threshold                       no
# 2                        Precision, Recall, F1-Score                      yes
# 3  Mean Reciprocal Rank, Hits@1, 3, and 10, F1-Sc...                      yes
# 3  Mean Reciprocal Rank, Hits@1, 3, and 10, F1-Sc...                      yes
# 3  Mean Reciprocal Rank, Hits@1, 3, and 10, F1-Sc...                      yes
#
#                                   Source code link Data used availability  \
# 1                                              NaN                    NaN
# 2  https://github.com/md-labs/Clinical_Hedges_BERT                    yes
# 3          https://github.com/tticoin/HKG-DDIE.git                    yes
# 3          https://github.com/tticoin/HKG-DDIE.git                    yes
# 3          https://github.com/tticoin/HKG-DDIE.git                    yes
#
#                                Preprocessing applied  \
# 1  for word2vec training: The first phase applied...
# 2                                                NaN
# 3                                                Yes
# 3                                                Yes
# 3                                                Yes
#
#             Pretraining corpus origin       Pretraining corpus size  \
# 1  for word2vec PubMed FTP repository  16,558,093 article abstracts
# 2                         see SciBERT                   see SciBERT
# 3                     see BERT models               see BERT models
# 3                     see BERT models               see BERT models
# 3                     see BERT models               see BERT models
#
#                         Fine-tuning corpus data/task  \
# 1         HPRD PPI; Custom-annotated from GEO series
# 2                            Clinical Hedges Dataset
# 3  DDIExtractions 2013; BioCreative VII DrugProt ...
# 3  DDIExtractions 2013; BioCreative VII DrugProt ...
# 3  DDIExtractions 2013; BioCreative VII DrugProt ...
#
#                                      New annotations Annotations type  \
# 1  genomic predictors of response and survival in...              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 3                                                NaN              NaN
# 3                                                NaN              NaN
#
#   New dataset developed                            Fine-tuning corpus size  \
# 1                   yes  10 microarray datasets measured on Affymetrix ...
# 2                    no                                     50,590 entries
# 3                    no                           20988 records (re-check)
# 3                    no                           20988 records (re-check)
# 3                    no                           20988 records (re-check)
#
#   Number of tasks/datasets for performance evaluation  \
# 1  4 (lung cancer, liver cancer, prostate cancer,...
# 2                                                NaN
# 3                                                NaN
# 3                                                NaN
# 3                                                NaN
#
#   Hardware used for training/validation/fine-tuning Hardware type  \
# 1                                               NaN           NaN
# 2                                               GPU           GPU
# 3                                               NaN           NaN
# 3                                               NaN           NaN
# 3                                               NaN           NaN
#
#   Internal validity 1 Internal validity 2 External validity  \
# 1                 Yes                  No               yes
# 2                 Yes                  No               yes
# 3                 Yes                  No               yes
# 3                 Yes                  No               yes
# 3                 Yes                  No               yes
#
#            External validity.1  \
# 1                     word2vec
# 2   CNN, Customized text query
# 3  CNN, Bi-LSTM, SciFice-Large
# 3  CNN, Bi-LSTM, SciFice-Large
# 3  CNN, Bi-LSTM, SciFice-Large
#
#                                              Comment  Unnamed: 43  \
# 1                                                NaN          NaN
# 2  Clinical Hedges dataset could be relevant for ...          NaN
# 3                                                NaN          NaN
# 3                                                NaN          NaN
# 3                                                NaN          NaN
#
#                                                  url  \
# 1  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 2  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 3  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 3  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
# 3  https://ovidsp.ovid.com/ovidweb.cgi?T=JS&CSC=Y...
#
#                         label  type  \
# 1  Alachram_2021_PLoONE.ElRes  JOUR
# 2   Ambalavanan_2020_JoofBiIn  JOUR
# 3             Asada_2023_Bioi  JOUR
# 3             Asada_2023_Bioi  JOUR
# 3             Asada_2023_Bioi  JOUR
#
#                                             abstract  \
# 1  Biomedical and life science literature is an e...
# 2  BACKGROUND: Finding specific scientific articl...
# 3  MOTIVATION: Most of the conventional deep neur...
# 3  MOTIVATION: Most of the conventional deep neur...
# 3  MOTIVATION: Most of the conventional deep neur...
#
#                                              address   accession  Link issue  \
# 1  Alachram, Halima. Department of Medical Bioinf...  34653224.0   NaN  10.0
# 2  Ambalavanan, Ashwin Karthik. Arizona State Uni...  33059047.0   NaN   NaN
# 3  Asada, Masaki. Toyota Technological Institute,...  36416141.0   NaN   1.0
# 3  Asada, Masaki. Toyota Technological Institute,...  36416141.0   NaN   1.0
# 3  Asada, Masaki. Toyota Technological Institute,...  36416141.0   NaN   1.0
#
#                                             keywords language       issn  \
# 1  Algorithms and *Breast Neoplasms/ge [Genetics]...  English  1932-6203
# 2  Information Storage and Retrieval and Medline ...  English  1532-0480
# 3  Humans and Pattern Recognition, Automated/mt [...  English  1367-4811
# 3  Humans and Pattern Recognition, Automated/mt [...  English  1367-4811
# 3  Humans and Pattern Recognition, Automated/mt [...  English  1367-4811
#
#       pages volume                   DA       DB                 DP     ID  \
# 1  e0258623   16.0                  NaN  MEDLINE  Ovid Technologies  101.0
# 2  103578.0  112.0                 12.0  MEDLINE  Ovid Technologies  182.0
# 3       1.0   39.0  2023-01-01 00:00:00  MEDLINE  Ovid Technologies  262.0
# 3       1.0   39.0  2023-01-01 00:00:00  MEDLINE  Ovid Technologies  262.0
# 3       1.0   39.0  2023-01-01 00:00:00  MEDLINE  Ovid Technologies  262.0
#
#                 j2                                m3  \
# 1         PLoS ONE  Research Support, Non-U.S. Gov't
# 2  J Biomed Inform                               NaN
# 3   Bioinformatics  Research Support, Non-U.S. Gov't
# 3   Bioinformatics  Research Support, Non-U.S. Gov't
# 3   Bioinformatics  Research Support, Non-U.S. Gov't
#
#                                                   n1  \
# 1  Alachram, Halima Chereda, Hryhorii Beisbarth, ...
# 2  Ambalavanan, Ashwin Karthik Devarakonda, Murth...
# 3  Using Smart Source Parsing 01 Asada, Masaki Mi...
# 3  Using Smart Source Parsing 01 Asada, Masaki Mi...
# 3  Using Smart Source Parsing 01 Asada, Masaki Mi...
#
#                                                   ST   m1  c5  c2  c1  OP  \
# 1  Text mining-based word representations for bio...  NaN NaN NaN NaN NaN
# 2  Using the contextual language model BERT for m...  NaN NaN NaN NaN NaN
# 3  Integrating heterogeneous knowledge graphs int...  NaN NaN NaN NaN NaN
# 3  Integrating heterogeneous knowledge graphs int...  NaN NaN NaN NaN NaN
# 3  Integrating heterogeneous knowledge graphs int...  NaN NaN NaN NaN NaN
#
#      publication_type  Unnamed: 40 Data availability  Unnamed: 33  \
# 1  biomedical_journal          NaN               NaN          NaN
# 2  biomedical_journal          NaN               NaN          NaN
# 3  biomedical_journal          NaN               NaN          NaN
# 3  biomedical_journal          NaN               NaN          NaN
# 3  biomedical_journal          NaN               NaN          NaN
#
#                Flattened_Data_Types
# 1                          HPRD PPI
# 2           Clinical Hedges Dataset
# 3               DDIExtractions 2013
# 3  BioCreative VII DrugProt Dataset
# 3                 PharmaHKG Dataset

# %%
selected_rows = df_exploded[df_exploded["Flattened_Data_Types"].str.contains("custom|self", case=False, na=False)]
custom_datasets = selected_rows[['title', 'Domain of automated approach', 'journal', 'Data type', 'Target application', 'year', 'Data used availability', 'Flattened_Data_Types', 'publication_type', 'New annotations']]
#custom_datasets[['Biomedical Domain', 'Domain Details']] = custom_datasets['Domain of automated approach'].str.split(':', 1, expand=True)
#df[['Biomedical Domain', 'Domain Details']] = df['Domain of automated approach'].str.split(':', 1, expand=True)

#custom_datasets[['Biomedical Domain Main', 'Biomedical Domain Additional']] = custom_datasets['Biomedical Domain'].str.split('/', 1, expand=True)
selected_rows.shape, custom_datasets.shape
# Out:
# ((0, 75), (0, 10))

# %%
custom_datasets_classification = custom_datasets[custom_datasets["Target application"].str.contains("classification", case=False, na=False)]
custom_datasets_classification.sort_values(by="Flattened_Data_Types")
# Out:
#                                                  title  \
# 103  A context-based framework for modeling the rol...
# 74   Automating Quality Assessment of Medical Evide...
# 102  CORA: A Deep Active Learning Covid-19 Relevanc...
# 38   Bat4RCT: A suite of benchmark data and baselin...
# 0    A Deep Learning Approach to Refine the Identif...
# 77   Clinical study type classification, validation...
# 109  Detecting causal language use in science findings
# 21   An automated approach to identify scientific p...
# 12   The Classification of Short Scientific Texts U...
# 54   Towards Automated Screening of Literature on A...
# 146  Two Directions for Clinical Data Generation wi...
# 169  Automatic literature screening using the PAJO ...
# 160  Ensemble of deep learning language models to s...
# 80   Machine learning approach to identify adverse ...
# 111  Canceremo: A dataset for fine-grained emotion ...
# 79   Risk of bias assessment in preclinical literat...
# 40   Thesaurus-based word embeddings for automated ...
# 31   Classifying literature mentions of biological ...
# 138  What to Fuse and How to Fuse: Exploring Emotio...
# 147  Deep learning to refine the identification of ...
# 150  Automatic classification of experimental model...
# 151  Semi-automating abstract screening with a natu...
# 176  Automated classification of lay health article...
# 161  Classifying referring/non-referring ADR in bio...
# 172  Prediction of American Society of Anesthesiolo...
# 173  A Supervised Text Classification System Detect...
# 183  MedKPL: A heterogeneous knowledge enhanced pro...
#
#                           Domain of automated approach  \
# 103  Biomedical Literature Curation: categorizing t...
# 74   Evidence-Based Medicine/ Research Quality Appr...
# 102  Biomedical Literature Curation/ Covid-19: dist...
# 38   Biomedical Literature Curation/ RCT Articles: ...
# 0    Literature Screening/ Methodological Quality: ...
# 77   Literature Screening/ Study Type/ Biomedical L...
# 109  Evidence-Based Medicine: prediction model to a...
# 21   Pharma/ Pharmacokinetics: Providing a centrali...
# 12   Literature Screening/ Systematic Reviews/ Neur...
# 54   Literature Screening/ Systematic Reviews/ Nurs...
# 146  Clinical/ Mental Disorder Detection: investiga...
# 169  Literature Screening: mines the textual inform...
# 160  Literature Screening: perform triage of COVID-...
# 80   Literature Screening/ Systematic Reviews/ Adve...
# 111  Media for Health Care/ Emotion Detection: fine...
# 79   Biomedical Literature Curation/ Risk Of Bias/ ...
# 40   Biomedical Literature Curation: Annotating bio...
# 31   Literature-Based Discovery/ Systematic Reviews...
# 138  Media for Health Care/ Mental Health Screening...
# 147  Evidence-Based Medicine: identify high-quality...
# 150  Biomedical Literature Curation: search alterna...
# 151  Literature Screening/ Systematic Reviews: inco...
# 176  Media for Health Care/ Health Education: devel...
# 161  General biomedical text mining: detect the sid...
# 172  Clinical/ Physical Status Classification: pred...
# 173  Clinical/ Disease Detection: utilize free text...
# 183  Clinical/ Disease Detection: propose a Medical...
#
#                                                journal  \
# 103                                              EMNLP
# 74                Journal of Medical Internet Research
# 102  Association for Computational Linguistics/ NLP...
# 38                      PLoS ONE [Electronic Resource]
# 0                              JMIR Research Protocols
# 77                                             medRxiv
# 109                                              EMNLP
# 21                              Wellcome Open Research
# 12          Studies in Health Technology & Informatics
# 54          Studies in Health Technology & Informatics
# 146                                      ACL/ Findings
# 169        BMC Medical Informatics and Decision Making
# 160                                 Systematic Reviews
# 80                  Clinical and translational science
# 111                                              EMNLP
# 79                          Research Synthesis Methods
# 40                     Neural Computing & Applications
# 31                     Journal of biomedical semantics
# 138  Association for Computational Linguistics/ Fin...
# 147                  Journal of Biomedical Informatics
# 150                    Journal of Biomedical Semantics
# 151                                 Systematic Reviews
# 176                            Frontiers in Psychiatry
# 161                   Informatics in Medicine Unlocked
# 172                                            medRxiv
# 173          Journal of the American Heart Association
# 183                  Journal of Biomedical Informatics
#
#                                              Data type   Target application  \
# 103                                          Abstracts  Text Classification
# 74                                  Systematic Reviews  Text Classification
# 102                               Abstracts, Full-text  Text Classification
# 38                                           Abstracts  Text Classification
# 0                                            Abstracts  Text Classification
# 77                                           Abstracts  Text Classification
# 109                                          Abstracts  Text Classification
# 21                                           Abstracts  Text Classification
# 12                                           Abstracts  Text Classification
# 54                                           Abstracts  Text Classification
# 146                          electronic health records  Text Classification
# 169                                    title, abstract  Text Classification
# 160                                    title, abstract  Text Classification
# 80                       Full-text, Systematic Reviews  Text Classification
# 111  Online health communities discussion boards re...  Text Classification
# 79                       Full-text, Systematic Reviews  Text Classification
# 40                                Abstracts, Full-text  Text Classification
# 31                                           Abstracts  Text Classification
# 138                                             Reddit  Text Classification
# 147                                    title, abstract  Text Classification
# 150                                    title, abstract  Text Classification
# 151                                           abstract  Text Classification
# 176     title, abstract, Online Healthcare Information  Text Classification
# 161               abstract, full-text, Askapatient.com  Text Classification
# 172                          electronic health records  Text Classification
# 173                          electronic health records  Text Classification
# 183                          electronic health records  Text Classification
#
#      year Data used availability  \
# 103  2019                    yes
# 74   2023                    yes
# 102  2020                    yes
# 38   2023                    yes
# 0    2021              partially
# 77   2022                     no
# 109  2019                    yes
# 21   2021                    yes
# 12   2021                    NaN
# 54   2022                     no
# 146  2023                    NaN
# 169  2023                    NaN
# 160  2023                    NaN
# 80   2022                     no
# 111  2020                    yes
# 79   2022                     no
# 40   2022                    NaN
# 31   2023                    yes
# 138  2023                    yes
# 147  2023                    NaN
# 150  2023                    NaN
# 151  2023                    NaN
# 176  2023                    NaN
# 161  2023                    NaN
# 172  2023                    NaN
# 173  2023                    NaN
# 183  2023                    NaN
#
#                                   Flattened_Data_Types    publication_type  \
# 103                               Custom-annotated ARC           nlp_venue
# 74                   Custom-annotated Cochrane Reviews  biomedical_journal
# 102                     Custom-annotated Elsevier data           nlp_venue
# 38                   Custom-annotated MEDLINE articles  biomedical_journal
# 0                         Custom-annotated PubMed data  biomedical_journal
# 77                        Custom-annotated PubMed data  biomedical_journal
# 109                       Custom-annotated PubMed data           nlp_venue
# 21                        Custom-annotated PubMed data  biomedical_journal
# 12                        Custom-annotated PubMed data  biomedical_journal
# 54    Custom-annotated abstracts from PubMed (MEDLINE)  biomedical_journal
# 146                              Custom-annotated data           nlp_venue
# 169                              Custom-annotated data  biomedical_journal
# 160                              Custom-annotated data  biomedical_journal
# 80                  Custom-annotated dataset of EMBASE  biomedical_journal
# 111          Custom-annotated health board discussions           nlp_venue
# 79                Custom-annotated preclinical studies  biomedical_journal
# 40                        Custom-developed PubMed data  biomedical_journal
# 31                    Custom-generated MEDLINE dataset  biomedical_journal
# 138  Self-Reported MentalHealth Diagnoses (SMHD) da...           nlp_venue
# 147                                Self-collected data  biomedical_journal
# 150                                Self-collected data  biomedical_journal
# 151                                Self-collected data  biomedical_journal
# 176                                Self-collected data  biomedical_journal
# 161                                Self-collected data  biomedical_journal
# 172                                Self-collected data  biomedical_journal
# 173                                Self-collected data  biomedical_journal
# 183                                Self-collected data  biomedical_journal
#
#                                        New annotations
# 103  full-text annotations for the resource role ty...
# 74   quality of evidence (RoB, imprecision, inconsi...
# 102  relevance annotation for the reserch question ...
# 38                                     RCT - yes or no
# 0    Article type: original study, systematic revie...
# 77   Abstracts were assigned one of the following s...
# 109  annotated sentence with on of the casual relat...
# 21   Pharmacokinetics - papers that contain in vivo...
# 12   Relevant or not for a systematic review in art...
# 54   if topic is artificial intelligence in nursing...
# 146                                                NaN
# 169                                                NaN
# 160                                                NaN
# 80   relevance annotation for the reserch question ...
# 111  sentences from an online cancer network annota...
# 79   five risk of bias domains annotated in full-te...
# 40   we collect metadata, together with their manua...
# 31   support the detection of experimentally studie...
# 138                                                NaN
# 147                                                NaN
# 150                                                NaN
# 151                                                NaN
# 176                                                NaN
# 161                                                NaN
# 172                                                NaN
# 173                                                NaN
# 183                                                NaN

# %%
custom_datasets_classification.shape
# Out:
# (27, 10)

# %%
custom_datasets['Target application'].value_counts()
# Out:
# Text Classification             27
# Information Extraction          19
# Information Retrieval            9
# Named Entity Recognition         6
# Knowledge Graph                  4
# Entity Normalization/Linking     3
# Similarity Clustering            2
# Text Summarization               2
# Text Generation                  2
# Machine Reading Coprehension     1
# Fact Verification                1
# Multi-Domain                     1
# Relation Extraction              1
# Topic Modelling                  1
# Name: Target application, dtype: int64

# %%
# Assuming df_exploded is your DataFrame with the exploded data types and data_type_counts is the counts
# If not, you can adjust accordingly based on your DataFrame structure

# Get the top 10 data types and their counts, in descending order
top_10_data_types = custom_datasets['Target application'].value_counts()

# Reverse the order
top_10_data_types = top_10_data_types[::-1]

# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_data_types.index, top_10_data_types, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('NLP Task', fontsize=15)
plt.title('Custom Datasets Applications', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/custom_dataset_nlp_task_2024.png')

# Display the chart
plt.show()

# %%
category_counts
# Out:
#               Target application    publication_type  count
# 0   Entity Normalization/Linking  biomedical_journal      2
# 1   Entity Normalization/Linking           nlp_venue      1
# 2              Fact Verification           nlp_venue      1
# 3         Information Extraction  biomedical_journal      3
# 4         Information Extraction           nlp_venue      5
# 5          Information Retrieval  biomedical_journal      5
# 6          Information Retrieval           nlp_venue      3
# 7                Knowledge Graph  biomedical_journal      2
# 8   Machine Reading Coprehension  biomedical_journal      1
# 9                   Multi-Domain           nlp_venue      1
# 10      Named Entity Recognition  biomedical_journal      5
# 11         Similarity Clustering  biomedical_journal      1
# 12           Text Classification  biomedical_journal     11
# 13           Text Classification           nlp_venue      5
# 14            Text Summarization  biomedical_journal      2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming custom_datasets is defined and loaded
# Count the frequency of each category
category_counts = custom_datasets.groupby(['Target application', 'publication_type']).size()
category_counts = category_counts.rename("count")
category_counts = category_counts.reset_index()

# Pivot the data for a stacked bar chart
pivoted_data = category_counts.pivot(index='Target application', columns='publication_type', values='count')

# Fill NaN with 0 for stacking
pivoted_data = pivoted_data.fillna(0)

# Sort by the total count of each category
pivoted_data['total'] = pivoted_data.sum(axis=1)
pivoted_data = pivoted_data.sort_values('total', ascending=False)

# Store the sorted target application names for later use
sorted_target_applications = pivoted_data.index.tolist()

# Drop the total column used for sorting
pivoted_data = pivoted_data.drop(columns='total')

# Create a larger figure
plt.figure(figsize=(10, 7))

# Plotting stacked horizontal bars
bar_plot = pivoted_data.plot(kind='barh', stacked=True, color=['skyblue', 'darkgrey'], ax=plt.gca())

# Reverse the order of the y-axis to match the sorted categories
plt.gca().invert_yaxis()

# Add labels and title
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('', fontsize=15)
plt.title('Custom Datasets Frequency Developed per NLP Task', fontsize=16)
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)

# Add count values as annotations in the center of each bar segment
for i, bar in enumerate(bar_plot.containers):
    for rect in bar:
        # Calculate width and center position for the annotation
        width = rect.get_width()
        center = rect.get_x() + width / 2
        if width > 0:  # Only annotate non-zero values
            plt.text(center, rect.get_y() + rect.get_height() / 2, int(width), ha='center', va='center', color='black', fontsize=12)

# Add color legend
plt.legend(['Biomedical Journal', 'NLP Venue'], fontsize=15)

# Save and show the plot
plt.savefig('viz/custom_dataset_nlp_task_stacked_2024.pdf', bbox_inches='tight')
plt.show()

# %%
custom_datasets['Data type'].value_counts()
# Out:
# Abstracts                                                                                                                       23
# Abstracts, Full-text                                                                                                             6
# Abstracts, Archive of human genetic variants and interpretations of their significance to disease, Disease genomics platform     2
# Full-text                                                                                                                        2
# Full-text, Systematic Reviews                                                                                                    2
# abstract, full-text                                                                                                              2
# clinical notes                                                                                                                   2
# Twitter, Wiki Articles                                                                                                           1
# title, abstract, journal characteristics                                                                                         1
# title, abstract                                                                                                                  1
# title, abstract, source                                                                                                          1
# electronic health records                                                                                                        1
# sentences                                                                                                                        1
# Twitter                                                                                                                          1
# Wiki Articles                                                                                                                    1
# Online health communities discussion boards related to cancer (CancerNet)                                                        1
# Abstracts, Functional Genomics                                                                                                   1
# Medical news websites, Abstracts                                                                                                 1
# Full-text, Metabolomics                                                                                                          1
# Abstracts, Stroke                                                                                                                1
# Systematic Reviews                                                                                                               1
# Abstracts, Meta-Analysis                                                                                                         1
# Abstracts, Full-text, Sentences                                                                                                  1
# abstract                                                                                                                         1
# Name: Data type, dtype: int64

# %%
custom_datasets['Biomedical Domain Main'].value_counts()
# Out:
# Literature-Based Discovery        16
# General biomedical text mining    13
# Literature Screening               8
# Evidence-Based Medicine            6
# Biomedical Literature Curation     6
# Media for Health Care              5
# Pharma                             1
# Clinical                           1
# Biological Functions               1
# Name: Biomedical Domain Main, dtype: int64

# %%
custom_datasets['publication_type'].value_counts()
# Out:
# biomedical_journal    41
# nlp_venue             16
# Name: publication_type, dtype: int64

# %%
41/bio_papers_count, 16/nlp_papers_count
# Out:
# (0.4606741573033708, 0.3137254901960784)

# %%
custom_datasets['Data used availability'].value_counts()
# Out:
# yes          28
# no           10
# partially     3
# Name: Data used availability, dtype: int64

# %%
len(custom_datasets_classification)
# Out:
# 18

# %%
custom_datasets_retrieval = custom_datasets[custom_datasets["Target application"].str.contains("retrieval", case=False, na=False)]
custom_datasets_retrieval.sort_values(by="Flattened_Data_Types")
# Out:
#                                                  title  \
# 116  Self-supervised context-aware COVID-19 documen...
# 45   pubmedKB: an interactive web server for explor...
# 45   pubmedKB: an interactive web server for explor...
# 9    LitCovid: an open database of COVID-19 literature
# 120  Transitioning from benchmarks to a real-world ...
# 8    LitCovid in 2022: an information resource for ...
# 53   LiSA: an assisted literature search pipeline f...
# 92   Querying across genres for medical claims in news
#
#                           Domain of automated approach  \
# 116  Literature-Based Discovery/ Covid-19: selfsupe...
# 45   Literature-Based Discovery: Search engine for ...
# 45   Literature-Based Discovery: Search engine for ...
# 9    Literature-Based Discovery/ Covid-19: Informat...
# 120  Literature-Based Discovery:  illustrate throug...
# 8    Literature-Based Discovery/ Covid-19: Informat...
# 53   Literature-Based Discovery/ Pharma/ Adverse-Dr...
# 92   Media for Health Care/ Health News Verificatio...
#
#                                                journal  \
# 116  Association for Computational Linguistics/ NLP...
# 45                              Nucleic Acids Research
# 45                              Nucleic Acids Research
# 9                               Nucleic Acids Research
# 120  Association for Computational Linguistics/ Fin...
# 8                               Nucleic Acids Research
# 53           BMC Medical Informatics & Decision Making
# 92                                               EMNLP
#
#                                              Data type     Target application  \
# 116                               Abstracts, Full-text  Information Retrieval
# 45   Abstracts, Archive of human genetic variants a...  Information Retrieval
# 45   Abstracts, Archive of human genetic variants a...  Information Retrieval
# 9                                            Abstracts  Information Retrieval
# 120                                          Abstracts  Information Retrieval
# 8                                            Abstracts  Information Retrieval
# 53                     Abstracts, Full-text, Sentences  Information Retrieval
# 92                    Medical news websites, Abstracts  Information Retrieval
#
#      year Data used availability  \
# 116  2020                    yes
# 45   2022                     no
# 45   2022                     no
# 9    2021                    yes
# 120  2023                     no
# 8    2023                    yes
# 53   2022              partially
# 92   2020                    yes
#
#                                   Flattened_Data_Types    publication_type  \
# 116  Custom-annotated CORD-19 (PubMed) with SIO lin...           nlp_venue
# 45                  Custom-annotated ClinVar abstracts  biomedical_journal
# 45                  Custom-annotated DisGeNET articles  biomedical_journal
# 9                         Custom-annotated PubMed data  biomedical_journal
# 120                       Custom-annotated PubMed data           nlp_venue
# 8                      Custom-annotated PubMed dataset  biomedical_journal
# 53                   Custom-annotated PubMed sentences  biomedical_journal
# 92   Custom-annotated news-PubMed publications dataset           nlp_venue
#
#                                        New annotations  \
# 116  samples consist of sentences and their\ntarget...
# 45   ClinVar: sentence-level triplet of (genetic Va...
# 45   ClinVar: sentence-level triplet of (genetic Va...
# 9    COVID-19 relevance, topic, geolocation and dru...
# 120  a practical use case simulating a search for V...
# 8    Vaccines recognition and normalization dataset...
# 53   sentences labeled for three categories based o...
# 92   collected claims from news paired with researc...
#
#                                      Biomedical Domain  \
# 116               Literature-Based Discovery/ Covid-19
# 45                          Literature-Based Discovery
# 45                          Literature-Based Discovery
# 9                 Literature-Based Discovery/ Covid-19
# 120                         Literature-Based Discovery
# 8                 Literature-Based Discovery/ Covid-19
# 53   Literature-Based Discovery/ Pharma/ Adverse-Dr...
# 92     Media for Health Care/ Health News Verification
#
#                                         Domain Details  \
# 116   selfsupervised grounding of Covid-related med...
# 45    Search engine for retrieving and interpreting...
# 45    Search engine for retrieving and interpreting...
# 9     Information resource for the\nCOVID-19 litera...
# 120    illustrate through a real-world zero-shot te...
# 8     Information resource for the\nCOVID-19 litera...
# 53    automatically identifying relevant publicatio...
# 92    ﬁnd the research publication that supports th...
#
#          Biomedical Domain Main Biomedical Domain Additional
# 116  Literature-Based Discovery                     Covid-19
# 45   Literature-Based Discovery                         None
# 45   Literature-Based Discovery                         None
# 9    Literature-Based Discovery                     Covid-19
# 120  Literature-Based Discovery                         None
# 8    Literature-Based Discovery                     Covid-19
# 53   Literature-Based Discovery   Pharma/ Adverse-Drug-Event
# 92        Media for Health Care     Health News Verification

# %%
custom_datasets_extraction = custom_datasets[custom_datasets["Target application"].str.contains("extraction", case=False, na=False)]
custom_datasets_extraction.sort_values(by="Flattened_Data_Types")
# Out:
#                                                  title  \
# 177  Extracting social determinants of health from ...
# 105  Evidence-based fact-checking of health-related...
# 59   Understanding Clinical Trial Reports: Extracti...
# 94   Fine-grained information extraction from biome...
# 35   EvidenceMap: a three-level knowledge represent...
# 144  Leveraging pre-trained language models for min...
# 155  Algorithmic identification of treatment-emerge...
# 167  SCREENER: Streamlined collaborative learning o...
# 168  RelCurator: a text mining-based curation syste...
# 171    FooDis: A food-disease relation mining pipeline
# 1    Text mining-based word representations for bio...
# 95   Multi-input multi-output sequence labeling for...
# 99   Grantrel: Grant information extraction via joi...
# 100  MedFilter: improving extraction of task-releva...
#
#                           Domain of automated approach  \
# 177  General biomedical text mining: automatic meth...
# 105  Media for Health Care/ Fact Checking: Evidence...
# 59   Literature-Based Discovery: Clinical eveidence...
# 94   Literature-Based Discovery: extract scientiﬁc ...
# 35   Evidence-Based Medicine/ PICO: Automated evide...
# 144  Evidence-Based Medicine: extract microbe-disea...
# 155  Clinical: identify serious adverse events (SAE...
# 167  General biomedical text mining: propose a mode...
# 168  General biomedical text mining: analyzes the t...
# 171  General biomedical text mining: mine abstracts...
# 1    General biomedical text mining/ Genomics: Extr...
# 95   General biomedical text mining: jointly extrac...
# 99   Biomedical Literature Curation: systematic fra...
# 100  General biomedical text mining/ Medical Practi...
#
#                                                journal  \
# 177  Journal of the American Medical Informatics As...
# 105  Association for Computational Linguistics/ Fin...
# 59   AMIA Summits on Translational Science Proceedings
# 94           Association for Computational Linguistics
# 35   Journal of the American Medical Informatics As...
# 144                                 BMC Bioinformatics
# 155                                            medRxiv
# 167                                           Plos one
# 168                                   Genes & Genomics
# 171                Artificial intelligence in medicine
# 1                       PLoS ONE [Electronic Resource]
# 95                                               EMNLP
# 99   Association for Computational Linguistics/ Fin...
# 100                                              EMNLP
#
#                           Data type      Target application  year  \
# 177                  clinical notes  Information Extraction  2023
# 105                       Abstracts  Information Extraction  2021
# 59                        Full-text  Information Extraction  2021
# 94             Abstracts, Full-text  Information Extraction  2021
# 35                        Abstracts  Information Extraction  2023
# 144                       sentences  Information Extraction  2023
# 155                  clinical notes  Information Extraction  2023
# 167             abstract, full-text  Information Extraction  2023
# 168                 title, abstract     Relation Extraction  2023
# 171                        abstract  Information Extraction  2023
# 1    Abstracts, Functional Genomics  Information Extraction  2021
# 95                        Abstracts  Information Extraction  2019
# 99                        Full-text  Information Extraction  2021
# 100                             NaN  Information Extraction  2020
#
#     Data used availability                               Flattened_Data_Types  \
# 177                    NaN                            2 Custom-annotated data
# 105                    yes  Custom-annotated COVID-19 related claims Healt...
# 59                      no                 Custom-annotated EBM-NLP abstracts
# 94                     yes               Custom-annotated PubMed and PMC data
# 35                     yes                       Custom-annotated PubMed data
# 144                    NaN                              Custom-annotated data
# 155                    NaN                              Custom-annotated data
# 167                    NaN                              Custom-annotated data
# 168                    NaN                              Custom-annotated data
# 171                    NaN                              Custom-annotated data
# 1                      NaN                   Custom-annotated from GEO series
# 95                      no                             Custom-anotated BioCFE
# 99                     yes             custom-annotated Grant-SP and Grant-RE
# 100                    yes  custom-annotated transcripts of real and de-id...
#
#        publication_type                                    New annotations  \
# 177  biomedical_journal                                                NaN
# 105           nlp_venue  claims retrieved from the web; annotated  evid...
# 59   biomedical_journal  ICO (intervention, comparator, outcome) elemen...
# 94            nlp_venue  covid-19 papers annotated for fine-grained ent...
# 35   biomedical_journal  PICO elements and their dependencies in RCT ar...
# 144  biomedical_journal                                                NaN
# 155  biomedical_journal                                                NaN
# 167  biomedical_journal                                                NaN
# 168  biomedical_journal                                                NaN
# 171  biomedical_journal                                                NaN
# 1    biomedical_journal  genomic predictors of response and survival in...
# 95            nlp_venue  manually annotated the fact and condition tupl...
# 99            nlp_venue  manually selected the funding sentence and lab...
# 100           nlp_venue  medically-relevant utterances in a given conve...
#
#                                     Biomedical Domain  \
# 177                    General biomedical text mining
# 105              Media for Health Care/ Fact Checking
# 59                         Literature-Based Discovery
# 94                         Literature-Based Discovery
# 35                      Evidence-Based Medicine/ PICO
# 144                           Evidence-Based Medicine
# 155                                          Clinical
# 167                    General biomedical text mining
# 168                    General biomedical text mining
# 171                    General biomedical text mining
# 1            General biomedical text mining/ Genomics
# 95                     General biomedical text mining
# 99                     Biomedical Literature Curation
# 100  General biomedical text mining/ Medical Practice
#
#                                         Domain Details  \
# 177   automatic methods to extract and classify pat...
# 105   Evidence-based Fact-Checking of Health-relate...
# 59    Clinical eveidence extraction (NER), i.e. int...
# 94    extract scientiﬁc entities and events from\nE...
# 35    Automated evidence extraction from randomized...
# 144   extract microbe-disease relationships from bi...
# 155   identify serious adverse events (SAEs) occurr...
# 167   propose a model that learns the document-leve...
# 168   analyzes the title and abstract of PubMed art...
# 171   mine abstracts of biomedical scientific paper...
# 1     Extract gene-gene networks, explore relations...
# 95    jointly extract the fact and condition tuples...
# 99    systematic framework that is capable of autom...
# 100   extract medically relevant utterances from do...
#
#              Biomedical Domain Main Biomedical Domain Additional
# 177  General biomedical text mining                         None
# 105           Media for Health Care                Fact Checking
# 59       Literature-Based Discovery                         None
# 94       Literature-Based Discovery                         None
# 35          Evidence-Based Medicine                         PICO
# 144         Evidence-Based Medicine                         None
# 155                        Clinical                         None
# 167  General biomedical text mining                         None
# 168  General biomedical text mining                         None
# 171  General biomedical text mining                         None
# 1    General biomedical text mining                     Genomics
# 95   General biomedical text mining                         None
# 99   Biomedical Literature Curation                         None
# 100  General biomedical text mining             Medical Practice

# %%
sorted_dataframe = custom_datasets_classification.sort_values(by="Flattened_Data_Types")

# Print the complete text content of "New annotations" column for the first row
print(sorted_dataframe['New annotations'].iloc[9])
# Out:
# if topic is artificial intelligence in nursing - relevant, else not

# %%
custom_datasets['Flattened_Data_Types'].value_counts()
# Out:
# Custom-annotated PubMed data                                                                                         13
# Custom-annotated data                                                                                                 9
# Custom-annotated Elsevier data                                                                                        1
# Custom-annotated TCM-related abstracts                                                                                1
# Custom-annotated news-PubMed publications dataset                                                                     1
# Custom-annotated PubMed and PMC data                                                                                  1
# Custom-anotated BioCFE                                                                                                1
# custom-annotated Grant-SP and Grant-RE                                                                                1
# custom-annotated transcripts of real and de-identiﬁed doctor-patient conversations                                    1
# Custom-annotated ARC, NeurIPS, PubMed dataset                                                                         1
# Custom-annotated preclinical studies                                                                                  1
# Custom-annotated COVID-19 related claims HealthVer                                                                    1
# Custom-annotated Wikipedia articles                                                                                   1
# Custom-annotated health board discussions                                                                             1
# Custom-annotated CORD-19 (PubMed) with SIO links dataset                                                              1
# Custom-annotated CovidLies dataset                                                                                    1
# Custom-annotated COVID-specific tweets                                                                                1
# Custom-annotated dataset of EMBASE                                                                                    1
# Custom-annotated PubMedDS                                                                                             1
# Custom-annotated from GEO series                                                                                      1
# Custom-annotated WikiMed                                                                                              1
# Custom-annotated PubMed dataset                                                                                       1
# Custom sample of articles from PubMed 2017 and 2020                                                                   1
# TREC 2017 Precision Medicine track with custom annotations                                                            1
# Custom-generated MEDLINE dataset                                                                                      1
# Custom-annotated MEDLINE articles                                                                                     1
# Custom-developed PubMed data, EuropePMC, and ClinicalTrials                                                           1
# Custom-annotated ClinVar abstracts                                                                                    1
# Custom-annotated DisGeNET articles                                                                                    1
# Custom-annotated PubMed sentences                                                                                     1
# Custom-annotated abstracts from PubMed (MEDLINE), CINAHL (Ebsco), Web of Science and IEEE                             1
# Custom sample of articles from PubMed Central                                                                         1
# Custom-annotated articles from BioMed Central                                                                         1
# Custom-annotated EBM-NLP abstracts                                                                                    1
# 6000 annotated relations from SemMedDB, 300 custom-annotated abstracts containing 492  relations with DS mentions     1
# Custom-annotated Cochrane Reviews                                                                                     1
# 2 Custom-annotated data                                                                                               1
# Name: Flattened_Data_Types, dtype: int64

# %% [markdown]
# ## Biomedical Domains

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)

# %%
df[['Biomedical Domain', 'Domain Details']] = df['Domain of automated approach'].str.split(':', 1, expand=True)
replace_values = {
    'Literature-Based Discovery': 'Knowledge Management/Literature-Based Discovery',
    'Literature Screening': 'Knowledge Management/Literature Screening',
    'Biomedical Literature Curation': 'Knowledge Management/Literature Curation'
}
df['Biomedical Domain'] = df['Biomedical Domain'].replace(replace_values, regex=True)

# %%
df[['Biomedical Domain Level 1', 'Biomedical Domain Level 2']] = df['Biomedical Domain'].str.split('/', 1, expand=True)
df[['Biomedical Domain Level 2', 'Biomedical Domain Level 3']] = df['Biomedical Domain Level 2'].str.split('/', 1, expand=True)

# %%
replace_values = {
    'Pharma': 'Pharmacology',
    'Evidence-Based Medicine': 'Evidence Synthesis',
    'Biological Functions': 'Biology'
}
df['Biomedical Domain Level 1'] = df['Biomedical Domain Level 1'].replace(replace_values, regex=True)

# %%
df[['Biomedical Domain', 'Biomedical Domain Level 1', 'Biomedical Domain Level 2', 'Biomedical Domain Level 3']]
# Out:
#                                      Biomedical Domain  \
# 0    Knowledge Management/Literature Screening/ Met...
# 1             General biomedical text mining/ Genomics
# 2    Knowledge Management/Literature Screening/ Com...
# 3                        Pharma/ Drug-Drug Interaction
# 4    Knowledge Management/Literature Screening/ Sys...
# 5                       General biomedical text mining
# 6                       General biomedical text mining
# 7    Knowledge Management/Literature Screening/ PIC...
# 8    Knowledge Management/Literature-Based Discover...
# 9    Knowledge Management/Literature-Based Discover...
# 10                Pharma/ Chemical-Disease Interaction
# 11                      General biomedical text mining
# 12   Knowledge Management/Literature Screening/ Sys...
# 13   Knowledge Management/Literature-Based Discover...
# 14                       Pharma/ Drug-Drug Interaction
# 15                                Biological Functions
# 16                      General biomedical text mining
# 17                      General biomedical text mining
# 18                      General biomedical text mining
# 19   Knowledge Management/Literature-Based Discover...
# 20                         Clinical/ Document Curation
# 21                            Pharma/ Pharmacokinetics
# 22   Knowledge Management/Literature-Based Discover...
# 23                      General biomedical text mining
# 24                           Pharma/Adverse-Drug-Event
# 25   Knowledge Management/Literature Screening/ Sys...
# 26                      General biomedical text mining
# 27   Knowledge Management/Literature-Based Discover...
# 28   Pharma/ Adverse-Drug-Event/ Media for Health Care
# 29                      General biomedical text mining
# 30                      General biomedical text mining
# 31   Knowledge Management/Literature-Based Discover...
# 32                       Pharma/ Drug-Drug Interaction
# 33   Media for Health Care/ Standardizing medical l...
# 34                      General biomedical text mining
# 35                       Evidence-Based Medicine/ PICO
# 36   Evidence-Based Medicine/ Understanding free-te...
# 37     Knowledge Management/Literature-Based Discovery
# 38   Knowledge Management/Literature Curation/ RCT ...
# 39   Knowledge Management/Literature Screening/ Top...
# 40            Knowledge Management/Literature Curation
# 41                      General biomedical text mining
# 42                      General biomedical text mining
# 43                      General biomedical text mining
# 44                            Pharma/ Drug Repurposing
# 45     Knowledge Management/Literature-Based Discovery
# 46                      General biomedical text mining
# 47                      General biomedical text mining
# 48                          Pharma/ Adverse-Drug-Event
# 49                Pharma/ Chemical-Disease Interaction
# 50   General biomedical text mining/ Genetics/ Phen...
# 51                      General biomedical text mining
# 52                         Clinical/ Document Curation
# 53   Knowledge Management/Literature-Based Discover...
# 54   Knowledge Management/Literature Screening/ Sys...
# 55     Knowledge Management/Literature-Based Discovery
# 56     Knowledge Management/Literature-Based Discovery
# 57   Evidence-Based Medicine/ Meta-Analysis/ Cancer...
# 58                      General biomedical text mining
# 59     Knowledge Management/Literature-Based Discovery
# 60     Knowledge Management/Literature-Based Discovery
# 61   Knowledge Management/Literature Screening/ PIO...
# 62   General biomedical text mining/ Genetics/ Phen...
# 63   Knowledge Management/Literature Screening/ RCT...
# 64   Knowledge Management/Literature Screening/ Cov...
# 65   Knowledge Management/Literature-Based Discover...
# 66                      General biomedical text mining
# 67                            Pharma/ Drug Repurposing
# 68                       Pharma/ Drug-Drug Interaction
# 69              Pharma/ Multiple Relations Exatraction
# 70                       Clinical/ Insights Generation
# 71          Pharma/ Drug Discovery/ Precision Medicine
# 72                      General biomedical text mining
# 73          Pharma/ Drug Discovery/ Precision Medicine
# 74   Evidence-Based Medicine/ Research Quality Appr...
# 75                              Clinical/ Data Privacy
# 76   Knowledge Management/Literature Screening/ Sys...
# 77   Knowledge Management/Literature Screening/ Stu...
# 78                      General biomedical text mining
# 79   Knowledge Management/Literature Curation/ Risk...
# 80   Knowledge Management/Literature Screening/ Sys...
# 81   Knowledge Management/Literature-Based Discover...
# 82                      General biomedical text mining
# 83                       Pharma/ Drug-Drug Interaction
# 84     Knowledge Management/Literature-Based Discovery
# 85                            Pharma/ Drug Repurposing
# 86                      General biomedical text mining
# 87   Knowledge Management/Literature-Based Discover...
# 88                      General biomedical text mining
# 89                      General biomedical text mining
# 90                      General biomedical text mining
# 91                      General biomedical text mining
# 92                Media for Health Care/ Fact Checking
# 93   Knowledge Management/Literature-Based Discover...
# 94     Knowledge Management/Literature-Based Discovery
# 95                      General biomedical text mining
# 96            General biomedical text mining/ Clinical
# 97                              Clinical/ Data Privacy
# 98   Knowledge Management/Literature-Based Discover...
# 99            Knowledge Management/Literature Curation
# 100   General biomedical text mining/ Medical Practice
# 101           Knowledge Management/Literature Curation
# 102  Knowledge Management/Literature Curation/ Covi...
# 103           Knowledge Management/Literature Curation
# 104                             Pharma/ Drug Discovery
# 105               Media for Health Care/ Fact Checking
# 106           General biomedical text mining/ Clinical
# 107                       Clinical/ Outcome Prediction
# 108               Media for Health Care/ Fact Checking
# 109                            Evidence-Based Medicine
# 110                     General biomedical text mining
# 111           Media for Health Care/ Emotion Detection
# 112  Knowledge Management/Literature Curation/ Elec...
# 113                     General biomedical text mining
# 114                     General biomedical text mining
# 115    Knowledge Management/Literature-Based Discovery
# 116  Knowledge Management/Literature-Based Discover...
# 117               Media for Health Care/ Fact Checking
# 118  Media for Health Care/ Covid-19 Content Identi...
# 119          Media for Health Care/ Sentiment Analysis
# 120    Knowledge Management/Literature-Based Discovery
# 121                     General biomedical text mining
# 122  Knowledge Management/Literature-Based Discover...
# 123                     General biomedical text mining
# 124                     General biomedical text mining
# 125     Media for Health Care/ Mental Health Screening
# 126                       Clinical/ Outcome Prediction
# 127                        Clinical/ Disease Detection
# 128                     General biomedical text mining
# 129                     General biomedical text mining
# 130     Media for Health Care/ Mental Health Screening
# 131                Clinical/ Mental Disorder Detection
# 132                       Clinical/ Outcome Prediction
# 133                     General biomedical text mining
# 134                     General biomedical text mining
# 135    Knowledge Management/Literature-Based Discovery
# 136                     General biomedical text mining
# 137                Clinical/ Mental Disorder Detection
# 138     Media for Health Care/ Mental Health Screening
# 139  Media for Health Care/ Self-Disclosure Assessment
# 140                     Pharma/ Processing Drug Labels
# 141                        Clinical/ Document Curation
# 142                     General biomedical text mining
# 143                     General biomedical text mining
# 144                            Evidence-Based Medicine
# 145  Knowledge Management/Literature Curation/ Syst...
# 146                Clinical/ Mental Disorder Detection
# 147                            Evidence-Based Medicine
# 148                       Clinical/ Outcome Prediction
# 149                            Evidence-Based Medicine
# 150           Knowledge Management/Literature Curation
# 151  Knowledge Management/Literature Screening/ Sys...
# 152                    Pharma/ Drug-Target Interaction
# 153                     General biomedical text mining
# 154                               Biological Functions
# 155                         Pharma/ Adverse-Drug-Event
# 156                               Biological Functions
# 157                     General biomedical text mining
# 158                     General biomedical text mining
# 159                     General biomedical text mining
# 160          Knowledge Management/Literature Screening
# 161                     General biomedical text mining
# 162                     General biomedical text mining
# 163    Knowledge Management/Literature-Based Discovery
# 164                      Pharma/ Drug-Drug Interaction
# 165               Pharma/ Chemical-Disease Interaction
# 166                            Evidence-Based Medicine
# 167                     General biomedical text mining
# 168                     General biomedical text mining
# 169          Knowledge Management/Literature Screening
# 170                            Evidence-Based Medicine
# 171    Knowledge Management/Literature-Based Discovery
# 172           Clinical/ Physical Status Classification
# 173                        Clinical/ Disease Detection
# 174                     Pharma/ Processing Drug Labels
# 175    Knowledge Management/Literature-Based Discovery
# 176            Media for Health Care/ Health Education
# 177                       Clinical/ Outcome Prediction
# 178                        Clinical/ Document Curation
# 179                     General biomedical text mining
# 180  Evidence-Based Medicine/ Research Quality Appr...
# 181                Clinical/ Mental Disorder Detection
# 182                Clinical/ Mental Disorder Detection
# 183                        Clinical/ Disease Detection
# 184                               Biological Functions
# 185                               Biological Functions
# 186           Knowledge Management/Literature Curation
# 187                      Clinical/ Insights Generation
# 188           Knowledge Management/Literature Curation
# 189                     General biomedical text mining
# 190                Clinical/ Mental Disorder Detection
# 191     Media for Health Care/ Mental Health Screening
# 192           Knowledge Management/Literature Curation
# 193           Knowledge Management/Literature Curation
# 194    Knowledge Management/Literature-Based Discovery
# 195           Knowledge Management/Literature Curation
#
#           Biomedical Domain Level 1          Biomedical Domain Level 2  \
# 0              Knowledge Management               Literature Screening
# 1    General biomedical text mining                           Genomics
# 2              Knowledge Management               Literature Screening
# 3                      Pharmacology              Drug-Drug Interaction
# 4              Knowledge Management               Literature Screening
# 5    General biomedical text mining                               None
# 6    General biomedical text mining                               None
# 7              Knowledge Management               Literature Screening
# 8              Knowledge Management         Literature-Based Discovery
# 9              Knowledge Management         Literature-Based Discovery
# 10                     Pharmacology       Chemical-Disease Interaction
# 11   General biomedical text mining                               None
# 12             Knowledge Management               Literature Screening
# 13             Knowledge Management         Literature-Based Discovery
# 14                     Pharmacology              Drug-Drug Interaction
# 15                          Biology                               None
# 16   General biomedical text mining                               None
# 17   General biomedical text mining                               None
# 18   General biomedical text mining                               None
# 19             Knowledge Management         Literature-Based Discovery
# 20                         Clinical                  Document Curation
# 21                     Pharmacology                   Pharmacokinetics
# 22             Knowledge Management         Literature-Based Discovery
# 23   General biomedical text mining                               None
# 24                     Pharmacology                 Adverse-Drug-Event
# 25             Knowledge Management               Literature Screening
# 26   General biomedical text mining                               None
# 27             Knowledge Management         Literature-Based Discovery
# 28                     Pharmacology                 Adverse-Drug-Event
# 29   General biomedical text mining                               None
# 30   General biomedical text mining                               None
# 31             Knowledge Management         Literature-Based Discovery
# 32                     Pharmacology              Drug-Drug Interaction
# 33            Media for Health Care     Standardizing medical language
# 34   General biomedical text mining                               None
# 35               Evidence Synthesis                               PICO
# 36               Evidence Synthesis   Understanding free-text evidence
# 37             Knowledge Management         Literature-Based Discovery
# 38             Knowledge Management                Literature Curation
# 39             Knowledge Management               Literature Screening
# 40             Knowledge Management                Literature Curation
# 41   General biomedical text mining                               None
# 42   General biomedical text mining                               None
# 43   General biomedical text mining                               None
# 44                     Pharmacology                   Drug Repurposing
# 45             Knowledge Management         Literature-Based Discovery
# 46   General biomedical text mining                               None
# 47   General biomedical text mining                               None
# 48                     Pharmacology                 Adverse-Drug-Event
# 49                     Pharmacology       Chemical-Disease Interaction
# 50   General biomedical text mining                           Genetics
# 51   General biomedical text mining                               None
# 52                         Clinical                  Document Curation
# 53             Knowledge Management         Literature-Based Discovery
# 54             Knowledge Management               Literature Screening
# 55             Knowledge Management         Literature-Based Discovery
# 56             Knowledge Management         Literature-Based Discovery
# 57               Evidence Synthesis                      Meta-Analysis
# 58   General biomedical text mining                               None
# 59             Knowledge Management         Literature-Based Discovery
# 60             Knowledge Management         Literature-Based Discovery
# 61             Knowledge Management               Literature Screening
# 62   General biomedical text mining                           Genetics
# 63             Knowledge Management               Literature Screening
# 64             Knowledge Management               Literature Screening
# 65             Knowledge Management         Literature-Based Discovery
# 66   General biomedical text mining                               None
# 67                     Pharmacology                   Drug Repurposing
# 68                     Pharmacology              Drug-Drug Interaction
# 69                     Pharmacology     Multiple Relations Exatraction
# 70                         Clinical                Insights Generation
# 71                     Pharmacology                     Drug Discovery
# 72   General biomedical text mining                               None
# 73                     Pharmacology                     Drug Discovery
# 74               Evidence Synthesis         Research Quality Appraisal
# 75                         Clinical                       Data Privacy
# 76             Knowledge Management               Literature Screening
# 77             Knowledge Management               Literature Screening
# 78   General biomedical text mining                               None
# 79             Knowledge Management                Literature Curation
# 80             Knowledge Management               Literature Screening
# 81             Knowledge Management         Literature-Based Discovery
# 82   General biomedical text mining                               None
# 83                     Pharmacology              Drug-Drug Interaction
# 84             Knowledge Management         Literature-Based Discovery
# 85                     Pharmacology                   Drug Repurposing
# 86   General biomedical text mining                               None
# 87             Knowledge Management         Literature-Based Discovery
# 88   General biomedical text mining                               None
# 89   General biomedical text mining                               None
# 90   General biomedical text mining                               None
# 91   General biomedical text mining                               None
# 92            Media for Health Care                      Fact Checking
# 93             Knowledge Management         Literature-Based Discovery
# 94             Knowledge Management         Literature-Based Discovery
# 95   General biomedical text mining                               None
# 96   General biomedical text mining                           Clinical
# 97                         Clinical                       Data Privacy
# 98             Knowledge Management         Literature-Based Discovery
# 99             Knowledge Management                Literature Curation
# 100  General biomedical text mining                   Medical Practice
# 101            Knowledge Management                Literature Curation
# 102            Knowledge Management                Literature Curation
# 103            Knowledge Management                Literature Curation
# 104                    Pharmacology                     Drug Discovery
# 105           Media for Health Care                      Fact Checking
# 106  General biomedical text mining                           Clinical
# 107                        Clinical                 Outcome Prediction
# 108           Media for Health Care                      Fact Checking
# 109              Evidence Synthesis                               None
# 110  General biomedical text mining                               None
# 111           Media for Health Care                  Emotion Detection
# 112            Knowledge Management                Literature Curation
# 113  General biomedical text mining                               None
# 114  General biomedical text mining                               None
# 115            Knowledge Management         Literature-Based Discovery
# 116            Knowledge Management         Literature-Based Discovery
# 117           Media for Health Care                      Fact Checking
# 118           Media for Health Care    Covid-19 Content Identification
# 119           Media for Health Care                 Sentiment Analysis
# 120            Knowledge Management         Literature-Based Discovery
# 121  General biomedical text mining                               None
# 122            Knowledge Management         Literature-Based Discovery
# 123  General biomedical text mining                               None
# 124  General biomedical text mining                               None
# 125           Media for Health Care            Mental Health Screening
# 126                        Clinical                 Outcome Prediction
# 127                        Clinical                  Disease Detection
# 128  General biomedical text mining                               None
# 129  General biomedical text mining                               None
# 130           Media for Health Care            Mental Health Screening
# 131                        Clinical          Mental Disorder Detection
# 132                        Clinical                 Outcome Prediction
# 133  General biomedical text mining                               None
# 134  General biomedical text mining                               None
# 135            Knowledge Management         Literature-Based Discovery
# 136  General biomedical text mining                               None
# 137                        Clinical          Mental Disorder Detection
# 138           Media for Health Care            Mental Health Screening
# 139           Media for Health Care         Self-Disclosure Assessment
# 140                    Pharmacology             Processing Drug Labels
# 141                        Clinical                  Document Curation
# 142  General biomedical text mining                               None
# 143  General biomedical text mining                               None
# 144              Evidence Synthesis                               None
# 145            Knowledge Management                Literature Curation
# 146                        Clinical          Mental Disorder Detection
# 147              Evidence Synthesis                               None
# 148                        Clinical                 Outcome Prediction
# 149              Evidence Synthesis                               None
# 150            Knowledge Management                Literature Curation
# 151            Knowledge Management               Literature Screening
# 152                    Pharmacology            Drug-Target Interaction
# 153  General biomedical text mining                               None
# 154                         Biology                               None
# 155                    Pharmacology                 Adverse-Drug-Event
# 156                         Biology                               None
# 157  General biomedical text mining                               None
# 158  General biomedical text mining                               None
# 159  General biomedical text mining                               None
# 160            Knowledge Management               Literature Screening
# 161  General biomedical text mining                               None
# 162  General biomedical text mining                               None
# 163            Knowledge Management         Literature-Based Discovery
# 164                    Pharmacology              Drug-Drug Interaction
# 165                    Pharmacology       Chemical-Disease Interaction
# 166              Evidence Synthesis                               None
# 167  General biomedical text mining                               None
# 168  General biomedical text mining                               None
# 169            Knowledge Management               Literature Screening
# 170              Evidence Synthesis                               None
# 171            Knowledge Management         Literature-Based Discovery
# 172                        Clinical     Physical Status Classification
# 173                        Clinical                  Disease Detection
# 174                    Pharmacology             Processing Drug Labels
# 175            Knowledge Management         Literature-Based Discovery
# 176           Media for Health Care                   Health Education
# 177                        Clinical                 Outcome Prediction
# 178                        Clinical                  Document Curation
# 179  General biomedical text mining                               None
# 180              Evidence Synthesis         Research Quality Appraisal
# 181                        Clinical          Mental Disorder Detection
# 182                        Clinical          Mental Disorder Detection
# 183                        Clinical                  Disease Detection
# 184                         Biology                               None
# 185                         Biology                               None
# 186            Knowledge Management                Literature Curation
# 187                        Clinical                Insights Generation
# 188            Knowledge Management                Literature Curation
# 189  General biomedical text mining                               None
# 190                        Clinical          Mental Disorder Detection
# 191           Media for Health Care            Mental Health Screening
# 192            Knowledge Management                Literature Curation
# 193            Knowledge Management                Literature Curation
# 194            Knowledge Management         Literature-Based Discovery
# 195            Knowledge Management                Literature Curation
#
#                              Biomedical Domain Level 3
# 0                               Methodological Quality
# 1                                                 None
# 2     Combination of Selection Criteria/ Knowledge ...
# 3                                                 None
# 4     Systematic Reviews/ Moxibustion for improving...
# 5                                                 None
# 6                                                 None
# 7     PICO Recognition/  Knowledge Management/Liter...
# 8                                             Covid-19
# 9                                             Covid-19
# 10                                                None
# 11                                                None
# 12                    Systematic Reviews/ Neurosurgery
# 13    Thematically Coherent Biomedical Documents/ S...
# 14                                                None
# 15                                                None
# 16                                                None
# 17                                                None
# 18                                                None
# 19                                            Covid-19
# 20                                                None
# 21                                                None
# 22                                  Precision Medicine
# 23                                                None
# 24                                                None
# 25                      Systematic Reviews/ Teratology
# 26                                                None
# 27                Clinical causal knowledge extraction
# 28                               Media for Health Care
# 29                                                None
# 30                                                None
# 31       Systematic Reviews/ Pathogen Characterisation
# 32                                                None
# 33                                                None
# 34                                                None
# 35                                                None
# 36                                                None
# 37                                                None
# 38                                        RCT Articles
# 39    Topic Subclasses/ COVID-19 Articles/ Knowledg...
# 40                                                None
# 41                                                None
# 42                                                None
# 43                                                None
# 44                                                None
# 45                                                None
# 46                                                None
# 47                                                None
# 48                                                None
# 49                                                None
# 50                                           Phenotype
# 51                                                None
# 52                                                None
# 53                          Pharma/ Adverse-Drug-Event
# 54                         Systematic Reviews/ Nursing
# 55                                                None
# 56                                                None
# 57                          Cancer/ Systematic Reviews
# 58                                                None
# 59                                                None
# 60                                                None
# 61    PIO Recognition/ Knowledge Management/Literat...
# 62                                           Phenotype
# 63    RCTs on sodium-glucose co-transporter-2 inhib...
# 64                                            Covid-19
# 65                                           Dietology
# 66                                                None
# 67                                                None
# 68                                                None
# 69                                                None
# 70                                                None
# 71                                  Precision Medicine
# 72                                                None
# 73                                  Precision Medicine
# 74                                  Systematic Reviews
# 75                                                None
# 76          Systematic Reviews/ Clinical interventions
# 77    Study Type/ Knowledge Management/Literature C...
# 78                                                None
# 79                    Risk Of Bias/ Systematic Reviews
# 80      Systematic Reviews/ Adverse-Drug-Event/ Pharma
# 81                                              Stroke
# 82                                                None
# 83                                                None
# 84                                                None
# 85                                                None
# 86                                                None
# 87                                  Precision medicine
# 88                                                None
# 89                                                None
# 90                                                None
# 91                                                None
# 92                                                None
# 93                                            Covid-19
# 94                                                None
# 95                                                None
# 96                                                None
# 97                                                None
# 98                                            Covid-19
# 99                                                None
# 100                                               None
# 101                                               None
# 102                                           Covid-19
# 103                                               None
# 104                                               None
# 105                                               None
# 106                                               None
# 107                                               None
# 108                                               None
# 109                                               None
# 110                                               None
# 111                                               None
# 112                          Electronic Health Records
# 113                                               None
# 114                                               None
# 115                                               None
# 116                                           Covid-19
# 117                                               None
# 118                                               None
# 119                                               None
# 120                                               None
# 121                                               None
# 122   Multi-document summarisation of Medical studi...
# 123                                               None
# 124                                               None
# 125                                               None
# 126                                               None
# 127                                               None
# 128                                               None
# 129                                               None
# 130                                               None
# 131                                               None
# 132                                               None
# 133                                               None
# 134                                               None
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
# 144                                               None
# 145                                 Systematic Reviews
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
# 151                                 Systematic Reviews
# 152                                               None
# 153                                               None
# 154                                               None
# 155                                               None
# 156                                               None
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
# 164                                               None
# 165                                               None
# 166                                               None
# 167                                               None
# 168                                               None
# 169                                               None
# 170                                               None
# 171                                               None
# 172                                               None
# 173                                               None
# 174                                               None
# 175                                               None
# 176                                               None
# 177                                               None
# 178                                               None
# 179                                               None
# 180                                               None
# 181                                               None
# 182                                               None
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
# 187                                               None
# 188                                               None
# 189                                               None
# 190                                               None
# 191                                               None
# 192                                               None
# 193                                               None
# 194                                               None
# 195                                               None

# %%
import textwrap

# %%
# Count the frequency of each category
#df['Biomedical Domain Main'] = df['Biomedical Domain Main'].replace("General biomedical text mining", "General biomedical \ntext mining")
#df['Biomedical Domain Main'] = df['Biomedical Domain Main'].replace("Biomedicla Literature Curation", "Biomedicla Literature \nCuration")
#df['Biomedical Domain Main'] = df['Biomedical Domain Main'].replace("Literature-Based Discovery", "Literature-Based \nDiscovery")

category_counts = df['Biomedical Domain Level 1'].value_counts()
top_n = 11

# Get the top 10 categories
top_10_categories = category_counts#.head(top_n) SHOW ALL!

# Sort the categories in descending order
top_10_categories = top_10_categories.sort_values(ascending=True)

# Transpose the DataFrame
top_10_categories = top_10_categories.transpose()


# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_categories.index, top_10_categories, color='lightgrey')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('Biomedical Domain', fontsize=15)
plt.title('Number of Articles per Domain', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/number_of_papers_domain_count_2024.pdf'.format(top_n))

# Display the chart
plt.show()

# %%
sum(category_counts)
# Out:
# 196

# %%
filtered_df = df[(df['Biomedical Domain Level 1'] == 'Knowledge Management') | (df['Biomedical Domain Level 1'] == 'Pharmacology') | (df['Biomedical Domain Level 1'] == 'Media for Health Care')| (df['Biomedical Domain Level 1'] == 'Clinical')]
filtered_df = filtered_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
filtered_df['Biomedical Domain Level 2'].fillna("missing", inplace=True)

# %%
filtered_df[['doi','Biomedical Domain Level 1', 'Biomedical Domain Level 2']]
# Out:
#                                      doi Biomedical Domain Level 1  \
# 0                          10.2196/29398      Knowledge Management
# 2              10.1016/j.jbi.2020.103578      Knowledge Management
# 3         10.1093/bioinformatics/btac754              Pharmacology
# 4             10.1186/s13643-021-01763-w      Knowledge Management
# 7              10.1186/s12911-019-0992-8      Knowledge Management
# 8                   10.1093/nar/gkac1005      Knowledge Management
# 9                    10.1093/nar/gkaa952      Knowledge Management
# 10               10.1093/database/baz116              Pharmacology
# 12                    10.3233/SHTI210125      Knowledge Management
# 13                10.3390/ijerph19105893      Knowledge Management
# 14            10.1186/s12859-022-04876-8              Pharmacology
# 19    10.1016/j.compbiolchem.2022.107808      Knowledge Management
# 20             10.1109/JBHI.2021.3062322                  Clinical
# 21      10.12688/wellcomeopenres.16718.1              Pharmacology
# 22                                   NaN      Knowledge Management
# 24                                   NaN              Pharmacology
# 25        10.1016/j.reprotox.2022.09.001      Knowledge Management
# 27             10.1016/j.jbi.2021.103932      Knowledge Management
# 28                  10.1155/2021/5589829              Pharmacology
# 31            10.1186/s13326-023-00282-y      Knowledge Management
# 32             10.1101/2022.08.31.506076              Pharmacology
# 33          10.1016/j.artmed.2021.102008     Media for Health Care
# 37              10.1093/database/baac104      Knowledge Management
# 38          10.1371/journal.pone.0283342      Knowledge Management
# 39             10.1101/2023.01.18.524571      Knowledge Management
# 40            10.1007/s00521-021-06053-z      Knowledge Management
# 44            10.1186/s12911-021-01614-7              Pharmacology
# 45                   10.1093/nar/gkac310      Knowledge Management
# 48                                   NaN              Pharmacology
# 49             10.1016/j.jbi.2021.103874              Pharmacology
# 52                         10.2196/22508                  Clinical
# 53            10.1186/s12911-022-02085-0      Knowledge Management
# 54                    10.3233/SHTI220155      Knowledge Management
# 55             10.1016/j.jbi.2020.103452      Knowledge Management
# 56            10.1016/j.cmpb.2019.105117      Knowledge Management
# 59                                   NaN      Knowledge Management
# 60               10.1093/database/baz137      Knowledge Management
# 61           10.1101/2022.02.24.22268947      Knowledge Management
# 63        10.1016/j.jclinepi.2021.01.010      Knowledge Management
# 64            10.1007/s10844-022-00768-8      Knowledge Management
# 65             10.1016/j.jbi.2022.104120      Knowledge Management
# 67             10.1016/j.jbi.2021.103902              Pharmacology
# 68            10.1186/s12859-022-05083-1              Pharmacology
# 69            10.1186/s12859-022-04642-w              Pharmacology
# 70                  10.1155/2020/5491963                  Clinical
# 71        10.1093/bioinformatics/btaa491              Pharmacology
# 73             10.1016/j.jbi.2020.103392              Pharmacology
# 75                                   NaN                  Clinical
# 76             10.1016/j.jbi.2022.104185      Knowledge Management
# 77           10.1101/2022.11.01.22281685      Knowledge Management
# 79                     10.1002/jrsm.1533      Knowledge Management
# 80                     10.1111/cts.13268      Knowledge Management
# 81            10.1186/s12859-021-04292-4      Knowledge Management
# 83          10.1016/j.artmed.2021.102153              Pharmacology
# 84            10.1038/s41467-022-28494-3      Knowledge Management
# 85             10.1016/j.jbi.2021.103696              Pharmacology
# 87            10.1186/s12859-022-05116-9      Knowledge Management
# 92       10.18653/v1/2020.emnlp-main.139     Media for Health Care
# 93                                   NaN      Knowledge Management
# 94         10.18653/v1/2021.acl-long.489      Knowledge Management
# 97       10.18653/v1/2020.emnlp-main.165                  Clinical
# 98      10.18653/v1/2020.nlpcovid19-2.15      Knowledge Management
# 99                                   NaN      Knowledge Management
# 101      10.18653/v1/2020.emnlp-main.431      Knowledge Management
# 102      10.18653/v1/2020.nlpcovid19-2.2      Knowledge Management
# 103                 10.18653/v1/D19-1524      Knowledge Management
# 104                 10.18653/v1/D19-5711              Pharmacology
# 105  10.18653/v1/2021.findings-emnlp.297     Media for Health Care
# 107      10.18653/v1/2020.emnlp-main.115                  Clinical
# 108  10.18653/v1/2020.findings-emnlp.216     Media for Health Care
# 111      10.18653/v1/2020.emnlp-main.715     Media for Health Care
# 112                 10.18653/v1/D19-1492      Knowledge Management
# 115      10.18653/v1/2020.nlpcovid19-2.3      Knowledge Management
# 116                                  NaN      Knowledge Management
# 117     10.18653/v1/2020.nlpcovid19-2.11     Media for Health Care
# 118           10.18653/v1/2020.wnut-1.66     Media for Health Care
# 119   10.18653/v1/2021.findings-emnlp.27     Media for Health Care
# 120      10.18653/v1/2020.nlpcovid19-2.9      Knowledge Management
# 122                                  NaN      Knowledge Management
# 125      10.18653/v1/2020.emnlp-main.619     Media for Health Care
# 126                                  NaN                  Clinical
# 127                                  NaN                  Clinical
# 130        10.18653/v1/2022.acl-short.70     Media for Health Care
# 131                                  NaN                  Clinical
# 132                                  NaN                  Clinical
# 135  10.18653/v1/2021.findings-emnlp.312      Knowledge Management
# 137                                  NaN                  Clinical
# 138                                  NaN     Media for Health Care
# 139     10.18653/v1/2022.findings-acl.83     Media for Health Care
# 140                  10.1093/bib/bbad226              Pharmacology
# 141         10.18653/v1/2023.bionlp-1.54                  Clinical
# 145                10.1093/jamia/ocad190      Knowledge Management
# 146  10.18653/v1/2023.findings-emnlp.474                  Clinical
# 148           10.1186/s12859-023-05439-1                  Clinical
# 150           10.1186/s13326-023-00292-w      Knowledge Management
# 151           10.1186/s13643-023-02353-8      Knowledge Management
# 152            10.1101/2023.07.24.550359              Pharmacology
# 155          10.1101/2023.09.06.23295149              Pharmacology
# 160            10.1101/2023.01.18.524571      Knowledge Management
# 163            10.1016/j.jbi.2023.104382      Knowledge Management
# 164           10.1186/s12859-023-05520-9              Pharmacology
# 165           10.3389/fphar.2023.1205144              Pharmacology
# 169           10.1186/s12911-023-02328-8      Knowledge Management
# 171         10.1016/j.artmed.2023.102586      Knowledge Management
# 172           10.1186/s12871-023-02248-0                  Clinical
# 173          10.1101/2023.03.01.23286659                  Clinical
# 174       10.1021/acs.chemrestox.3c00028              Pharmacology
# 175                   10.3233/SHTI230710      Knowledge Management
# 176           10.3389/fpsyt.2023.1258887     Media for Health Care
# 177                10.1093/jamia/ocad071                  Clinical
# 178                10.1148/radiol.231362                  Clinical
# 181           10.3389/fpsyt.2023.1213141                  Clinical
# 182          10.1101/2023.06.27.23291884                  Clinical
# 183            10.1016/j.jbi.2023.104417                  Clinical
# 186       10.1093/bioinformatics/btad440      Knowledge Management
# 187           10.1038/s41598-023-45758-0                  Clinical
# 188  10.18653/v1/2023.findings-emnlp.586      Knowledge Management
# 190         10.1016/j.neucom.2023.126413                  Clinical
# 191                        10.2196/49074     Media for Health Care
# 192           10.3389/fninf.2023.1215261      Knowledge Management
# 193  10.18653/v1/2023.findings-emnlp.781      Knowledge Management
# 194            10.1101/2023.05.30.542911      Knowledge Management
# 195           10.1038/s41598-023-32915-8      Knowledge Management
#
#            Biomedical Domain Level 2
# 0               Literature Screening
# 2               Literature Screening
# 3              Drug-Drug Interaction
# 4               Literature Screening
# 7               Literature Screening
# 8         Literature-Based Discovery
# 9         Literature-Based Discovery
# 10      Chemical-Disease Interaction
# 12              Literature Screening
# 13        Literature-Based Discovery
# 14             Drug-Drug Interaction
# 19        Literature-Based Discovery
# 20                 Document Curation
# 21                  Pharmacokinetics
# 22        Literature-Based Discovery
# 24                Adverse-Drug-Event
# 25              Literature Screening
# 27        Literature-Based Discovery
# 28                Adverse-Drug-Event
# 31        Literature-Based Discovery
# 32             Drug-Drug Interaction
# 33    Standardizing medical language
# 37        Literature-Based Discovery
# 38               Literature Curation
# 39              Literature Screening
# 40               Literature Curation
# 44                  Drug Repurposing
# 45        Literature-Based Discovery
# 48                Adverse-Drug-Event
# 49      Chemical-Disease Interaction
# 52                 Document Curation
# 53        Literature-Based Discovery
# 54              Literature Screening
# 55        Literature-Based Discovery
# 56        Literature-Based Discovery
# 59        Literature-Based Discovery
# 60        Literature-Based Discovery
# 61              Literature Screening
# 63              Literature Screening
# 64              Literature Screening
# 65        Literature-Based Discovery
# 67                  Drug Repurposing
# 68             Drug-Drug Interaction
# 69    Multiple Relations Exatraction
# 70               Insights Generation
# 71                    Drug Discovery
# 73                    Drug Discovery
# 75                      Data Privacy
# 76              Literature Screening
# 77              Literature Screening
# 79               Literature Curation
# 80              Literature Screening
# 81        Literature-Based Discovery
# 83             Drug-Drug Interaction
# 84        Literature-Based Discovery
# 85                  Drug Repurposing
# 87        Literature-Based Discovery
# 92                     Fact Checking
# 93        Literature-Based Discovery
# 94        Literature-Based Discovery
# 97                      Data Privacy
# 98        Literature-Based Discovery
# 99               Literature Curation
# 101              Literature Curation
# 102              Literature Curation
# 103              Literature Curation
# 104                   Drug Discovery
# 105                    Fact Checking
# 107               Outcome Prediction
# 108                    Fact Checking
# 111                Emotion Detection
# 112              Literature Curation
# 115       Literature-Based Discovery
# 116       Literature-Based Discovery
# 117                    Fact Checking
# 118  Covid-19 Content Identification
# 119               Sentiment Analysis
# 120       Literature-Based Discovery
# 122       Literature-Based Discovery
# 125          Mental Health Screening
# 126               Outcome Prediction
# 127                Disease Detection
# 130          Mental Health Screening
# 131        Mental Disorder Detection
# 132               Outcome Prediction
# 135       Literature-Based Discovery
# 137        Mental Disorder Detection
# 138          Mental Health Screening
# 139       Self-Disclosure Assessment
# 140           Processing Drug Labels
# 141                Document Curation
# 145              Literature Curation
# 146        Mental Disorder Detection
# 148               Outcome Prediction
# 150              Literature Curation
# 151             Literature Screening
# 152          Drug-Target Interaction
# 155               Adverse-Drug-Event
# 160             Literature Screening
# 163       Literature-Based Discovery
# 164            Drug-Drug Interaction
# 165     Chemical-Disease Interaction
# 169             Literature Screening
# 171       Literature-Based Discovery
# 172   Physical Status Classification
# 173                Disease Detection
# 174           Processing Drug Labels
# 175       Literature-Based Discovery
# 176                 Health Education
# 177               Outcome Prediction
# 178                Document Curation
# 181        Mental Disorder Detection
# 182        Mental Disorder Detection
# 183                Disease Detection
# 186              Literature Curation
# 187              Insights Generation
# 188              Literature Curation
# 190        Mental Disorder Detection
# 191          Mental Health Screening
# 192              Literature Curation
# 193              Literature Curation
# 194       Literature-Based Discovery
# 195              Literature Curation

# %%
import plotly.express as px

# Create a sunburst chart
fig = px.sunburst(filtered_df, path=['Biomedical Domain Level 1', 'Biomedical Domain Level 2'])

# Update layout for better readability
fig.update_layout(margin=dict(t=0, l=0, r=0, b=0))

# Show the chart
fig.show()

# %%
from collections import defaultdict

category_counts = defaultdict(lambda: defaultdict(int))

# Iterate over the DataFrame rows
for _, row in filtered_df.iterrows():
    # Increment the count of the (Level 1, Level 2) pair
    category_counts[row['Biomedical Domain Level 1']][row['Biomedical Domain Level 2']] += 1

# Convert the defaultdict to a regular dict and sort the subcategories by count, descending
categories = {lvl1: sorted(lvl2.items(), key=lambda item: item[1], reverse=True)
               for lvl1, lvl2 in category_counts.items()}

# %%
import matplotlib.pyplot as plt

# Define colors for each main category
category_colors = {'Knowledge Management': 'gray', 'Pharmacology': 'steelblue', 'Clinical': 'mediumaquamarine', 'Media for Health Care': 'orange'}

# Create the figure and the axes with increased figure size
fig, ax = plt.subplots(figsize=(12, 10))

# Combine all subcategories and their values into a single list
all_items = [(subcat, value) for items in categories.values() for subcat, value in items]

# Sort the items by value in ascending order
sorted_items = sorted(all_items, key=lambda x: x[1], reverse=True)

# Loop over the sorted items in reverse order to create the stacked bar chart.
for subcat, value in reversed(sorted_items):
    # Find the category for the current subcategory
    for category, items in categories.items():
        if (subcat, value) in items:
            # Plot the horizontal bar with the corresponding value and color
            bar = ax.barh(subcat, value, color=category_colors[category])
            # Display the value at the end of each bar using the bar width
            bar_width = bar[0].get_width()
            # Use the bar's y-coordinate for text placement
            bar_y = bar[0].get_y() + bar[0].get_height() / 2
            ax.text(bar_width, bar_y, str(value), va='center', color='black', fontsize=15)  # Set the text size to 15

# Set the title of the chart with font size
ax.set_title('Biomedical Application Subdomains', fontsize=15)

# Add a legend for the colors
handles = [plt.Rectangle((0, 0), 1, 1, color=color, label=category) for category, color in category_colors.items()]
ax.legend(handles=handles, loc='lower right', fontsize=15)  # Set the legend font size to 15

# Set the x-axis label
ax.set_xlabel('Frequency', fontsize=15)  # Set the x-axis label and font size

# Show the x-axis labels and title
ax.xaxis.set_visible(True)

# Set the font size for x-axis and y-axis labels
ax.tick_params(axis='both', labelsize=15)

plt.tight_layout()  # Adjust subplot spacing to avoid cutting off labels

plt.savefig('viz/number_of_papers_subdomain_count_2024.pdf'.format(top_n))

# Show the plot
plt.show()

# %% [markdown]
# ## Target NLP Task

# %%
#df = pd.concat([df_initial, df_2024_included], ignore_index=True)
#df['year'] = df['year'].astype(int)

# %%
df['Target application'].value_counts()
# Out:
# Text Classification             55
# Information Extraction          27
# Relation Extraction             25
# Multi-Domain                    19
# Named Entity Recognition        16
# Information Retrieval           13
# Entity Normalization/Linking     9
# Knowledge Graph                  7
# Text Summarization               5
# Similarity Clustering            4
# Question Answering               4
# Text Generation                  3
# Other                            2
# Machine Reading Coprehension     2
# Explainable/ Fair AI             2
# Fact Verification                2
# Topic Modelling                  1
# Name: Target application, dtype: int64

# %%
category_counts = df['Target application'].value_counts()
top_n = len(df['Target application'].value_counts()) # interested in all categories

# Get the top 10 categories
top_10_categories = category_counts#.head(top_n)

# Sort the categories in descending order
top_10_categories = top_10_categories.sort_values(ascending=True)

# Transpose the DataFrame
top_10_categories = top_10_categories.transpose()


# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_categories.index, top_10_categories, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('NLP Task', fontsize=15)
plt.title('Number of Articles per NLP task', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/target_NLP_application_count_2024.pdf'.format(top_n))

# Display the chart
plt.show()

# %% [markdown]
# ### combined domains and nlp tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with information on biomedical domains and target NLP applications

# Get the top counts for Biomedical Domain Level 1 and Target application
top_biomedical_domains = df['Biomedical Domain Level 1'].value_counts()
top_nlp_tasks = df['Target application'].value_counts()

# Reverse the order for plotting to have the largest counts at the top of the plot
top_biomedical_domains_reversed = top_biomedical_domains[::-1]
top_nlp_tasks_reversed = top_nlp_tasks[::-1]

# Create a larger figure to hold both subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# Plot for Top Biomedical Domains by Frequency
bars_domains = axes[0].barh(top_biomedical_domains_reversed.index, top_biomedical_domains_reversed, color='lightgrey')
# Add labels to each bar in the domains plot
for bar in bars_domains:
    width = bar.get_width()
    axes[0].text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

axes[0].tick_params(axis='y', labelsize=15)
axes[0].tick_params(axis='x', labelsize=15)
axes[0].set_xlabel('Frequency', fontsize=15)
axes[0].set_title('Biomedical Domains by Frequency', fontsize=16)
axes[0].set_xlim(0, 65)  # Adjust the x-axis limit if needed

# Plot for Top NLP Tasks by Frequency
bars_tasks = axes[1].barh(top_nlp_tasks_reversed.index, top_nlp_tasks_reversed, color='lightgrey')
# Add labels to each bar in the NLP tasks plot
for bar in bars_tasks:
    width = bar.get_width()
    axes[1].text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

axes[1].tick_params(axis='y', labelsize=15)
axes[1].tick_params(axis='x', labelsize=15)
axes[1].set_xlabel('Frequency', fontsize=15)
axes[1].set_title('NLP Tasks by Frequency', fontsize=16)
axes[1].set_xlim(0, 60)  # Adjust the x-axis limit if needed

plt.tight_layout()
# Save the combined plot to a local folder
plt.savefig('viz/domains_and_nlp_tasks_frequency_2024.pdf')
# Display the combined chart
plt.show()

# %% [markdown]
# ### Domains - NLP Tasks Sanky Diagram

# %%
# %pip install pySankey
# Out:
# Requirement already satisfied: pySankey in /Users/donevas/opt/miniconda3/lib/python3.9/site-packages (0.0.1)
# DEPRECATION: prodigy 1.11.8 has a non-standard dependency specifier srsly>=2.0.0<3.0.0. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of prodigy or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install webcolors
# Out:
# Requirement already satisfied: webcolors in /Users/donevas/opt/miniconda3/lib/python3.9/site-packages (1.13)
# DEPRECATION: prodigy 1.11.8 has a non-standard dependency specifier srsly>=2.0.0<3.0.0. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of prodigy or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Group by 'Biomedical Domain Level 1' and 'Target application' and count
count_df = df.groupby(['Biomedical Domain Level 1', 'Target application']).size().reset_index(name='Sum of Included')

# Sort the DataFrame based on the count in descending order
count_df = count_df.sort_values(by='Sum of Included', ascending=False).reset_index(drop=True)
count_df.head()
# Out:
#         Biomedical Domain Level 1     Target application  Sum of Included
# 0            Knowledge Management    Text Classification               23
# 1                    Pharmacology    Relation Extraction               16
# 2  General biomedical text mining           Multi-Domain               15
# 3                        Clinical    Text Classification               14
# 4            Knowledge Management  Information Retrieval               12

# %%
top_5_domains = df['Biomedical Domain Level 1'].value_counts().head(5).index.tolist()
top_5_domains
# Out:
# ['Knowledge Management',
#  'General biomedical text mining',
#  'Pharmacology',
#  'Clinical',
#  'Media for Health Care']

# %%
filtered_count_df = count_df[count_df["Biomedical Domain Level 1"].isin(top_5_domains)]

# %%
l1 = filtered_count_df["Biomedical Domain Level 1"].to_list()
l2 = filtered_count_df["Target application"].to_list()
connect_values = count_df["Sum of Included"].to_list()
levels_combined = list(set(l1+l2))
levels_combined
# Out:
# ['Information Retrieval',
#  'Text Summarization',
#  'Text Generation',
#  'Fact Verification',
#  'General biomedical text mining',
#  'Multi-Domain',
#  'Knowledge Management',
#  'Pharmacology',
#  'Question Answering',
#  'Entity Normalization/Linking',
#  'Text Classification',
#  'Machine Reading Coprehension',
#  'Named Entity Recognition',
#  'Topic Modelling',
#  'Similarity Clustering',
#  'Media for Health Care',
#  'Knowledge Graph',
#  'Relation Extraction',
#  'Explainable/ Fair AI',
#  'Other',
#  'Information Extraction',
#  'Clinical']

# %%
#node_label = ["A1", "A2", "B1", "B2","B3", "C1", "C2"]
node_dict = {y:x for x, y in enumerate(levels_combined)}
node_dict
# Out:
# {'Information Retrieval': 0,
#  'Text Summarization': 1,
#  'Text Generation': 2,
#  'Fact Verification': 3,
#  'General biomedical text mining': 4,
#  'Multi-Domain': 5,
#  'Knowledge Management': 6,
#  'Pharmacology': 7,
#  'Question Answering': 8,
#  'Entity Normalization/Linking': 9,
#  'Text Classification': 10,
#  'Machine Reading Coprehension': 11,
#  'Named Entity Recognition': 12,
#  'Topic Modelling': 13,
#  'Similarity Clustering': 14,
#  'Media for Health Care': 15,
#  'Knowledge Graph': 16,
#  'Relation Extraction': 17,
#  'Explainable/ Fair AI': 18,
#  'Other': 19,
#  'Information Extraction': 20,
#  'Clinical': 21}

# %%
source = l1 #['A1','A1','A1','A2','A2','A2','B1','B2','B2','B3','B3']
target = l2 #['B1','B2','B3','B1','B2','B3','C1','C1','C2','C1','C2'] 
values = connect_values #[ 10, 5, 15, 5, 20, 45, 15, 20, 5, 30, 30 ]

# %%
source_node = [node_dict[x] for x in source]
target_node = [node_dict[x] for x in target]

# %%
#source_node

# %%
import plotly.graph_objects as go # Import the graphical object

fig = go.Figure( 
    data=[go.Sankey( # The plot we are interest
        # This part is for the node information
        node = dict( 
            label = levels_combined
        ),
        # This part is for the link information
        link = dict(
            source = source_node,
            target = target_node,
            value = values
        ))])

# With this save the plots 
plot(fig,
     image_filename='sankey_plot_1', 
     image='png', 
     image_width=900, 
     image_height=600
)
# And shows the plot
fig.show()

# %% [markdown]
# ## LLMs

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)

# Create a new column to store the flattened data types
df['Flattened_Models'] = df['LLM Model'].str.split(', ')

# Explode the flattened data types into separate rows
df_exploded = df.explode('Flattened_Models')
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace(r'(?i).*gpt.*', 'GPT', regex=True)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace(r'(?i).*t5.*', 'T5', regex=True)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace('Bio+Clinical BERT', 'BioClinicalBERT', regex=False)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace('Bio+ClinicalBERT', 'BioClinicalBERT', regex=False)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace('BioCinicalBERT', 'BioClinicalBERT', regex=False)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace('Sci-BERT uncased version', 'SciBERT', regex=False)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace('BioBERT (base and large)', 'BioBERT', regex=False)
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.replace('AlBERT', 'ALBERT', regex=False)


# Remove leading and trailing whitespaces from the 'Flattened_Models' column
df_exploded['Flattened_Models'] = df_exploded['Flattened_Models'].str.strip()

# Count the frequency of each data type
data_type_counts = df_exploded['Flattened_Models'].value_counts()

# Print the frequency counts
# Adjust the maximum display options to show the full list
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the full list of data type counts
print(data_type_counts)
# Out:
# BERT                                                                                 87
# BioBERT                                                                              82
# PubMedBERT                                                                           29
# SciBERT                                                                              26
# BlueBERT                                                                             17
# GPT                                                                                  16
# RoBERTa                                                                              16
# ClinicalBERT                                                                         13
# T5                                                                                    8
# BioClinicalBERT                                                                       8
# ALBERT                                                                                6
# DistilBERT                                                                            5
# COVID-Twitter-BERT                                                                    4
# BioLinkBERT                                                                           3
# Longformer                                                                            3
# ELECTRA                                                                               3
# XLNet                                                                                 2
# Sentence-BERT                                                                         2
# BART                                                                                  2
# BioALBERT                                                                             2
# BioELECTRA                                                                            2
# MentalRoBERTa                                                                         2
# Bioformer                                                                             2
# SapBERT                                                                               2
# SPECTER                                                                               2
# BERN                                                                                  2
# NCBI BERT                                                                             2
# Clinical Note BERT (CNBERT)                                                           1
# BioBART                                                                               1
# SciFive                                                                               1
# BERTopic                                                                              1
# MatBERT                                                                               1
# BatteryBERT                                                                           1
# 7 SCHOLARBERT variants                                                                1
# BioMedLM                                                                              1
# Siamese BERT                                                                          1
# PharmBERT                                                                             1
# BioMegatron                                                                           1
# Transformer                                                                           1
# DFCI-ImagingBERT                                                                      1
# ClninicalBERT                                                                         1
# pBERT                                                                                 1
# GatorTron                                                                             1
# SciBERT-BiLSTM                                                                        1
# BioBERT-BiLSTM                                                                        1
# UCSF BERT                                                                             1
# FoodNER(based on BERT)                                                                1
# BioM-ELECTRA                                                                          1
# MentalBERT                                                                            1
# BioM-ALBERT                                                                           1
# ColBERTv2                                                                             1
# Clinical Longformer                                                                   1
# BigBird Pegasus PubMed                                                                1
# AdaLM                                                                                 1
# COCO-DR                                                                               1
# ChemBERT                                                                              1
# LITMC-BERT                                                                            1
# BioBERT Ensamble                                                                      1
# FARM-BERT                                                                             1
# Relation BioBERT (R-BioBERT)                                                          1
# R-BERT                                                                                1
# BERTfilter                                                                            1
# Sultan                                                                                1
# UMLSBERT                                                                              1
# BERTScore                                                                             1
# SciNCL                                                                                1
# ASPIRE                                                                                1
# SpanBERT                                                                              1
# SciFive-PubMed-PMC                                                                    1
# BART XSUM                                                                             1
# BART Cochrance                                                                        1
# BioBART Cochrane                                                                      1
# Pegasus XSUM                                                                          1
# Pegasus PubMed                                                                        1
# Pegasus Cochrane                                                                      1
# Primera                                                                               1
# Primera Cochrane                                                                      1
# exBERT                                                                                1
# SentenceBERT                                                                          1
# UniLM                                                                                 1
# ProphetNet                                                                            1
# BENNERD(BERT-based Exhaustive Neural Named Entity Recognition and Disambiguation)     1
# Name: Flattened_Models, dtype: int64

# %%
#df_year_model = df_exploded[["year", "Flattened_Models"]]
df_year_model = df_exploded[df_exploded['year'] != 2024][["year", "Flattened_Models"]]

# Group by year and model, and count occurrences
year_model_counts = df_year_model.groupby(['year', 'Flattened_Models']).size().reset_index(name='counts')

# For each year, find the top 5 models
top5_per_year = year_model_counts.groupby('year').apply(lambda x: x.nlargest(5, 'counts')).reset_index(drop=True)

# Pivot this data for plotting
pivot_data = top5_per_year.pivot(index='year', columns='Flattened_Models', values='counts').fillna(0)
pivot_data.head()
# Out:
# Flattened_Models  BERT  BioBERT  BlueBERT  ClinicalBERT   GPT  NCBI BERT  \
# year
# 2019              10.0      4.0       0.0           0.0   0.0        1.0
# 2020              19.0     14.0       0.0           4.0   0.0        0.0
# 2021              15.0     24.0       5.0           0.0   0.0        0.0
# 2022              13.0     19.0       5.0           0.0   0.0        0.0
# 2023              30.0     20.0       0.0           0.0  15.0        0.0
#
# Flattened_Models  PubMedBERT  RoBERTa  SciBERT
# year
# 2019                     0.0      0.0      0.0
# 2020                     0.0      5.0      7.0
# 2021                     5.0      0.0      5.0
# 2022                    10.0      0.0      6.0
# 2023                    13.0      9.0      0.0

# %%
pastel_palette = sns.color_palette("Spectral", len(pivot_data.columns))

plt.figure(figsize=(12, 8))
ax = pivot_data.plot(kind='bar', stacked=True, figsize=(10, 6), color=pastel_palette)

# Adding data labels inside the bars
for rect in ax.patches:
    # Find where to place the label
    y_value = rect.get_y() + rect.get_height() / 2
    x_value = rect.get_x() + rect.get_width() / 2

    # Get the value to label
    value = int(rect.get_height())

    # Only label bars with a value
    if value > 0:
        ax.annotate(value, (x_value, y_value), ha='center', va='center', fontsize=12)

# Adding total label on top of each bar
for i, total in enumerate(pivot_data.sum(axis=1)):
    ax.text(i, total, str(int(total)), ha='center', va='bottom', fontsize=12)

plt.title("Top 5 Models per Year (Stacked Bar Chart)",fontsize=15)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xticks(rotation=45)
plt.legend(title="Models", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)
plt.tight_layout()
plt.savefig('viz/LLM_models_top5_per_year_2024.pdf'.format(top_n))
plt.show()

# %%
# Get the top 10 categories
top_10_categories = data_type_counts.head(10)

# Sort the categories in descending order
top_10_categories = top_10_categories.sort_values(ascending=True)

# Transpose the DataFrame
top_10_categories = top_10_categories.transpose()

# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_categories.index, top_10_categories, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('LLM Model Name', fontsize=15)
plt.title('Frequency of Models Use', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/LLM_models_top_10_2024.pdf'.format(top_n))

# Display the chart
plt.show()

# %% [markdown]
# ### combine models and over time trend

# %%
# Define the extended Okabe-Ito palette with the additional Light Lavender Purple
custom_colors = [
    "#E69F00",  # Orange
    "#56B4E9",  # Sky Blue
    "#009E73",  # Bluish Green
    "#F0E442",  # Yellow
    "#0072B2",  # Blue
    "#D55E00",  # Vermilion
    "#CC79A7",  # Reddish Purple
    "#808080",  # Black
    "#008080"   # teal
]

# Convert the custom colors list to a seaborn palette
okabe_ito_palette = sns.color_palette(custom_colors)
okabe_ito_palette
# Out:
# [(0.9019607843137255, 0.6235294117647059, 0.0),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784),
#  (0.0, 0.6196078431372549, 0.45098039215686275),
#  (0.9411764705882353, 0.8941176470588236, 0.25882352941176473),
#  (0.0, 0.4470588235294118, 0.6980392156862745),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.4745098039215686, 0.6549019607843137),
#  (0.5019607843137255, 0.5019607843137255, 0.5019607843137255),
#  (0.0, 0.5019607843137255, 0.5019607843137255)]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a larger figure to hold both subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# FIRST plot 
top_10_categories = data_type_counts.head(10)

# Sort the categories in descending order
top_10_categories = top_10_categories.sort_values(ascending=True)

# Transpose the DataFrame
top_10_categories = top_10_categories.transpose()

# Create a horizontal bar chart for the top 10 data types
#plt.figure(figsize=(10, 6))
bars = axes[0].barh(top_10_categories.index, top_10_categories, color='lightgrey')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    axes[0].text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

axes[0].tick_params(axis='y', labelsize=15)
axes[0].tick_params(axis='x', labelsize=15)
axes[0].set_xlabel('Frequency', fontsize=15)
#axes[0].set_ylabel('Data Sources', fontsize=15)
axes[0].set_title('Top 10 LLMs by Frequency', fontsize=16)
axes[0].set_xlim(0, 100)  # Set x-axis limit up to 125

# SECOND plot

# SECOND plot - Stacked Bar Chart for Model Frequency over Years
#colors = plt.cm.Pastel1(np.linspace(0, 1, len(models)))
pivot_data.plot(kind='bar', stacked=True, ax=axes[1], color=okabe_ito_palette, figsize=(15, 6))

axes[1].tick_params(axis='y', labelsize=15)
axes[1].tick_params(axis='x', labelsize=15, labelrotation=0)
axes[1].set_title('Model Frequency Over Years', fontsize=16)
axes[1].set_xlabel('Year', fontsize=15)

# Adding data labels inside the bars
for p in axes[1].patches:
    width, height = p.get_width(), p.get_height()
    if height > 0:
        axes[1].annotate(f'{int(height)}', (p.get_x() + width/2, p.get_y() + height/2), ha='center', va='center', fontsize=10)

# Adding total label on top of each bar
for i, total in enumerate(pivot_data.sum(axis=1)):
    axes[1].text(i, total, str(int(total)), ha='center', va='bottom', fontsize=12)

# Reverse the order of legend items and change the legend title
handles, labels = axes[1].get_legend_handles_labels()
axes[1].legend(handles[::-1], labels[::-1], title='Model Names', fontsize=10)

plt.tight_layout()
# Save the combined plot to a local folder
plt.savefig('viz/LLM_models_and_time_trend_2024.pdf')
# Display the combined chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a larger figure to hold both subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# FIRST plot 
top_10_categories = data_type_counts.head(10)

# Sort the categories in descending order
top_10_categories = top_10_categories.sort_values(ascending=True)

# Transpose the DataFrame
top_10_categories = top_10_categories.transpose()

# Create a horizontal bar chart for the top 10 data types
#plt.figure(figsize=(10, 6))
bars = axes[0].barh(top_10_categories.index, top_10_categories, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    axes[0].text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

axes[0].tick_params(axis='y', labelsize=15)
axes[0].tick_params(axis='x', labelsize=15)
axes[0].set_xlabel('Frequency', fontsize=15)
#axes[0].set_ylabel('Data Sources', fontsize=15)
axes[0].set_title('Top 10 LLMs by Frequency', fontsize=16)
axes[0].set_xlim(0, 100)  # Set x-axis limit up to 125

# SECOND plot - Normalized Stacked Bar Chart for Model Frequency over Years
# Normalize the pivot_data DataFrame to reflect percentages rather than absolute counts
pivot_data_normalized = pivot_data.div(pivot_data.sum(axis=1), axis=0) * 100

pivot_data_normalized.plot(kind='bar', stacked=True, ax=axes[1], color=pastel_palette, figsize=(15, 6))
axes[1].set_title('Model Frequency Over Years (Normalized)', fontsize=16)
axes[1].set_xlabel('Year', fontsize=15)
axes[1].set_ylabel('Proportion (%)', fontsize=15)
axes[1].tick_params(axis='x', labelrotation=0)  # Making x-axis labels horizontal

# Corrected approach for adding percentage labels
for i, (index, row) in enumerate(pivot_data_normalized.iterrows()):
    cumulative_height = 0
    for model in row.index:
        percentage = row[model]
        if percentage > 0:  # Only add labels to non-zero segments
            x = i
            y = cumulative_height + percentage / 2  # Position at the middle of the segment
            label = f'{percentage:.0f}%' if percentage > 5 else ''  # Only label if segment is large enough
            axes[1].annotate(label, (x, y), ha='center', va='center', fontsize=10, rotation=0)
            cumulative_height += percentage

plt.tight_layout()
# Save the combined plot to a local folder
#plt.savefig('viz/LLM_models_and_time_trend_2024.pdf')
# Display the combined chart
plt.show()

# %% [markdown]
# ### number of models over time

# %%
df_year_model_list = df[df['year'] != 2024][["year", "Flattened_Models"]]
#df_year_model = df_exploded[df_exploded['year'] != 2024][["year", "Flattened_Models"]]

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# Convert the "year" column to integers
df_year_model_list['year'] = df_year_model_list['year'].astype(int)

# Calculate the number of models used by each paper
df_year_model_list['Num_Models_Used'] = df_year_model_list['Flattened_Models'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# Calculate the average number of models for each year
yearly_avg = df_year_model_list.groupby('year')['Num_Models_Used'].mean()

# Calculate the confidence intervals for the averages
yearly_std = df_year_model_list.groupby('year')['Num_Models_Used'].std()
confidence_interval = stats.norm.interval(0.95, loc=yearly_avg, scale=yearly_std / np.sqrt(df_year_model_list['year'].nunique()))

# Create a DataFrame for the results
result_df = pd.DataFrame({
    "Year": yearly_avg.index,
    "Average_Num_Models": yearly_avg.values,
    "Lower_CI": confidence_interval[0],
    "Upper_CI": confidence_interval[1]
})

# Create a line graph with confidence intervals
plt.figure(figsize=(9, 6))
plt.plot(result_df['Year'], result_df['Average_Num_Models'], marker='o', label='Average Number of Models', color='b')
plt.fill_between(result_df['Year'], result_df['Lower_CI'], result_df['Upper_CI'], color='grey', alpha=0.2, label='95% Confidence Interval')

plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xticks(result_df['Year'])  # Set the x-axis ticks to match the "Year" values
#plt.title("Mean Number of Models Used by Papers Published Each Year", fontsize=15)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Mean (+/- std)", fontsize=15)
plt.legend(fontsize=12)
plt.grid(axis='y')  # Enable grid only on the y-axis

# Annotate each data point with rounded values
for i, row in result_df.iterrows():
    plt.text(row['Year'], round(row['Average_Num_Models'], 2) + 0.05, round(row['Average_Num_Models'], 2), ha='center', va='bottom', fontsize=15)
    
plt.savefig('viz/LLM_number_per_paper_over_time_2024.pdf'.format(top_n))

plt.tight_layout()
plt.show()

# %%
result_df
# Out:
#    Year  Average_Num_Models  Lower_CI  Upper_CI
# 0  2019            1.363636  0.772685  1.954588
# 1  2020            1.968750  0.889836  3.047664
# 2  2021            1.707317  0.665694  2.748940
# 3  2022            2.095238  0.512878  3.677598
# 4  2023            2.391304  0.947760  3.834848

# %% [markdown]
# ## Technical Details

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)

# %%
df_technical_setup = df[["Library/Framework Harmonized", "Hardware type", "Programming language" ,"publication_type"]]

# %%
df_technical_setup.head()
# Out:
#   Library/Framework Harmonized Hardware type Programming language  \
# 0                  HuggingFace      GPU, CPU               Python
# 1                      PyTorch           NaN               Python
# 2                      PyTorch           GPU               Python
# 3                  HuggingFace           NaN               Python
# 4                          NaN           TPU                  NaN
#
#      publication_type
# 0  biomedical_journal
# 1  biomedical_journal
# 2  biomedical_journal
# 3  biomedical_journal
# 4  biomedical_journal

# %%
nan_count = df_technical_setup.isna().sum()

# Print the results
print(nan_count)
# Out:
# Library/Framework Harmonized     59
# Hardware type                   118
# Programming language             37
# publication_type                 56
# dtype: int64

# %%
nan_counts = df_technical_setup.groupby('publication_type').apply(lambda x: x.isna().sum())
nan_counts
# Out:
#                     Library/Framework Harmonized  Hardware type  \
# publication_type
# biomedical_journal                            25             52
# nlp_venue                                     19             26
#
#                     Programming language  publication_type
# publication_type
# biomedical_journal                    15                 0
# nlp_venue                             11                 0

# %%
# Get the count of unique values in the "Hardware type" column
hardware_type_counts = df_technical_setup['Hardware type'].value_counts()
hardware_type_counts = hardware_type_counts.sort_values(ascending=True)

# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(hardware_type_counts.index, hardware_type_counts, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('Hardware Type', fontsize=15)
plt.title('Frequency of Reporting', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/technical_hardware_used_2024.pdf'.format(top_n))

# Display the chart
plt.show()

# %%
hardware_type_counts
# Out:
# TPU, GPU     1
# CPU          2
# TPU          4
# CPU, GPU     5
# GPU, CPU     6
# GPU         60
# Name: Hardware type, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Split the values in the "Programming language" column by ","
df_technical_setup['Programming language'] = df_technical_setup['Programming language'].str.split(', ')

# Explode the list into separate rows
df_technical_setup = df_technical_setup.explode('Programming language')

# Get the count of unique values in the "Programming language" column
programming_language_counts = df_technical_setup['Programming language'].value_counts()
programming_language_counts = programming_language_counts.sort_values(ascending=True)

# Create a horizontal bar chart for the counts
plt.figure(figsize=(10, 6))
bars = plt.barh(programming_language_counts.index, programming_language_counts, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)

plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('Programming language', fontsize=15)
plt.title('Reported Programming Language Count', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/technical_programming_language_count_2024.pdf')

# Display the chart
plt.show()
# Out:
# /var/folders/px/wtj901jn7z9f26xgbys4l7jh0000gp/T/ipykernel_38901/2156231770.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
programming_language_counts
# Out:
# C           1
# AWK         1
# PHP         1
# Perl        3
# R           4
# Java        6
# Python    157
# Name: Programming language, dtype: int64

# %%
# Create a new column to store the flattened data types
df_technical_setup['Flattened_Libraries'] = df_technical_setup['Library/Framework Harmonized'].str.split(', ')

# Explode the flattened data types into separate rows
df_exploded = df_technical_setup.explode('Flattened_Libraries')
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].str.lower()

df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("nltk", "NLTK")
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("transformers", "HuggingFace")
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("transformer", "HuggingFace")
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("huggingface", "HuggingFace")
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("tensorflow", "TensorFlow")
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("pytorch", "PyTorch")
df_exploded['Flattened_Libraries'] = df_exploded['Flattened_Libraries'].replace("stanford corenlp", "CoreNLP ")
 

# Count the frequency of each data type
library_counts_flat = df_exploded['Flattened_Libraries'].value_counts()

# %%
# Get the top 10 categories
top_10_libraries = library_counts_flat.head(10)

# Sort the categories in descending order
top_10_libraries = top_10_libraries.sort_values(ascending=True)
top_10_libraries
# Out:
# torch            4
# gensim           5
# CoreNLP          6
# keras            7
# spacy           10
# NLTK            13
# scikit-learn    21
# TensorFlow      30
# PyTorch         48
# HuggingFace     83
# Name: Flattened_Libraries, dtype: int64

# %%
#library_counts = df['Library/Framework Harmonized'].value_counts()
#library_counts = library_counts.sort_values(ascending=True)

# Create a horizontal bar chart for the top 10 data types
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_libraries.index, top_10_libraries, color='skyblue')

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height() / 2, f'{width}', va='center', fontsize=12)
    
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Frequency', fontsize=15)
plt.ylabel('Code Library', fontsize=15)
plt.title('Reported Library Usage Count', fontsize=15)
plt.tight_layout()

# Save the plot to a local folder
plt.savefig('viz/technical_code_library_count_2024.pdf')

# Display the chart
plt.show()

# %%
library_counts_flat
# Out:
# HuggingFace                       83
# PyTorch                           48
# TensorFlow                        30
# scikit-learn                      21
# NLTK                              13
# spacy                             10
# keras                              7
# CoreNLP                            6
# gensim                             5
# torch                              4
# numpy                              4
# neo4j                              4
# scispacy                           3
# scipy                              3
# top2vec                            2
# requests                           2
# boto3                              2
# fairseq                            2
# allennlp                           2
# entrez                             2
# subword-nmt                        2
# rdkit                              2
# chainer-chemistry                  2
# bertopic                           2
# tqdm                               2
# r topicmodels                      2
# clamp toolkit                      2
# sagemaker                          2
# mtimlextension package             2
# bert sentence_transformer          2
# elasticsearch                      2
# word2vec                           1
# nodevectors library                1
# opennmt                            1
# liblinear (for classification)     1
# slim                               1
# simpletransformers                 1
# fasttext                           1
# pandas                             1
# lime                               1
# django                             1
# jieba                              1
# mysql                              1
# networkx                           1
# apache spark                       1
# azure databricks                   1
# powerbi for visualization          1
# stanford openie                    1
# python                             1
# scispacy dependency parsers        1
# sentence-bert                      1
# Name: Flattened_Libraries, dtype: int64

# %%
top_10_libraries.replace('Stanford CoreNLP', 'CoreNLP')
# Out:
# torch            4
# gensim           5
# CoreNLP          6
# keras            7
# spacy           10
# NLTK            13
# scikit-learn    21
# TensorFlow      30
# PyTorch         48
# HuggingFace     83
# Name: Flattened_Libraries, dtype: int64

# %% [markdown]
# ### technical summary

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df_technical_setup and top_10_libraries are already defined with the necessary data

# Setup for subplot arrangement
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

# Plot for "Hardware type"
axes[0].barh(hardware_type_counts.index, hardware_type_counts, color='lightgrey')
for i, v in enumerate(hardware_type_counts):
    axes[0].text(v, i, f"{v}", va='center', fontsize=12)

# Plot for "Programming language"
axes[1].barh(programming_language_counts.index, programming_language_counts, color='lightgrey')
for i, v in enumerate(programming_language_counts):
    axes[1].text(v, i, f"{v}", va='center', fontsize=12)

# Plot for "Library/Framework Harmonized"
# Assuming top_10_libraries data is prepared similarly to the previous examples
axes[2].barh(top_10_libraries.index, top_10_libraries, color='lightgrey')
for i, v in enumerate(top_10_libraries):
    axes[2].text(v, i, f"{v}", va='center', fontsize=12)

# Setting labels and titles for each subplot
axes[0].set_xlabel('Frequency', fontsize=15)
axes[0].set_title('Hardware Type Reporting', fontsize=15)
axes[0].tick_params(axis='y', labelsize=15)
axes[0].tick_params(axis='x', labelsize=15)

axes[1].tick_params(axis='y', labelsize=15)
axes[1].tick_params(axis='x', labelsize=15)
axes[1].set_xlabel('Frequency', fontsize=15)
axes[1].set_title('Programming Language Reporting', fontsize=15)
axes[1].set_xlim(0, 170) 


axes[2].tick_params(axis='y', labelsize=15)
axes[2].tick_params(axis='x', labelsize=15)
axes[2].set_xlabel('Frequency', fontsize=15)
axes[2].set_title('Top 10 Library/Framework Usage', fontsize=15)

# Adjust subplot parameters to reduce white space
plt.subplots_adjust(wspace=0.01)  # Adjust the wspace parameter as needed to reduce the white space

plt.tight_layout()


# Save the combined plot to a local folder
plt.savefig('viz/technical_summary_2024.pdf')

# Display the combined chart
plt.show()

# %% [markdown]
# ## Data and Code Availability

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)

# %%
df_transparency = df[["year", "Source code availability", "Data used availability", "Hosted Application for End-users", "publication_type"]]
df_transparency.fillna("no", inplace=True)
# Out:
# /Users/donevas/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_transparency['Hosted Application for End-users'] = df_transparency['Hosted Application for End-users'].str.split(':|,', n=1).str[0]
# Out:
# /var/folders/px/wtj901jn7z9f26xgbys4l7jh0000gp/T/ipykernel_38901/2614672984.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_transparency
# Out:
#      year     Source code availability Data used availability  \
# 0    2021                           no              partially
# 1    2021                           no                     no
# 2    2020                          yes                    yes
# 3    2023                          yes                    yes
# 4    2021                          yes                     no
# 5    2022                          yes                    yes
# 6    2021                          yes                    yes
# 7    2019                           no                    yes
# 8    2023                           no                    yes
# 9    2021                           no                    yes
# 10   2019                          yes                    yes
# 11   2019                           no                    yes
# 12   2021                           no                     no
# 13   2022                           no                     no
# 14   2022                          yes                    yes
# 15   2022                          yes                    yes
# 16   2023                          yes                    yes
# 17   2021                          yes                    yes
# 18   2022                          yes                    yes
# 19   2023                           no                     no
# 20   2021                           no                    yes
# 21   2021                          yes                    yes
# 22   2021                           no                     no
# 23   2022                          yes                    yes
# 24   2019                           no                    yes
# 25   2022                           no                     no
# 26   2022                           no                    yes
# 27   2021                          yes                     no
# 28   2021                           no                    yes
# 29   2022                          yes                    yes
# 30   2020                           no                    yes
# 31   2023                          yes                    yes
# 32   2022                           no                    yes
# 33   2021                           no                    yes
# 34   2020                          yes                    yes
# 35   2023                          yes                    yes
# 36   2021                           no              partially
# 37   2022                          yes                    yes
# 38   2023                          yes                    yes
# 39   2023                          yes                    yes
# 40   2022                           no                     no
# 41   2021                           no                    yes
# 42   2020                          yes                    yes
# 43   2022                          yes                    yes
# 44   2021                           no                    yes
# 45   2022                           no                     no
# 46   2022                           no                    yes
# 47   2022                           no                    yes
# 48   2020                           no                    yes
# 49   2021                           no                    yes
# 50   2021                          yes                    yes
# 51   2022                          yes                     no
# 52   2020                           no                    yes
# 53   2022                           no              partially
# 54   2022                           no                     no
# 55   2020                          yes                    yes
# 56   2020                          yes                    yes
# 57   2022                           no                    yes
# 58   2022                          yes                    yes
# 59   2021                           no                     no
# 60   2020                          yes                    yes
# 61   2022                          yes                    yes
# 62   2021                          yes                    yes
# 63   2021                           no                     no
# 64   2022                          yes                    yes
# 65   2022                          yes                    yes
# 66   2021                           no                    yes
# 67   2021                          yes                    yes
# 68   2022                          yes                    yes
# 69   2022                          yes                    yes
# 70   2020                           no                    yes
# 71   2020                          yes                    yes
# 72   2021                          yes                    yes
# 73   2020                           no                    yes
# 74   2023                           no                    yes
# 75   2019                           no                    yes
# 76   2022                          yes                    yes
# 77   2022                           no                     no
# 78   2021                          yes                    yes
# 79   2022                          yes                     no
# 80   2022                           no                     no
# 81   2021                          yes                     no
# 82   2022                          yes                    yes
# 83   2021                           no                    yes
# 84   2022                          yes                    yes
# 85   2021                          yes                    yes
# 86   2022                          yes                    yes
# 87   2023                          yes                    yes
# 88   2022                          yes                     no
# 89   2021                          yes                    yes
# 90   2021                          yes                    yes
# 91   2021                           no                    yes
# 92   2020                          yes                    yes
# 93   2020                           no                    yes
# 94   2021                          yes                    yes
# 95   2019                           no                     no
# 96   2020                          yes                    yes
# 97   2020                           no                    yes
# 98   2020                          yes                    yes
# 99   2021                           no                    yes
# 100  2020                          yes                    yes
# 101  2020                          yes                    yes
# 102  2020                           no                    yes
# 103  2019                           no                    yes
# 104  2019                           no                    yes
# 105  2021                          yes                    yes
# 106  2021                           no                    yes
# 107  2020                           no                    yes
# 108  2020                          yes                    yes
# 109  2019                          yes                    yes
# 110  2020                          yes                    yes
# 111  2020                          yes                    yes
# 112  2019                           no                     no
# 113  2021                           no                    yes
# 114  2019                           no                    yes
# 115  2020                           no                    yes
# 116  2020                          yes                    yes
# 117  2020                          yes                    yes
# 118  2020                           no                    yes
# 119  2021                           no                     no
# 120  2023                           no                     no
# 121  2020                           no                     no
# 122  2022                           no                     no
# 123  2020                          yes                    yes
# 124  2020                           no                    yes
# 125  2020                          yes                    yes
# 126  2021                          yes                    yes
# 127  2021                           no                    yes
# 128  2021                           no                    yes
# 129  2022                           no                    yes
# 130  2022                           no                    yes
# 131  2023                          yes                    yes
# 132  2022                          yes                    yes
# 133  2022                           no                    yes
# 134  2022                           no                    yes
# 135  2021                           no                    yes
# 136  2023                           no                    yes
# 137  2022                           no                    yes
# 138  2023                           no                    yes
# 139  2022                          yes                    yes
# 140  2023                          Yes                     no
# 141  2023                           No                     no
# 142  2023                          Yes                     no
# 143  2023                          Yes                     no
# 144  2023                          Yes                     no
# 145  2024                           No                     no
# 146  2023                           No                     no
# 147  2023                           No                     no
# 148  2023                          Yes                     no
# 149  2023                           No                     no
# 150  2023                          Yes                     no
# 151  2023                           No                     no
# 152  2023                           No                     no
# 153  2023                          Yes                     no
# 154  2023                          Yes                     no
# 155  2023                           No                     no
# 156  2023                          Yes                     no
# 157  2023                          Yes                     no
# 158  2023                          Yes                     no
# 159  2023                           No                     no
# 160  2023                          Yes                     no
# 161  2023                          Yes                     no
# 162  2023                           No                     no
# 163  2023                          Yes                     no
# 164  2023                          Yes                     no
# 165  2023                          Yes                     no
# 166  2023                           No                     no
# 167  2023                           No                     no
# 168  2023                           No                     no
# 169  2023                          Yes                     no
# 170  2023                          Yes                     no
# 171  2023                          Yes                     no
# 172  2023                          Yes                     no
# 173  2023                          Yes                     no
# 174  2023                          Yes                     no
# 175  2023                          Yes                     no
# 176  2023                          Yes                     no
# 177  2023                           No                     no
# 178  2023                           no                     no
# 179  2023                           no                     no
# 180  2023                           No                     no
# 181  2023                           no                     no
# 182  2023                           No                     no
# 183  2023                           No                     no
# 184  2023                           No                     no
# 185  2023                           No                     no
# 186  2023                           No                     no
# 187  2023                          Yes                     no
# 188  2023  Yes, but link 404 not found                     no
# 189  2023                          Yes                     no
# 190  2023                           No                     no
# 191  2023                           No                     no
# 192  2023                          Yes                     no
# 193  2023                          Yes                     no
# 194  2023                          Yes                     no
# 195  2023                           No                     no
#
#     Hosted Application for End-users    publication_type
# 0                                 no  biomedical_journal
# 1                                yes  biomedical_journal
# 2                                 no  biomedical_journal
# 3                                 no  biomedical_journal
# 4                                 no  biomedical_journal
# 5                                 no  biomedical_journal
# 6                                 no  biomedical_journal
# 7                                 no  biomedical_journal
# 8                                yes  biomedical_journal
# 9                                yes  biomedical_journal
# 10                               yes  biomedical_journal
# 11                                no  biomedical_journal
# 12                                no  biomedical_journal
# 13                                no  biomedical_journal
# 14                                no  biomedical_journal
# 15                                no  biomedical_journal
# 16                                no  biomedical_journal
# 17                                no  biomedical_journal
# 18                                no  biomedical_journal
# 19                                no  biomedical_journal
# 20                                no  biomedical_journal
# 21                               yes  biomedical_journal
# 22                                no  biomedical_journal
# 23                               yes  biomedical_journal
# 24                                no  biomedical_journal
# 25                                no  biomedical_journal
# 26                                no  biomedical_journal
# 27                                no  biomedical_journal
# 28                                no  biomedical_journal
# 29                               yes  biomedical_journal
# 30                                no  biomedical_journal
# 31                                no  biomedical_journal
# 32                                no  biomedical_journal
# 33                                no  biomedical_journal
# 34                                no  biomedical_journal
# 35                                no  biomedical_journal
# 36                                no  biomedical_journal
# 37                               yes  biomedical_journal
# 38                                no  biomedical_journal
# 39                                no  biomedical_journal
# 40                                no  biomedical_journal
# 41                                no  biomedical_journal
# 42                                no  biomedical_journal
# 43                                no  biomedical_journal
# 44                                no  biomedical_journal
# 45                             https  biomedical_journal
# 46                                no  biomedical_journal
# 47                                no  biomedical_journal
# 48                                no  biomedical_journal
# 49                                no  biomedical_journal
# 50                                no  biomedical_journal
# 51                                no  biomedical_journal
# 52                                no  biomedical_journal
# 53                               yes  biomedical_journal
# 54                                no  biomedical_journal
# 55                                no  biomedical_journal
# 56                                no  biomedical_journal
# 57                                no  biomedical_journal
# 58                                no  biomedical_journal
# 59                                no  biomedical_journal
# 60                                no  biomedical_journal
# 61                               yes  biomedical_journal
# 62                                no  biomedical_journal
# 63                                no  biomedical_journal
# 64                                no  biomedical_journal
# 65                                no  biomedical_journal
# 66                                no  biomedical_journal
# 67                                no  biomedical_journal
# 68                                no  biomedical_journal
# 69                                no  biomedical_journal
# 70                                no  biomedical_journal
# 71                                no  biomedical_journal
# 72                                no  biomedical_journal
# 73                                no  biomedical_journal
# 74                                no  biomedical_journal
# 75                                no  biomedical_journal
# 76                                no  biomedical_journal
# 77                               yes  biomedical_journal
# 78                               yes  biomedical_journal
# 79                                no  biomedical_journal
# 80                                no  biomedical_journal
# 81                               yes  biomedical_journal
# 82                                no  biomedical_journal
# 83                                no  biomedical_journal
# 84                                no  biomedical_journal
# 85                                no  biomedical_journal
# 86                                no  biomedical_journal
# 87                                no  biomedical_journal
# 88                                no  biomedical_journal
# 89                                no           nlp_venue
# 90                                no           nlp_venue
# 91                                no           nlp_venue
# 92                                no           nlp_venue
# 93                                no           nlp_venue
# 94                                no           nlp_venue
# 95                                no           nlp_venue
# 96                                no           nlp_venue
# 97                                no           nlp_venue
# 98                                no           nlp_venue
# 99                                no           nlp_venue
# 100                               no           nlp_venue
# 101                               no           nlp_venue
# 102                               no           nlp_venue
# 103                               no           nlp_venue
# 104                               no           nlp_venue
# 105                               no           nlp_venue
# 106                               no           nlp_venue
# 107                               no           nlp_venue
# 108                               no           nlp_venue
# 109                               no           nlp_venue
# 110                               no           nlp_venue
# 111                               no           nlp_venue
# 112                               no           nlp_venue
# 113                               no           nlp_venue
# 114                               no           nlp_venue
# 115                               no           nlp_venue
# 116                              yes           nlp_venue
# 117                              yes           nlp_venue
# 118                               no           nlp_venue
# 119                               no           nlp_venue
# 120                               no           nlp_venue
# 121                               no           nlp_venue
# 122                               no           nlp_venue
# 123                               no           nlp_venue
# 124                               no           nlp_venue
# 125                               no           nlp_venue
# 126                               no           nlp_venue
# 127                               no           nlp_venue
# 128                               no           nlp_venue
# 129                               no           nlp_venue
# 130                               no           nlp_venue
# 131                               no           nlp_venue
# 132                               no           nlp_venue
# 133                               no           nlp_venue
# 134                               no           nlp_venue
# 135                               no           nlp_venue
# 136                               no           nlp_venue
# 137                               no           nlp_venue
# 138                               no           nlp_venue
# 139                               no           nlp_venue
# 140                               No  biomedical_journal
# 141                               No  biomedical_journal
# 142                               No           nlp_venue
# 143                               No           nlp_venue
# 144                               No  biomedical_journal
# 145                               No  biomedical_journal
# 146                               No           nlp_venue
# 147                               No  biomedical_journal
# 148                               No  biomedical_journal
# 149                               No           nlp_venue
# 150                               No  biomedical_journal
# 151                               No  biomedical_journal
# 152                               No  biomedical_journal
# 153                               No  biomedical_journal
# 154                               No  biomedical_journal
# 155                              Yes  biomedical_journal
# 156                              Yes  biomedical_journal
# 157                               No  biomedical_journal
# 158                               No           nlp_venue
# 159                               No  biomedical_journal
# 160                               No  biomedical_journal
# 161                               No  biomedical_journal
# 162                               No  biomedical_journal
# 163                              Yes  biomedical_journal
# 164                               No  biomedical_journal
# 165                               No  biomedical_journal
# 166                               No  biomedical_journal
# 167                              Yes  biomedical_journal
# 168                              Yes  biomedical_journal
# 169                               No  biomedical_journal
# 170                               no  biomedical_journal
# 171                               no  biomedical_journal
# 172                               no  biomedical_journal
# 173                               no  biomedical_journal
# 174                               No  biomedical_journal
# 175                               No  biomedical_journal
# 176                              Yes  biomedical_journal
# 177                               No  biomedical_journal
# 178                               No  biomedical_journal
# 179                               No  biomedical_journal
# 180                               No  biomedical_journal
# 181                               No  biomedical_journal
# 182                               No  biomedical_journal
# 183                               No  biomedical_journal
# 184                              Yes  biomedical_journal
# 185                               No  biomedical_journal
# 186                              Yes  biomedical_journal
# 187                               No  biomedical_journal
# 188                               No           nlp_venue
# 189                               No           nlp_venue
# 190                               No  biomedical_journal
# 191                               No  biomedical_journal
# 192                              Yes  biomedical_journal
# 193                               No           nlp_venue
# 194                              Yes  biomedical_journal
# 195                               No  biomedical_journal

# %%
# Group by year and calculate the percentages for each category
result_by_year = df_transparency.groupby("year").agg({
    "Source code availability": lambda x: (x == "yes").mean() * 100,
    "Data used availability": lambda x: (x == "yes").mean() * 100,
    "Hosted Application for End-users": lambda x: (x == "yes").mean() * 100
}).reset_index()

# Rename columns for clarity
result_by_year.columns = ["Year", "Source code availability (%)", "Data used availability (%)", "Hosted Application for End-users (%)"]
result_by_year
# Out:
#    Year  Source code availability (%)  Data used availability (%)  \
# 0  2019                     18.181818                   81.818182
# 1  2020                     59.375000                   96.875000
# 2  2021                     41.463415                   73.170732
# 3  2022                     54.761905                   71.428571
# 4  2023                     11.594203                   17.391304
# 5  2024                      0.000000                    0.000000
#
#    Hosted Application for End-users (%)
# 0                              9.090909
# 1                              6.250000
# 2                             12.195122
# 3                             14.285714
# 4                              1.449275
# 5                              0.000000

# %%
result = df_transparency.groupby("publication_type").agg({
    "Source code availability": lambda x: (x == "yes").mean() * 100,
    "Data used availability": lambda x: (x == "yes").mean() * 100,
    "Hosted Application for End-users": lambda x: (x == "yes").mean() * 100
}).reset_index()

# Rename columns for clarity
result.columns = ["publication_type", "Source code availability", "Data used availability", "Application for End-users"]
result
# Out:
#      publication_type  Source code availability  Data used availability  \
# 0  biomedical_journal                 35.036496               48.905109
# 1           nlp_venue                 35.593220               76.271186
#
#    Application for End-users
# 0                   9.489051
# 1                   3.389831

# %%
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.annotate(f'{height:.0f}%',
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3),  # 3 points vertical offset
                     textcoords="offset points",
                     ha='center', va='bottom', fontsize=15)

# %%
from matplotlib.patches import Patch

# Adjusted code

fig, ax = plt.subplots(figsize=(10, 6))  # Increased plot size

# The x position for each bar
bar_width = 0.35
index = np.arange(len(result.columns) - 1)

bar1 = ax.bar(index, result.iloc[0, 1:], bar_width, label="Biomedical Journal", color='skyblue')
bar2 = ax.bar(index + bar_width, result.iloc[1, 1:], bar_width, label="NLP Venue", color='darkgrey')

#ax.set_xlabel('Category', fontsize=15)
#ax.set_ylabel('Percentage', fontsize=15)
ax.set_title('Transparency of Methods', fontsize=15)
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(result.columns[1:], fontsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_ylim(0, 100)

# Adding percentage labels on the bars
add_labels(bar1)
add_labels(bar2)

# Create legend handles for each category
legend_handles = [Patch(color='skyblue', label='Biomedical Journal'), Patch(color='darkgrey', label='NLP Venue')]

# Add color legend
plt.legend(handles=legend_handles, fontsize=15)
plt.savefig('viz/rs_transparency_overview_2024.pdf')

plt.show()

# %%
df_overview = df_transparency.groupby(['publication_type', 'New dataset developed']).size().reset_index(name='counts')
df_overview
# Out:
#      publication_type New dataset developed  counts
# 0  biomedical_journal                    no      49
# 1  biomedical_journal                   yes      40
# 2           nlp_venue                    no      30
# 3           nlp_venue                   yes      22

# %%
df_overview = df_transparency.groupby(['publication_type', 'Source code availability']).size().reset_index(name='counts')
df_overview
# Out:
#      publication_type Source code availability  counts
# 0  biomedical_journal                       no      41
# 1  biomedical_journal                      yes      48
# 2           nlp_venue                       no      31
# 3           nlp_venue                      yes      21

# %%
# Group by "publication_type" and "Source code availability" and calculate the percentage
df_grouped = df_transparency.groupby(['publication_type', 'Source code availability']).size().unstack(fill_value=0)
df_grouped_percentage = df_grouped.div(df_grouped.sum(axis=1), axis=0) * 100
df_grouped_percentage
# Out:
# Source code availability         no        yes
# publication_type
# biomedical_journal        46.067416  53.932584
# nlp_venue                 59.615385  40.384615

# %%
df_grouped = df_transparency.groupby(['publication_type', 'Data used availability']).size().unstack(fill_value=0)
df_grouped_percentage = df_grouped.div(df_grouped.sum(axis=1), axis=0) * 100
df_grouped_percentage
# Out:
# Data used availability         no  partially        yes
# publication_type
# biomedical_journal      21.348315   3.370787  75.280899
# nlp_venue               13.461538   0.000000  86.538462

# %%
# Create a larger figure
plt.figure(figsize=(20, 3))

# Group by "Source code availability" and "publication_type", then count the occurrences
counts = df_transparency.groupby(['Source code availability', 'publication_type']).size().unstack(fill_value=0)

# Plot the stacked bar chart
bars = counts.plot(kind='bar', stacked=True, color=['skyblue', 'darkblue'], width=0.8)

# Add count values as annotations for each bar
for i, source_avail in enumerate(counts.index):
    for pub_type, count in zip(counts.columns, counts.loc[source_avail]):
        total_count = counts.sum(axis=1)[source_avail]
        plt.text(i, total_count - 13, str(count), color='white' if count < counts.sum(axis=1).max() else 'black', ha='center', va='center', fontsize=12)

# Add total count values on top of each bar
for i, total_count in enumerate(counts.sum(axis=1)):
    plt.text(i, total_count, str(total_count), color='black', ha='center', va='bottom', fontsize=12)
    
# Customize the plot
plt.xticks(range(len(counts.index)), counts.index, rotation=0, fontsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.xlabel('Source code availability', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(['Biomedical Journal', 'NLP Venue'], title='Publication Type', fontsize=12)

# Set the y-axis limit to ensure it reaches up to 100
plt.ylim(0, 100)

# Tight layout for better visualization
plt.tight_layout()

# Display the chart
plt.show()

# %% [markdown]
# ## Risk of bias

# %%
df = pd.concat([df_initial, df_2024_included], ignore_index=True)
df['year'] = df['year'].astype(int)

# %%
df.columns
# Out:
# Index(['author', 'doi', 'Link to paper', 'title', 'journal', 'year',
#        'Extracted by', 'Included', 'Reason for exclusion',
#        'Target application', 'Domain of automated approach', 'Target database',
#        'Data type', 'Data filter applied', 'Hosted Application for End-users',
#        'Alternative Approach', 'LLM Model', 'Models/Resources used with LLM',
#        'System Architecture/ Flow', 'Programming language',
#        'Library/Framework', 'Library/Framework Harmonized',
#        'Reported performance metrics',
#        'Reported performance metrics Harmonized', 'Source code availability',
#        'Source code link', 'Data used availability', 'Preprocessing applied',
#        'Pretraining corpus origin', 'Pretraining corpus size',
#        'Fine-tuning corpus data/task', 'New annotations', 'Annotations type',
#        'New dataset developed', 'Fine-tuning corpus size',
#        'Number of tasks/datasets for performance evaluation',
#        'Hardware used for training/validation/fine-tuning', 'Hardware type',
#        'Internal validity 1', 'Internal validity 2', 'External validity',
#        'External validity.1', 'Comment', 'Unnamed: 43', 'url', 'label', 'type',
#        'abstract', 'address', 'accession', 'Link', 'issue', 'keywords',
#        'language', 'issn', 'pages', 'volume', 'DA', 'DB', 'DP', 'ID', 'j2',
#        'm3', 'n1', 'ST', 'm1', 'c5', 'c2', 'c1', 'OP', 'publication_type',
#        'Unnamed: 40', 'Data availability', 'Unnamed: 33'],
#       dtype='object')

# %%
df_rob = df[["Internal validity 1", "Internal validity 2", "External validity" ,"External validity.1"]]
# Define the new column names
new_column_names = {
    "Internal validity 1": "data_split_reported",
    "Internal validity 2": "overfitting_avoided",
    "External validity": "compared_to_others",
    "External validity.1": "external_validity"
}
# Rename the columns
df_rob = df_rob.rename(columns=new_column_names)

# Convert column names to lowercase
df_rob = df_rob.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# Replace NaNs with "no"
df_rob = df_rob.fillna('no')

# Replace "yes" with "yes" in 'overfitting_avoided' column
df_rob = df_rob.replace(r'^yes.*', 'yes', regex=True)
df_rob = df_rob.replace(r'^partial.*', 'yes', regex=True)

df_rob.head(5)
# Out:
#   data_split_reported overfitting_avoided compared_to_others  \
# 0                 yes                  no                 no
# 1                 yes                  no                yes
# 2                 yes                  no                yes
# 3                 yes                  no                yes
# 4                  no                  no                yes
#
#                                    external_validity
# 0                                                 no
# 1                                           word2vec
# 2                         cnn, customized text query
# 3                        cnn, bi-lstm, scifice-large
# 4  svc, k-beighbors, decision tree, random forest...

# %%
len(df_rob[df_rob["data_split_reported"]=="yes"])/len(df_rob)
# Out:
# 0.8877551020408163

# %%
len(df_rob[df_rob["overfitting_avoided"]=="yes"])/len(df_rob)
# Out:
# 0.22448979591836735

# %%
len(df_rob[df_rob["compared_to_others"]=="yes"])/len(df_rob)
# Out:
# 0.8418367346938775
